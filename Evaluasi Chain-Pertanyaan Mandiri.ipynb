# %% [markdown]
# #Install Library

# %%
# !pip install langchain selenium langdetect pymupdf "unstructured[all-docs]" sentence-transformers faiss-cpu pandas evaluate rouge-score ipython-autotime
# !sudo apt-get install libmagic-dev poppler-utils tesseract-ocr libxml2 libxslt-dev
import nltk
nltk.download('punkt')
# %load_ext autotime
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.1.17)
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (4.20.0)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (1.0.9)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.10/dist-packages (1.24.2)
# Requirement already satisfied: unstructured[all-docs] in /usr/local/lib/python3.10/dist-packages (0.13.6)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.7.0)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.10/dist-packages (1.8.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.6.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.36 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.36)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.50)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.54)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.11.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Requirement already satisfied: PyMuPDFb==1.24.1 in /usr/local/lib/python3.10/dist-packages (from pymupdf) (1.24.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.4.27)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.9.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.12.3)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.11.1)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2024.4.27)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.9.0)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.2.1)
# Requirement already satisfied: unstructured-client in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.22.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.14.1)
# Requirement already satisfied: onnx in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.3)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (20231228)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.0.1)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.6)
# Requirement already satisfied: pypandoc in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.13)
# Requirement already satisfied: pillow-heif in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.16.0)
# Requirement already satisfied: unstructured-inference==0.7.29 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.7.29)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.1.2)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: google-cloud-vision in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.7.2)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.2.0)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.1.2)
# Requirement already satisfied: pikepdf in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (8.15.1)
# Requirement already satisfied: msg-parser in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.3.12)
# Requirement already satisfied: python-pptx<=0.6.23 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.6.23)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (0.3.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (0.0.9)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (0.23.0)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (4.8.0.76)
# Requirement already satisfied: onnxruntime>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (1.17.3)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (4.40.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.2.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.19.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (23.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.14.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.2)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.23->unstructured[all-docs]) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.29->unstructured[all-docs]) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.29->unstructured[all-docs]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.29->unstructured[all-docs]) (0.4.3)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured[all-docs]) (2.5)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (2.11.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (3.20.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: olefile>=0.46 in /usr/local/lib/python3.10/dist-packages (from msg-parser->unstructured[all-docs]) (0.47)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[all-docs]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[all-docs]) (1.4.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[all-docs]) (1.1.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[all-docs]) (42.0.5)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from pikepdf->unstructured[all-docs]) (1.2.14)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: deepdiff>=6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (7.0.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from deepdiff>=6.0->unstructured-client->unstructured[all-docs]) (4.1.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.63.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.63.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (4.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.4)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.29->unstructured[all-docs]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.29->unstructured[all-docs]) (24.3.25)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.13)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.1.10)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.11.0)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.3.10)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.17.1+cu121)
# Requirement already satisfied: effdet in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.4.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.29->unstructured[all-docs]) (10.0)
# Requirement already satisfied: timm>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.9.16)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (2.3.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (2.8.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (4.29.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (3.1.2)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libxslt1-dev' instead of 'libxslt-dev'
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# libmagic-dev is already the newest version (1:5.41-3ubuntu0.1).
# libxml2 is already the newest version (2.9.13+dfsg-1ubuntu0.4).
# libxslt1-dev is already the newest version (1.1.34-4ubuntu0.22.04.1).
# poppler-utils is already the newest version (22.02.0-2ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# time: 369 µs (started: 2024-05-06 00:19:36 +00:00)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #Load Document & Splitting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# time: 2.67 s (started: 2024-05-06 00:19:48 +00:00)

# %%
from langchain.schema import Document
import json
from typing import Iterable
import os

def load_from_json(file_path)->Iterable[Document]:
    array = []
    with open(file_path, 'r') as json_file:
        for line in json_file:
            data = json.loads(line)
            obj = Document(**data)
            array.append(obj)
    return array

docs = load_from_json('/content/drive/MyDrive/Skripsi/dataset.json')
# Out:
# time: 2.25 s (started: 2024-05-06 00:19:55 +00:00)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
#ganti chunk size dan overlap buat eval
    chunk_size = 1500,
    chunk_overlap  = 100,
    length_function = len,
    is_separator_regex = False,
)
char_splits= text_splitter.split_documents(docs)
# Out:
# time: 2.41 s (started: 2024-05-06 02:49:37 +00:00)

# %% [markdown]
# #Embedding & Indexing

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/paraphrase-multilingual-mpnet-base-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.13k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# time: 20.2 s (started: 2024-05-06 00:20:10 +00:00)

# %%
from langchain.vectorstores import FAISS
import joblib
db = FAISS.from_documents(documents=char_splits, embedding=embeddings)
joblib.dump(db, '/content/drive/MyDrive/Skripsi/Db/db_500_0_paraphrase_all-mpnet-base-v2.joblib')
# Out:
# ['/content/drive/MyDrive/Skripsi/Db/db_500_0_paraphrase_all-mpnet-base-v2.joblib']
# time: 5min 40s (started: 2024-05-06 01:26:08 +00:00)

# %%
from langchain.vectorstores import FAISS
import joblib
db = FAISS.from_documents(documents=char_splits, embedding=embeddings)
joblib.dump(db, '/content/drive/MyDrive/Skripsi/Db/db_500_100_paraphrase_all-mpnet-base-v2.joblib')
# Out:
# ['/content/drive/MyDrive/Skripsi/Db/db_500_100_paraphrase_all-mpnet-base-v2.joblib']
# time: 6min 37s (started: 2024-05-06 02:05:07 +00:00)

# %%
from langchain.vectorstores import FAISS
import joblib
db = FAISS.from_documents(documents=char_splits, embedding=embeddings)
joblib.dump(db, '/content/drive/MyDrive/Skripsi/Db/db_500_200_paraphrase_all-mpnet-base-v2.joblib')
# Out:
# ['/content/drive/MyDrive/Skripsi/Db/db_500_200_paraphrase_all-mpnet-base-v2.joblib']
# time: 7min 51s (started: 2024-05-06 02:22:03 +00:00)

# %%
from langchain.vectorstores import FAISS
import joblib
db = FAISS.from_documents(documents=char_splits, embedding=embeddings)
joblib.dump(db, '/content/drive/MyDrive/Skripsi/Db/db_1000_0_paraphrase_all-mpnet-base-v2.joblib')
# Out:
# ['/content/drive/MyDrive/Skripsi/Db/db_1000_0_paraphrase_all-mpnet-base-v2.joblib']
# time: 2min 57s (started: 2024-05-06 00:25:11 +00:00)

# %%
from langchain.vectorstores import FAISS
import joblib
db = FAISS.from_documents(documents=char_splits, embedding=embeddings)
joblib.dump(db, '/content/drive/MyDrive/Skripsi/Db/db_1000_100_paraphrase_all-mpnet-base-v2.joblib')
# Out:
# ['/content/drive/MyDrive/Skripsi/Db/db_1000_100_paraphrase_all-mpnet-base-v2.joblib']
# time: 3min 12s (started: 2024-05-06 00:37:11 +00:00)

# %%
from langchain.vectorstores import FAISS
import joblib
db = FAISS.from_documents(documents=char_splits, embedding=embeddings)
joblib.dump(db, '/content/drive/MyDrive/Skripsi/Db/db_1000_200_paraphrase_all-mpnet-base-v2.joblib')
# Out:
# ['/content/drive/MyDrive/Skripsi/Db/db_1000_200_paraphrase_all-mpnet-base-v2.joblib']
# time: 3min 25s (started: 2024-05-06 02:34:53 +00:00)

# %%
from langchain.vectorstores import FAISS
import joblib
db = FAISS.from_documents(documents=char_splits, embedding=embeddings)
joblib.dump(db, '/content/drive/MyDrive/Skripsi/Db/db_1500_0_paraphrase_all-mpnet-base-v2.joblib')
# Out:
# ['/content/drive/MyDrive/Skripsi/Db/db_1500_100_paraphrase_all-mpnet-base-v2.joblib']
# time: 2min 9s (started: 2024-05-06 00:43:09 +00:00)

# %%
from langchain.vectorstores import FAISS
import joblib
db = FAISS.from_documents(documents=char_splits, embedding=embeddings)
joblib.dump(db, '/content/drive/MyDrive/Skripsi/Db/db_1500_100_paraphrase_all-mpnet-base-v2.joblib')
# Out:
# ['/content/drive/MyDrive/Skripsi/Db/db_1500_100_paraphrase_all-mpnet-base-v2.joblib']
# time: 2min 15s (started: 2024-05-06 02:49:50 +00:00)

# %%
from langchain.vectorstores import FAISS
import joblib
db = FAISS.from_documents(documents=char_splits, embedding=embeddings)
joblib.dump(db, '/content/drive/MyDrive/Skripsi/Db/db_1500_200_paraphrase_all-mpnet-base-v2.joblib')
# Out:
# ['/content/drive/MyDrive/Skripsi/Db/db_1500_200_paraphrase_all-mpnet-base-v2.joblib']
# time: 2min 16s (started: 2024-05-06 00:53:00 +00:00)

# %% [markdown]
# #LLM Repo

# %%
from langchain.vectorstores import FAISS
import joblib
#ganti db buat eval chunk size dan overlap
loaded_db = joblib.load('/content/drive/MyDrive/Skripsi/Db/db_1000_0_paraphrase_all-mpnet-base-v2.joblib')
retriever = loaded_db.as_retriever()
# Out:
# time: 12.4 s (started: 2024-05-06 03:07:25 +00:00)

# %%
import os
from langchain.llms import HuggingFaceHub
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"
repo_id = "bigscience/bloom"
llm = HuggingFaceHub(
    repo_id=repo_id, model_kwargs={"temperature": 0.5, "max_length": 512, "return_full_text" : False}
)
# Out:
# time: 375 ms (started: 2024-05-06 02:57:12 +00:00)

# %% [markdown]
# #Load Dataset QA

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/Skripsi/QnA dataset.xlsx'
df = pd.read_excel(file_path)

questions = []
answers = []
current_answers = []

for index, row in df.iterrows():
    question = row['Pertanyaan']
    answer = row['Jawaban']

    if pd.notna(question):
        if current_answers:
            answers.append(current_answers)
        current_answers = [answer]
        questions.append(question)
    else:
        current_answers.append(answer)

if current_answers:
    answers.append(current_answers)
# Out:
# time: 1.48 s (started: 2024-05-06 00:28:40 +00:00)

# %%
questions
# Out:
# ['Apa itu stunting?',
#  'Apa penyebab stunting',
#  'Bagaimana cara mencegah stunting?',
#  'Pendampingan keluarga adalah',
#  'Jelaskan mengenai Pengembangan Anak Usia Dini Holistik Integratif!',
#  'Sebutkan jenis intervensi gizi!',
#  'Apa kepanjangan dari RPJPN?',
#  'Apa itu Gerakan Scaling Up Nutrition (SUN)?',
#  'Mengatur tentang apa Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023?',
#  'Apa kepanjangan Elsimil?',
#  'Bagaimana data SGGI diperoleh?',
#  'Kapan diperingati Hari Gizi Nasional setiap tahunnya?',
#  'Berapa target prevalensi stunting World Health Assembly?',
#  'RPJPN itu untuk periode berapa tahun?',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak berapa Kabupaten/Kota?']
# time: 3.67 ms (started: 2024-05-05 07:10:54 +00:00)

# %%
answers
# Out:
# [['Stunting menurut Peraturan Presiden Nomor 72 Tahun 2021 tentang Percepatan Penurunan Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang atau tinggi badannya berada di bawah standar yang ditetapkan oleh menteri yang menyelenggarakan urusan pemerintahan di bidang kesehatan',
#   'Menurut UNICEF, stunting didefinisikan sebagai persentase anak-anak usia 0 sampai 59 bulan, dengan tinggi di bawah minus dua (stunting sedang dan berat) dan minus tiga (stunting kronis) diukur dari standar pertumbuhan anak keluaran WHO',
#   'Menurut WHO, stunting adalah gangguan tumbuh kembang yang dialami anak akibat gizi buruk, infeksi berulang, dan didefinisikan terhambat gizinya jika tinggi badan mereka terhadap usia lebih dari dua deviasi standar di bawah median standar pertumbuhan anak WHO',
#   'Menurut para ahli, stunting adalah kondisi gagal tumbuh pada anak akibat dari kekurangan gizi kronis sehingga anak terlalu pendek untuk usianya',
#   'Stunting adalah kondisi gagal tumbuh pada anak balita akibat kekurangan gizi kronis terutama pada 1.000 Hari Pertama Kehidupan (HPK)',
#   'Stunting adalah kondisi gagal tumbuh pada anak usia di bawah lima tahun (balita) akibat kekurangan gizi kronis, infeksi berulang, dan stimulasi psikososial yang tidak memadai terutama dalam 1.000 Hari Pertama Kehidupan (HPK)'],
#  ['Stunting disebabkan karena seseorang tidak mendapatkan asupan bergizi dalam jumlah yang tepat pada jangka waktu yang lama (kronik)',
#   'Stunting terjadi sebagai akibat dampak kumulatif asupan makanan tidak memadai dan kondisi kesehatan yang buruk hasil dari kemiskinan endemik',
#   'Stunting disebabkan oleh faktor rumah tangga (keadaan rumah, rendahnya kualitas pangan, keamanan pangan dan air, kondisi ibu, pengasuhan yang tidak cukup, ketidakcukupan ASI, ketidakcukupan keadaan makanan masyarakat atau negara (keadaan politik dan ekonomi, air, lingkungan, pertanian, pendidikan, sosial dan budaya)',
#   'Stunting disebabkan berbagai macam faktor, satu diantaranya adalah praktik pengasuhan orangtua dan anggota keluarga yang tidak baik dan benar terhadap balita dan anak'],
#  ['Stunting sebenarnya dapat dicegah dengan asupan gizi yang memadai, terutama pada 1000 Hari Pertama Kehidupan.',
#   'Melalui peningkatan pengetahuan gizi pada masyarakat yang dibina oleh petugas kesehatan dimaksud.',
#   'Pendekatan gizi yang terpadu atau konvergen sangat penting dilakukan untuk mencegah stunting dan masalah gizi',
#   'Pendampingan keluarga adalah serangkaian kegiatan yang meliputi penyuluhan, fasilitasi pelayanan rujukan, dan fasilitasi pemberian bantuan sosial yang bertujuan untuk meningkatkan akses informasi dan pelayanan kepada keluarga dan/atau keluarga berisiko stunting seperti ibu hamil, ibu pasca persalinan, anak usia 0-59 bulan, serta calon pengantin/ calon pasangan usia subur melalui pendampingan 3 bulan pranikah sebagai bagian dari pelayanan nikah untuk deteksi dini faktor risiko stunting dan melakukan upaya pencegahan pengaruh dari faktor risiko stunting.'],
#  ['Secara konsep, pendampingan keluarga adalah serangkaian kegiatan yang dilakukan terhadap keluarga yang memiliki ibu hamil, ibu pascapersalinan, anak usia dibawah 5 tahun (balita), serta calon pengantin/calon pasangan usia subur untuk deteksi dini faktor risiko Stunting dan melakukan upaya meminimalisir atau pencegahan dari faktor risiko Stunting.'],
#  ['Pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi.',
#   'Pengembangan Anak Usia Dini Holistik Integratif (PAUD HI) direncanakan secara sistematis dan diterapkan secara sistemik di Satuan PAUD (TK/KB/TPA/SPS) untuk mengoptimalkan potensi tumbuh kembang anak secara optimal agar kelak menjadi anak yang berkualitas dan berdaya saing di masa depan'],
#  ['Intervensi gizi spesifik dan sensitif'],
#  ['Rencana Pembangunan Jangka Panjang Nasional'],
#  ['Gerakan Scaling Up Nutrition (SUN) merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor'],
#  ['Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023'],
#  ['Elektronik Siap Nikah dan Hamil'],
#  ['Data SSGI 2021 diambil pada 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas)'],
#  ['Tanggal 25 Januari diperingati sebagai Hari Gizi Nasional (HGN) setiap tahunnya',
#   '25 Januari'],
#  ['Target prevalensi stunting World Health Assembly (WHA) yaitu menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#   40,
#   '40 persen'],
#  ['RPJPN merupakan dokumen perencanaan pembangunan nasional untuk periode 20 tahun',
#   20,
#   '20 tahun'],
#  [260,
#   'Berdasarkan surat menteri PPN pada tanggal 29 April 2019, Lokus stunting untuk tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota',
#   '260 Kabupaten/Kota']]
# time: 11.7 ms (started: 2024-05-05 07:11:20 +00:00)

# %% [markdown]
# # Retrieval-based QA

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", "timpal0l/mdeberta-v3-base-squad2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/879 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# time: 19.9 s (started: 2024-03-02 00:38:48 +00:00)

# %% [markdown]
# ## 500 0

# %%
candidate = []
retrieved_docs_list = []

for question in questions:
    retrieved_docs = retriever.get_relevant_documents(question)
    retrieved_docs_string = "\n".join([doc.page_content for doc in retrieved_docs])
    context = retrieved_docs_string
    retrieved_docs_list. append(context)

    response = qa_model(question, context)
    answer = response.get('answer', '').strip()

    candidate.append(answer)

candidate
# Out:
# ['percepatan penurunan',
#  'Pengertian Stunting',
#  'upaya percepatan penurunan',
#  'layanan PAUD HI idealnya dilaksanakan terpusat,',
#  'Peraturan Presiden Republik Indonesia Nomor 60 Tahun Tahun 2013',
#  'intervensi spesifik dan intervensi sensitif.',
#  'Kegiatan Prioritas\nRencana Pembangunan Jangka Panjang Nasional',
#  'upaya terpadu untuk mengatasi semua bentuk malnutrisi',
#  'PDTUNJUK TEKNIS',
#  'KATA PENGANTAR\nKATA PENGANTAR',
#  'Kantor\n\nKode Pos\n\nTelepon\n\nFax\n\nEmail',
#  'Januari 26, 2022',
#  '22 persen pada tahun 2025',
#  '2005-2025.',
#  '260']
# time: 40.7 s (started: 2024-03-02 00:44:45 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.03425633446247062,
#  'precisions': [0.34782608695652173,
#   0.2777777777777778,
#   0.275,
#   0.27586206896551724],
#  'brevity_penalty': 0.11707652054258598,
#  'length_ratio': 0.31797235023041476,
#  'translation_length': 69,
#  'reference_length': 217}
# time: 942 ms (started: 2024-03-02 00:45:33 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.29132639617111666,
#  'rouge2': 0.1300163666121113,
#  'rougeL': 0.29293386392765275,
#  'rougeLsum': 0.28801322900701787}
# time: 629 ms (started: 2024-03-02 00:45:36 +00:00)

# %% [markdown]
# ## 500 100

# %%
candidate = []
retrieved_docs_list = []

for question in questions:
    retrieved_docs = retriever.get_relevant_documents(question)
    retrieved_docs_string = "\n".join([doc.page_content for doc in retrieved_docs])
    context = retrieved_docs_string
    retrieved_docs_list. append(context)

    response = qa_model(question, context)
    answer = response.get('answer', '').strip()

    candidate.append(answer)

candidate
# Out:
# ['gangguan tumbuh kembang',
#  'pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan',
#  'stunting\n\ngizi\n\nspesifik\n\ndan\n3. Intervensi Pencegahan Stunting',
#  'semuanya\t berpusat\t pada\t keluarga.',
#  'Peraturan Presiden Republik Indonesia Nomor 60 Tahun Tahun 2013',
#  'Penyediaan Makanan Tambahan bagi Balita Kurus',
#  'Kegiatan Prioritas\nRencana Pembangunan Jangka Panjang Nasional',
#  'merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi',
#  'PDTUNJUK TEKNIS',
#  'KATA PENGANTAR',
#  'TABEL KUALITAS DATA',
#  'Januari 25, 2022',
#  '22 persen pada tahun 2025',
#  '2005-2025.',
#  '260']
# time: 46.8 s (started: 2024-03-02 00:42:35 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.049305333809178044,
#  'precisions': [0.4230769230769231,
#   0.2698412698412698,
#   0.2653061224489796,
#   0.24324324324324326],
#  'brevity_penalty': 0.16829257741573317,
#  'length_ratio': 0.35944700460829493,
#  'translation_length': 78,
#  'reference_length': 217}
# time: 914 ms (started: 2024-03-02 00:43:27 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.30027522945937263,
#  'rouge2': 0.12004907373328426,
#  'rougeL': 0.2596701136317504,
#  'rougeLsum': 0.26793179511593834}
# time: 887 ms (started: 2024-03-02 00:43:34 +00:00)

# %% [markdown]
# ## 500 200

# %%
candidate = []
retrieved_docs_list = []

for question in questions:
    retrieved_docs = retriever.get_relevant_documents(question)
    retrieved_docs_string = "\n".join([doc.page_content for doc in retrieved_docs])
    context = retrieved_docs_string
    retrieved_docs_list. append(context)

    response = qa_model(question, context)
    answer = response.get('answer', '').strip()

    candidate.append(answer)
# Out:
# time: 1min 1s (started: 2024-03-02 00:39:12 +00:00)

# %%
candidate
# Out:
# ['Stunting merujuk pada kondisi gagal tumbuh pada anak',
#  'pola asuh yang salah',
#  'stunting\n\ngizi\n\nspesifik',
#  'Satuan PAUD.',
#  'Peraturan Presiden Republik Indonesia Nomor 60 Tahun Tahun 2013',
#  'intervensi spesifik dan intervensi sensitif.',
#  'Kegiatan Prioritas\nRencana Pembangunan Jangka Panjang Nasional',
#  'merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi',
#  'PDTUNJUK TEKNIS',
#  'KATA PENGANTAR',
#  'Normalisasi indikator adalah proses penyekalaan nilai',
#  'Januari 25, 2022',
#  '40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#  '(lima',
#  '260']
# time: 7.36 ms (started: 2024-03-02 00:40:33 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.07340740246501164,
#  'precisions': [0.5394736842105263,
#   0.4262295081967213,
#   0.44680851063829785,
#   0.4722222222222222],
#  'brevity_penalty': 0.15641177626480543,
#  'length_ratio': 0.35023041474654376,
#  'translation_length': 76,
#  'reference_length': 217}
# time: 1.17 s (started: 2024-03-02 00:40:50 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.38806694394929686,
#  'rouge2': 0.17043706293706296,
#  'rougeL': 0.35072800837506724,
#  'rougeLsum': 0.34700874289109584}
# time: 918 ms (started: 2024-03-02 00:41:02 +00:00)

# %% [markdown]
# ## 1000 0

# %%
candidate = []
retrieved_docs_list = []

for question in questions:
    retrieved_docs = retriever.get_relevant_documents(question)
    retrieved_docs_string = "\n".join([doc.page_content for doc in retrieved_docs])
    context = retrieved_docs_string
    retrieved_docs_list. append(context)

    response = qa_model(question, context)
    answer = response.get('answer', '').strip()

    candidate.append(answer)

candidate
# Out:
# ['percepatan penurunan stunting.\n1. Pengertian Stunting',
#  'pola asuh yang salah',
#  'Fokus pada masa 1000 HPK',
#  'untuk deteksi dini faktor risiko Stunting',
#  'Peraturan Presiden Republik Indonesia Nomor 60 Tahun Tahun 2013',
#  'intervensi sensitif',
#  'RPJMN\n\nRKP',
#  'gerakan global',
#  '2023',
#  'PEMUTAXIIRAN',
#  'independen',
#  'Januari 26, 2022',
#  '22 persen pada tahun 2025',
#  '2025-2029).',
#  '260']
# time: 1min 7s (started: 2024-03-02 00:47:04 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.014325492020074519,
#  'precisions': [0.35714285714285715,
#   0.21951219512195122,
#   0.23333333333333334,
#   0.22727272727272727],
#  'brevity_penalty': 0.05641613950377735,
#  'length_ratio': 0.25806451612903225,
#  'translation_length': 56,
#  'reference_length': 217}
# time: 886 ms (started: 2024-03-02 00:48:35 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.22071262071262074,
#  'rouge2': 0.03907491201608849,
#  'rougeL': 0.21601139601139602,
#  'rougeLsum': 0.21392829392829393}
# time: 655 ms (started: 2024-03-02 00:48:38 +00:00)

# %% [markdown]
# ## 1000 100

# %%
candidate = []
retrieved_docs_list = []

for question in questions:
    retrieved_docs = retriever.get_relevant_documents(question)
    retrieved_docs_string = "\n".join([doc.page_content for doc in retrieved_docs])
    context = retrieved_docs_string
    retrieved_docs_list. append(context)

    response = qa_model(question, context)
    answer = response.get('answer', '').strip()

    candidate.append(answer)

candidate
# Out:
# ['kondisi gagal tumbuh pada anak',
#  'pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan',
#  'Fokus pada masa 1000 HPK',
#  'bidan',
#  'Peraturan Presiden Republik Indonesia Nomor 60 Tahun Tahun 2013',
#  'Intervensi gizi spesifik',
#  'RPJMN',
#  'merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi',
#  '2023',
#  'PEMUTAXIIRAN',
#  'independen',
#  'Januari 25, 2022',
#  '22 persen',
#  '2005- 2025',
#  '260']
# time: 1min 56s (started: 2024-03-02 00:50:02 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.018770556452603615,
#  'precisions': [0.4727272727272727,
#   0.35,
#   0.3225806451612903,
#   0.30434782608695654],
#  'brevity_penalty': 0.05257815522235845,
#  'length_ratio': 0.2534562211981567,
#  'translation_length': 55,
#  'reference_length': 217}
# time: 1.08 s (started: 2024-03-02 00:52:04 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.31626984126984126,
#  'rouge2': 0.11207729468599033,
#  'rougeL': 0.283968253968254,
#  'rougeLsum': 0.28174603174603174}
# time: 616 ms (started: 2024-03-02 00:52:07 +00:00)

# %% [markdown]
# ## 1000 200

# %%
candidate = []
retrieved_docs_list = []

for question in questions:
    retrieved_docs = retriever.get_relevant_documents(question)
    retrieved_docs_string = "\n".join([doc.page_content for doc in retrieved_docs])
    context = retrieved_docs_string
    retrieved_docs_list. append(context)

    response = qa_model(question, context)
    answer = response.get('answer', '').strip()

    candidate.append(answer)

candidate
# Out:
# ['suatu sindrom',
#  'tumbuh\n\nkecil, pendek, kurus',
#  'Fokus pada masa 1000 HPK',
#  'fokus pada masa inkubasi Stunting,',
#  'Peraturan Presiden Republik Indonesia Nomor 60 Tahun Tahun 2013',
#  'Intervensi Gizi Sensitif',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'SUN Movement Joint-Assessment Report',
#  '2023',
#  'tr:tf;:Et. ; En',
#  'diambil pada 514 kabupaten/kota se-Indonesia',
#  '25 Januari',
#  '22 persen pada tahun 2025',
#  '2005-2025',
#  '100']
# time: 1min 24s (started: 2024-03-02 00:52:53 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.03427728754449639,
#  'precisions': [0.4117647058823529,
#   0.2830188679245283,
#   0.275,
#   0.27586206896551724],
#  'brevity_penalty': 0.11178515927492272,
#  'length_ratio': 0.31336405529953915,
#  'translation_length': 68,
#  'reference_length': 217}
# time: 1.04 s (started: 2024-03-02 00:54:36 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.26356233721558797,
#  'rouge2': 0.1982905982905983,
#  'rougeL': 0.257297410192147,
#  'rougeLsum': 0.2653506314806624}
# time: 657 ms (started: 2024-03-02 00:54:39 +00:00)

# %% [markdown]
# ## 1500 0

# %%
candidate = []
retrieved_docs_list = []

for question in questions:
    retrieved_docs = retriever.get_relevant_documents(question)
    retrieved_docs_string = "\n".join([doc.page_content for doc in retrieved_docs])
    context = retrieved_docs_string
    retrieved_docs_list. append(context)

    response = qa_model(question, context)
    answer = response.get('answer', '').strip()

    candidate.append(answer)

candidate
# Out:
# ['gangguan tumbuh kembang',
#  'pola asuh yang salah',
#  'Fokus pada masa 1000 HPK',
#  '35 -\n\nberisiko',
#  'Peraturan Presiden Republik Indonesia',
#  'intervensi spesifik dan intervensi sensitif.',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi',
#  '2023',
#  'destinesi den daya saing indu6tri',
#  'proses penskalaan nilai indikator',
#  '25 Januari',
#  '22 persen pada tahun 2025',
#  '2020-2024',
#  '260']
# time: 2min 20s (started: 2024-03-02 00:55:22 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.030497456938182257,
#  'precisions': [0.5517241379310345,
#   0.4418604651162791,
#   0.43333333333333335,
#   0.47368421052631576],
#  'brevity_penalty': 0.06448134573994568,
#  'length_ratio': 0.2672811059907834,
#  'translation_length': 58,
#  'reference_length': 217}
# time: 1.2 s (started: 2024-03-02 00:57:53 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.3682539682539682,
#  'rouge2': 0.21497975708502023,
#  'rougeL': 0.36168945089997717,
#  'rougeLsum': 0.36652046783625725}
# time: 828 ms (started: 2024-03-02 00:58:00 +00:00)

# %% [markdown]
# ## 1500 100

# %%
candidate = []
retrieved_docs_list = []

for question in questions:
    retrieved_docs = retriever.get_relevant_documents(question)
    retrieved_docs_string = "\n".join([doc.page_content for doc in retrieved_docs])
    context = retrieved_docs_string
    retrieved_docs_list. append(context)

    response = qa_model(question, context)
    answer = response.get('answer', '').strip()

    candidate.append(answer)

candidate
# Out:
# ['gangguan tumbuh kembang',
#  'pola asuh yang salah',
#  'Fokus pada masa 1000 HPK',
#  'Tabel 34.',
#  'Peraturan Presiden Republik Indonesia',
#  'Spesifik dan Sensitif',
#  'RAN-PASTI',
#  'merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi',
#  '2023',
#  'M-IL2',
#  'diambil pada 514 kabupaten/kota se-Indonesia',
#  '25 Januari',
#  '22 persen',
#  '2005- 2025',
#  '260']
# time: 2min 26s (started: 2024-03-02 00:58:49 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.01731645057791789,
#  'precisions': [0.6041666666666666,
#   0.5151515151515151,
#   0.5454545454545454,
#   0.6923076923076923],
#  'brevity_penalty': 0.029574779246646133,
#  'length_ratio': 0.22119815668202766,
#  'translation_length': 48,
#  'reference_length': 217}
# time: 971 ms (started: 2024-03-02 01:01:20 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.3352020202020202,
#  'rouge2': 0.18155467720685112,
#  'rougeL': 0.32629452418926097,
#  'rougeLsum': 0.33000797448165875}
# time: 677 ms (started: 2024-03-02 01:01:23 +00:00)

# %% [markdown]
# ## 1500 200

# %%
candidate = []
retrieved_docs_list = []

for question in questions:
    retrieved_docs = retriever.get_relevant_documents(question)
    retrieved_docs_string = "\n".join([doc.page_content for doc in retrieved_docs])
    context = retrieved_docs_string
    retrieved_docs_list. append(context)

    response = qa_model(question, context)
    answer = response.get('answer', '').strip()

    candidate.append(answer)

candidate
# Out:
# ['identifikasi risiko dan penyebab\n\nrisiko',
#  'identifikasi risiko dan penyebab\n\nrisiko',
#  'identifikasi risiko dan penyebab\n\nrisiko',
#  'Tabel 34.',
#  'Peraturan Presiden Republik Indonesia',
#  'masyarakat secara umum',
#  'RPJMN\n\nRKP\n\nRencana Pembangunan Jangka Panjang Nasional',
#  'gerakan global',
#  '2023',
#  'Tarset',
#  'sebagai target SKMI 2014',
#  '25 Januari',
#  '22 persen pada tahun 2025',
#  '20',
#  '260']
# time: 2min 20s (started: 2024-03-02 01:02:05 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.00959200659287496,
#  'precisions': [0.3877551020408163,
#   0.2647058823529412,
#   0.2608695652173913,
#   0.2857142857142857],
#  'brevity_penalty': 0.03243324089479551,
#  'length_ratio': 0.22580645161290322,
#  'translation_length': 49,
#  'reference_length': 217}
# time: 892 ms (started: 2024-03-02 01:04:36 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.31617237538290166,
#  'rouge2': 0.13333333333333333,
#  'rougeL': 0.3069395711500974,
#  'rougeLsum': 0.3137120579225842}
# time: 648 ms (started: 2024-03-02 01:04:39 +00:00)

# %% [markdown]
# # Retrieval QA Chain

# %%
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
prompt_template = """Use the following pieces of context to answer the question at the end.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}
Answer in Indonesian:"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)
chain_type_kwargs = {"prompt": PROMPT}
rqa_chain= RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=False,
    chain_type_kwargs=chain_type_kwargs
)
# Out:
# time: 1.91 ms (started: 2024-05-06 00:56:06 +00:00)

# %% [markdown]
# ## 500 0

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['i.',
#  'adalah',
#  'i.',
#  'i.',
#  'adalah pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan Anak Usia Dini Holistik Integratif adalah adalah adalah adalah adalah adalah adalah adalah adalah adalah adalah adalah adalah adalah adalah adalah adalah adalah a',
#  'iba sasaran lainnya',
#  'a.l',
#  'iii',
#  'Menimbang Mengingat SK No 096209',
#  'i',
#  'TABEL KUALITAS DATA ditanggapi peserta lainnya',
#  'dalam satu perilaku penting dalam mewujudkan gizi seimbang',
#  '2025',
#  'b.',
#  '260 Kabupaten/Kota']
# time: 13.6 s (started: 2024-03-01 23:59:19 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.047310596057230425,
#  'precisions': [0.0893854748603352,
#   0.06097560975609756,
#   0.05228758169934641,
#   0.0410958904109589],
#  'brevity_penalty': 0.8087297251938965,
#  'length_ratio': 0.8248847926267281,
#  'translation_length': 179,
#  'reference_length': 217}
# time: 832 ms (started: 2024-03-01 23:59:36 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.09899395140491893,
#  'rouge2': 0.07555555555555556,
#  'rougeL': 0.09395448079658605,
#  'rougeLsum': 0.09343839584936336}
# time: 910 ms (started: 2024-03-01 23:59:39 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['Stunting',
#  'adalah tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun',
#  'tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak a',
#  'keluarga berencana',
#  'kejadian kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi',
#  'gizi spesifik dan Upaya',
#  'dan tidak dapat dilakannya pembiayaar sasaran PN secara konsisten',
#  'keterlibatan multisektor',
#  'SK No 169859 A SALINAN PRESIDEN REPUBLIK INDONESIA PERATURAN PRESIDEN REPUBLIK INDONESIA NOMOR',
#  'kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepad',
#  'TABEL KUALITAS DATA ditanggapi peserta lainnya',
#  '25 Januari',
#  'angka stunting sebanyak 40 persen',
#  'adalah kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali',
#  '260 Kabupaten/Kota']
# time: 1min 7s (started: 2024-05-05 07:48:41 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.04539012399102397,
#  'precisions': [0.06666666666666667,
#   0.050505050505050504,
#   0.0395010395010395,
#   0.031914893617021274],
#  'brevity_penalty': 1.0,
#  'length_ratio': 2.3502304147465436,
#  'translation_length': 510,
#  'reference_length': 217}
# time: 915 ms (started: 2024-03-02 00:02:07 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.2883631897678409,
#  'rouge2': 0.24333333333333332,
#  'rougeL': 0.2848418112464624,
#  'rougeLsum': 0.28721431032361266}
# time: 625 ms (started: 2024-03-02 00:02:10 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['percepatan penurunan stunting',
#  'KONVERGENSI PENCEGAHAN STUNTING DI DESA',
#  'upaya percepatan penurunan stunting',
#  'tim pendamping keluarga yang dilaksanakan tiap tahun',
#  'Peraturan Presiden Republik Indonesia',
#  'Indonesia',
#  'Kegiatan Prioritas Rencana Pembangunan Jangka Panjang Nasional',
#  'upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor',
#  'Rencana Pembangunan Jangka Menengah Nasional Tahun 2020-2024',
#  'KATA PENGANTAR',
#  'TABEL KUALITAS DATA ditanggapi peserta lainnya',
#  'Tanggal 25 Januari',
#  'menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#  'RPJMN Tahun 2005–2025',
#  '260']
# time: 36.2 s (started: 2024-03-01 23:57:37 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.08863171797692333,
#  'precisions': [0.5, 0.46153846153846156, 0.4807692307692308, 0.525],
#  'brevity_penalty': 0.18041419287047078,
#  'length_ratio': 0.3686635944700461,
#  'translation_length': 80,
#  'reference_length': 217}
# time: 836 ms (started: 2024-03-01 23:58:22 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.34422448305315295,
#  'rouge2': 0.2070697167755991,
#  'rougeL': 0.33567385870368316,
#  'rougeLsum': 0.3428577727317801}
# time: 615 ms (started: 2024-03-01 23:58:25 +00:00)

# %% [markdown]
# ### Bloom

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah suatu kondisi di mana tinggi badan seseorang jauh di bawah rata-rata tinggi badan pada usianya.\nAnswer',
#  'Penyebab stunting adalah kurangnya asupan gizi pada masa 1000 HPK (Hari Pertama Kehidupan) atau kurang',
#  'Bagaimana cara mencegah stunting?\nBagaimana cara mencegah stunting?\nBagaimana cara mencegah stunting?\nBagaimana',
#  'Pendampingan Keluarga adalah\nAnswer in English: The family guidance is\nQuestion: Keluarga beresiko stunting adalah',
#  'Peraturan Presiden Republik Indonesia Nomor 60 Tahun Tahun 2013 tentang Pengembangan Anak Usia Dini Holistik Integratif,',
#  'Intervensi gizi spesifik meliputi:\n\nKegiatan pemberian ASI eksklusif\n\nKegiatan pemberian makanan pendamping ASI (',
#  'RPJPN\nAnswer in English: RPJPN\nQuestion: Apa kepanjangan dari RPJMN?',
#  'Gerakan Scaling Up Nutrition (SUN) merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan',
#  'Mengatur tentang Dana Alokasi Khusus Fisik.\nQuestion: Mengatur tentang apa Peraturan Presiden Republik Indonesia Nomor',
#  'Answer in English:\n\nAnswer in English:\n\nAnswer in English:\n\nAnswer in English:\n\nAnswer in English:',
#  'Data SGGI diperoleh melalui:\n\n1) Survei Kesehatan Ibu dan Anak (SKIA)',
#  'Tanggal 25 Januari diperingati sebagai Hari Gizi Nasional (HGN) setiap tahunnya.\nAnswer in',
#  'Target prevalensi stunting World Health Assembly (WHA) yaitu menurunkan angka stunting sebanyak 40',
#  'RPJPN itu untuk periode berapa tahun?\n\nA:\n\nRPJPN adalah Rencana Pembangunan Jangka Panjang',
#  'Berdasarkan surat menteri PPN pada tanggal 29 April 2019, Lokus stunting untuk tahun 2020 ditetapkan sebanyak 260']
# time: 1.46 s (started: 2024-03-03 02:14:56 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.3188150805582521,
#  'precisions': [0.43089430894308944,
#   0.31601731601731603,
#   0.2824074074074074,
#   0.26865671641791045],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.1336405529953917,
#  'translation_length': 246,
#  'reference_length': 217}
# time: 1.47 s (started: 2024-03-03 02:11:33 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.38489052182209704,
#  'rouge2': 0.2958165832971648,
#  'rougeL': 0.37388806093724125,
#  'rougeLsum': 0.3707807275483683}
# time: 1.06 s (started: 2024-03-03 02:11:42 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kekurangan tinggi badan pada anak yang terjadi saat masa kehamilan hingga usia 2 tahun.',
#  'Penyebab stunting dapat berasal dari faktor genetik, lingkungan dan gizi.',
#  'Mencegah stunting dapat dilakukan dengan memberikan asupan gizi yang cukup sejak kehamilan, menjaga kebersihan lingkungan, dan mengurangi resiko penyakit. Selain itu, perhatian juga harus diberikan pada pertumbuhan dan perkembangan anak dengan menggunakan upaya',
#  'Pendampingan keluarga adalah suatu proses bantuan dan arahan yang diberikan oleh pendamping kepada keluarga dalam mengatasi masalah yang dihadapi oleh keluarga tersebut, sehingga dapat mencapai tujuan yang diinginkan. Dalam hal ini, pendampingan kel',
#  'Pengembangan Anak Usia Dini Holistik Integratif (PAUD HI) adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. Layanan stimulasi holistik mencakup layanan',
#  'Intervensi gizi dapat dibedakan menjadi dua jenis, yaitu intervensi spesifik dan intervensi sensitif. Intervensi spesifik merupakan kegiatan yang langsung mengatasi penyebab terjadinya stunting, seperti asupan makanan, pencegahan infeksi, status gizi ibu, penyak',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Scaling Up Nutrition (SUN) adalah upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Ini merupakan gerakan internasional yang diluncurkan pada tahun 2010 dengan prinsip dasar bahwa semua warga negara memiliki hak untuk mendap',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang PDTUNJUK TEKNIS DANA ALOKASI KHUSUS FISIK TAHUN ANGGARAN 2023.',
#  'Elsimil merupakan kepanjangan dari E-Learning Sistem Militer',
#  'Data SSGI 2021 didapat dari survei yang dilakukan oleh Kementerian Perencanaan Pembangunan Nasional / Badan Perencanaan Pembangunan Nasional dan Kementerian Dalam Negeri. Data tersebut sangat penting dan dibutuhkan dalam pelaksanaan intervensi gizi terintegrasi di setiap tingkatan.',
#  'Hari Gizi Nasional diperingati setiap tanggal 25 Januari setiap tahunnya.',
#  'Target prevalensi stunting World Health Assembly adalah 22 persen pada tahun 2025.',
#  'RPJPN itu untuk periode tahun 2005-2025.',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota.']
# time: 34.5 s (started: 2024-03-03 02:35:11 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.26296980123518565,
#  'precisions': [0.437125748502994,
#   0.27899686520376177,
#   0.2138157894736842,
#   0.18339100346020762],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.5391705069124424,
#  'translation_length': 334,
#  'reference_length': 217}
# time: 1.57 s (started: 2024-03-03 02:36:00 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.48367995506878453,
#  'rouge2': 0.3378794716784689,
#  'rougeL': 0.4349400613855181,
#  'rougeLsum': 0.4386104884620553}
# time: 1.12 s (started: 2024-03-03 02:36:09 +00:00)

# %% [markdown]
# ## 500 100

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['0',
#  'dalah sebuah saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu saatu s',
#  'ilegal',
#  'iap tiap tahun',
#  'id',
#  '1).',
#  'iii',
#  'ii.',
#  '-23-',
#  'yang meliputi',
#  'd.',
#  'ii.',
#  '2025',
#  'b.',
#  '260 Kabupaten/Kota']
# time: 33.4 s (started: 2024-03-02 00:05:26 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.011617993416051816,
#  'precisions': [0.05384615384615385,
#   0.02608695652173913,
#   0.01904761904761905,
#   0.009900990099009901],
#  'brevity_penalty': 0.5121023512013517,
#  'length_ratio': 0.5990783410138248,
#  'translation_length': 130,
#  'reference_length': 217}
# time: 973 ms (started: 2024-03-02 00:06:10 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.07864701436130007,
#  'rouge2': 0.06666666666666667,
#  'rougeL': 0.07679516250944823,
#  'rougeLsum': 0.07581254724111867}
# time: 600 ms (started: 2024-03-02 00:06:13 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['dilakukan untuk mengidentifikasi alokasi yang seperti identifikasi alokasi tumbuhan dan perkembangan anak kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang ortingai oleh menteri yang menyelenggarai urusan pemerintahan di bidang kesehatan.',
#  'kembali tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya.',
#  'kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali',
#  'tim pendamping keluarga yang dilakukan tiap tahun',
#  'PAUD HI',
#  'gizi spesifik dan intervensi sensitif',
#  'PN dan Program Prioritas (PP) di dalam RKP selalu berubah baik jumlah maupun nomenclatumya- Padahal, merujuk pad Undang-undang Sistem Perencs.naan Pembangunan Nasional',
#  'terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor',
#  'PRESIDEN REPUBLIK INDONESIA NOMOR',
#  'kembali kembali yang meliputi',
#  'TABEL KUALITAS DATA variabel, metodologi, dan pengukuran indeks melalui kajian literatur terkait stunting serta konsultasi bersama para pakar multidisiplin',
#  '25 Januari',
#  'angka stunting sebanyak 40 persen',
#  'adalah tahun terakhir pelaksanaan RPJMN, yang hasil digunakan sebagai input dalam penyusunan RPJMN periode selanjutnya (RPJMN 2025-2029).',
#  '260 Kabupaten/Kota']
# time: 43.1 s (started: 2024-03-02 00:04:17 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.13307924988865982,
#  'precisions': [0.2491103202846975,
#   0.14661654135338345,
#   0.10756972111553785,
#   0.07983193277310924],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.294930875576037,
#  'translation_length': 281,
#  'reference_length': 217}
# time: 932 ms (started: 2024-03-02 00:05:03 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.3782046486054458,
#  'rouge2': 0.27567357904953815,
#  'rougeL': 0.3515310601238638,
#  'rougeLsum': 0.35579394840683065}
# time: 890 ms (started: 2024-03-02 00:05:07 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang',
#  'Stunting adalah suatu sindrom di mana berfungsi gangguan kegagalan sebagai pertumbuhan linier penanda beberapa dilakukan untuk mengidentifikasi alokasi yang secara riil mendukung percepatan penurunan stunting',
#  'Identifikasi data pada level sub-komponen dan detilnya dilakukan dengan Cegah Stunting BKKBN Perkenalkan Aplikasi ELSIMIL untuk Cegah Stunting Cegah Stunting',
#  'tim pendamping keluarga yang dilaksanakan tiap tahun',
#  'Peraturan Presiden Republik Indonesia',
#  'yang terdiri',
#  'Kegiatan Prioritas Rencana Pembangunan Jangka Panjang Nasional',
#  'upaya terpadu untuk mengatasi semua bentuk malnutrisi',
#  'TENTANG PDTUNJUK TEKNIS DANA ALOKASI KHUSUS FISIK',
#  'KATA PENGANTAR i KATA PENGANTAR KATA PENGANTAR yelp',
#  'TABEL KUALITAS DATA variabel, metodologi, dan pengukuran indeks melalui kajian literatur terkait stunting serta konsultasi bersama para pakar multidisiplin',
#  'Peringatan ini awalnya ditujukan untuk memperingati berdirinya Sekolah Juru Penerang Makanan yang merupakan cikal bakal pendidikan tenaga gizi Indonesia',
#  'menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#  'RPJMN 2025-2029',
#  '260']
# time: 40.8 s (started: 2024-05-05 08:07:54 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.18153540378941338,
#  'precisions': [0.33962264150943394,
#   0.25,
#   0.23846153846153847,
#   0.23076923076923078],
#  'brevity_penalty': 0.6943494782815145,
#  'length_ratio': 0.7327188940092166,
#  'translation_length': 159,
#  'reference_length': 217}
# time: 1.41 s (started: 2024-03-02 00:08:19 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.3266130860380523,
#  'rouge2': 0.20817435746228316,
#  'rougeL': 0.3165531783903038,
#  'rougeLsum': 0.31885716196993}
# time: 650 ms (started: 2024-03-02 00:08:22 +00:00)

# %% [markdown]
# ### Bloom

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan',
#  'Stunting terjadi karena pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK',
#  'Cara mencegah stunting adalah dengan melakukan intervensi spesifik di tingkat rumah tangga dan masyarakat untuk mencegah terjadinya st',
#  'Keluarga berencana\nAnswer in English: Family planning\n\nBAB IV\n\nUpaya Pencapaian Gizi Se',
#  'Pengembangan Anak Usia Dini Holistik Integratif (PAUD HI) adalah upaya pengembangan anak usia dini yang',
#  'Intervensi gizi sensitif yang dipilih yaitu\n\n1. Pemberian Makanan Tambahan\n\n2. Pemberian Makanan',
#  'RPJPN\nAnswer in English: RPJPN\nHope this helps~',
#  'Gerakan Scaling Up Nutrition (SUN) merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang petunjuk teknis dana alokasi khusus fisik tahun anggaran 2023',
#  'Elsimil adalah kepanjangan dari Electronic Simulator\n\nA:\n\nThe answer is Electronic Simulator.',
#  'Data SGGI diperoleh melalui pengumpulan data\n\nyang dilakukan oleh SAL Kabupaten/Kota dengan melakukan kunjungan rumah tangga di',
#  'Tanggal 25 Januari diperingati sebagai Hari Gizi Nasional (HGN) setiap tahunnya.\nAnswer in',
#  'Target prevalensi stunting World Health Assembly yaitu menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013',
#  'RPJPN itu untuk periode berapa tahun?\nAnswer in English: RPJMN itu untuk periode berapa tahun',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota.\nAnswer in English: The number of stunting focus']
# time: 17.7 s (started: 2024-03-03 02:13:29 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.3703280399090206,
#  'precisions': [0.46938775510204084,
#   0.3739130434782609,
#   0.33488372093023255,
#   0.32],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.1290322580645162,
#  'translation_length': 245,
#  'reference_length': 217}
# time: 1.46 s (started: 2024-03-03 02:13:56 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4228034803171002,
#  'rouge2': 0.3305546038066483,
#  'rougeL': 0.41020239509616024,
#  'rougeLsum': 0.41400562949291764}
# time: 1.09 s (started: 2024-03-03 02:14:09 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang atau tinggi badannya berada di bawah standar yang ditetapkan oleh menteri yang menyelenggarakan urusan pemerintahan di bidang k',
#  'Penyebab stunting terjadi lantaran pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK).',
#  'Untuk mencegah stunting, dapat dilakukan dengan menggunakan aplikasi ELSIMIL yang dirancang oleh BKKBN. Aplikasi ini digunakan untuk mengidentifikasi alokasi yang secara riil mendukung percepatan penurunan stunting pada level sub-komponen dan detilnya.',
#  'Pendampingan keluarga adalah upaya untuk mencapai gizi seimbang melalui pemberian informasi dan pendampingan kepada keluarga yang memiliki anak dengan risiko stunting.',
#  'Pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. Layanan stimulasi holistik mencakup layanan pendidikan, k',
#  'Intervensi gizi dapat dibedakan menjadi dua jenis, yaitu intervensi spesifik dan intervensi sensitif. Intervensi spesifik merupakan kegiatan yang langsung mengatasi penyebab terjadinya stunting dan umumnya diberikan oleh sektor kesehatan. Intervensi sensitif merupakan ke',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Scaling Up Nutrition (SUN) adalah usaha terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Kerjasama antara pemerintah, organisasi masyarakat sipil, dunia usaha, mitra pembangunan dan akademisi merupakan ciri khas dari gerakan ini. Indonesia b',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang PDTUNJUK TEKNIS DANA ALOKASI KHUSUS FISIK TAHUN ANGGARAN 2023.',
#  'Eliminasi Simulasi Militer',
#  'Data SSGI 2021 diperoleh melalui pengumpulan data menggunakan metode sampel Susenas Maret 2019 dari 12 provinsi, yaitu Aceh, Sumatera Utara, Jawa Timur, Jawa Tengah, Kalimantan Selatan, Kalimantan Timur, Sulawesi Selatan, Sulawesi Tenggara,',
#  'Tanggal 25 Januari diperingati Hari Gizi Nasional setiap tahunnya.',
#  'Target prevalensi stunting World Health Assembly adalah menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025.',
#  'RPJPN itu untuk periode tahun 2005-2025.',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota.']
# time: 30.7 s (started: 2024-03-03 02:43:15 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.37871483260672095,
#  'precisions': [0.509915014164306,
#   0.3875739644970414,
#   0.33746130030959753,
#   0.30844155844155846],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.6267281105990783,
#  'translation_length': 353,
#  'reference_length': 217}
# time: 1.59 s (started: 2024-03-03 02:43:59 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.5349830235841441,
#  'rouge2': 0.42458385129270887,
#  'rougeL': 0.5155178636906381,
#  'rougeLsum': 0.5282581851704506}
# time: 1.24 s (started: 2024-03-03 02:44:06 +00:00)

# %% [markdown]
# ## 500 200

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ['dalam tahun 2021',
#  'dalam tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun t',
#  'i.',
#  'KELUARGA BERENCANA',
#  '',
#  '1).',
#  'a.l',
#  'ii.',
#  'ttd.',
#  'yang meliputi',
#  'TABEL KUALITAS DATA',
#  'ii.',
#  '20252',
#  'dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN dilakukan evaluasi RPJMN',
#  '260 Kabupaten/Kota']
# time: 31.2 s (started: 2024-05-05 07:08:43 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# {'bleu': 0.01261649500580834,
#  'precisions': [0.038461538461538464,
#   0.013636363636363636,
#   0.00966183574879227,
#   0.005],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.0783410138248848,
#  'translation_length': 234,
#  'reference_length': 217}
# time: 11.2 s (started: 2024-05-05 07:10:03 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.07733372044869372,
#  'rouge2': 0.06944444444444445,
#  'rougeL': 0.07832671636147573,
#  'rougeLsum': 0.07698163452708907}
# time: 758 ms (started: 2024-05-05 07:11:43 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['adalah tumbuhan dan perkembangan anak kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang ortingai berada di bawah standar yang ditetapkan oleh menteri yang menyelenggarai urusan pemerintahan di bidang kesehatan.',
#  'kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali',
#  'dan kejadian tidak terhadap penyakit',
#  'tim pendamping keluarga yang dilakukan tiap tahun',
#  'kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali',
#  'gizi spesifik dan intervensi sensitif.',
#  'dan tidak dapat dilakannya pembiayaar sasaran PN secara konsisten',
#  'terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor',
#  'PRESIDEN REPUBLIK INDONESIA',
#  'kembali kembali yang meliputi',
#  'TABEL KUALITAS DATA',
#  '25 Januari',
#  '40 persen',
#  'lima tahun',
#  '260 Kabupaten/Kota']
# time: 59.1 s (started: 2024-03-02 00:10:26 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.13101462317161314,
#  'precisions': [0.19112627986348124,
#   0.1474820143884892,
#   0.11406844106463879,
#   0.09163346613545817],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.3502304147465438,
#  'translation_length': 293,
#  'reference_length': 217}
# time: 876 ms (started: 2024-03-02 00:11:52 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4230259635542654,
#  'rouge2': 0.3210526315789474,
#  'rougeL': 0.4055749831621086,
#  'rougeLsum': 0.40459637439881607}
# time: 851 ms (started: 2024-03-02 00:11:55 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang',
#  'terjadi lantaran pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK)',
#  'Stunting mempengaruhi perkembangan otak sehingga tingkat kecerdasan anak tidak maksimmal',
#  'tim pendamping keluarga yang dilaksanakan tiap tahun',
#  'Peraturan Presiden Republik Indonesia',
#  'yang terdiri',
#  'Kegiatan Prioritas Rencana Pembangunan Jangka Panjang Nasional',
#  'upaya terpadu untuk mengatasi semua bentuk malnutrisi',
#  'TENTANG PDTUNJUK TEKNIS DANA ALOKASI KHUSUS FISIK TAHUN ANGGARAN 2023',
#  'KATA PENGANTAR i KATA PENGANTAR KATA PENGANTAR yelp',
#  'unanswerable',
#  'Peringatan ini awalnya ditujukan untuk memperingati berdirinya Sekolah Juru Penerang Makanan yang merupakan cikal bakal pendidikan tenaga gizi Indonesia',
#  'menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#  'RPJMN',
#  '260']
# time: 41.2 s (started: 2024-03-02 00:09:18 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.15768048534901163,
#  'precisions': [0.4166666666666667,
#   0.34285714285714286,
#   0.3333333333333333,
#   0.32926829268292684],
#  'brevity_penalty': 0.44560011453513587,
#  'length_ratio': 0.5529953917050692,
#  'translation_length': 120,
#  'reference_length': 217}
# time: 922 ms (started: 2024-03-02 00:10:03 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.32410105999996264,
#  'rouge2': 0.2236955132930365,
#  'rougeL': 0.31786111938448386,
#  'rougeLsum': 0.32218543921364007}
# time: 690 ms (started: 2024-03-02 00:10:06 +00:00)

# %% [markdown]
# ### Bloom

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan',
#  'Stunting terjadi lantaran pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK',
#  'Stunting dapat dicegah dengan memberikan asupan gizi yang baik dan seimbang sejak masa kehamilan, terutama pada 1000',
#  'Pendampingan keluarga adalah\nAnswer in English: Family accompaniment is\nBAB 8\n\nKELU',
#  'Pengembangan Anak Usia Dini Holistik Integratif (PAUD HI) adalah upaya pengembangan anak usia dini yang',
#  'Upaya penurunan stunting dilakukan melalui dua intervensi gizi, yaitu intervensi spesifik dan intervensi sensitif. Intervensi spesifik',
#  'RPJPN\nAnswer in English: RPJPN\nQuestion: Apa kepanjangan dari RPJMN?',
#  'Gerakan Scaling Up Nutrition (SUN) merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan',
#  'Mengatur tentang apa Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023?\n\nQuestion in English: What is the subject',
#  'Elsimil adalah kepanjangan dari Electronic Simulator\n\nA:\n\nThe answer is Electronic Simulator.',
#  'Data SGGI diperoleh dari berbagai sumber. Untuk data 2018, data diambil dari Susenas 2018.',
#  'Tanggal 25 Januari diperingati sebagai Hari Gizi Nasional (HGN) setiap tahunnya.\nAnswer in',
#  'Target prevalensi stunting World Health Assembly (WHA) yaitu menurunkan angka stunting sebanyak 40 persen',
#  'RPJPN itu untuk jangka waktu 25 tahun.\nQuestion: Apa saja isi dari RPJMN?\nAnswer',
#  'Berdasarkan surat menteri PPN pada tanggal 29 April 2019, Lokus stunting untuk tahun 2020 ditetapkan sebanyak 260']
# time: 13.5 s (started: 2024-03-03 02:21:20 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.4383691757619609,
#  'precisions': [0.5303643724696356,
#   0.4396551724137931,
#   0.41013824884792627,
#   0.38613861386138615],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.1382488479262673,
#  'translation_length': 247,
#  'reference_length': 217}
# time: 1.79 s (started: 2024-03-03 02:21:49 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4366534835141157,
#  'rouge2': 0.3455549227202328,
#  'rougeL': 0.4388819619925942,
#  'rougeLsum': 0.4386598363178823}
# time: 1.29 s (started: 2024-03-03 02:22:02 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang atau tinggi badannya berada di bawah standar yang ditetapkan oleh menteri yang menyelenggarakan urusan pemerintahan di bidang k',
#  'Pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK) adalah penyebab stunting.',
#  'Cara mencegah stunting adalah dengan membersihkan tangan sebelum makan, makan secara berkala dan seimbang, mengurangi kebiasaan mengkonsumsi makanan yang mengandung zat berbahaya, dan mengkonsumsi makanan yang kaya akan nutrisi. Selain itu, perlu jug',
#  'Pendampingan keluarga adalah upaya pemberian bantuan dan pendampingan kepada keluarga yang membutuhkan bantuan dalam melakukan kegiatan keluarga sesuai dengan standar yang ditetapkan. Hal ini dilakukan oleh tim pendamping keluarga yang dilaksanakan tiap tah',
#  'Pengembangan Anak Usia Dini Holistik Integratif (PAUD HI) adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. PAUD HI mencakup layanan pendidikan,',
#  'Intervensi gizi dibedakan menjadi dua, yaitu Intervensi Gizi Spesifik dan Intervensi Gizi Sensitif. Intervensi Gizi Spesifik ditujukan pada anak dalam 1.000 Hari Pertama Kehidupan dan berkontribusi pada 30 persen penurunan stunting, sambil Intervensi Gizi',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Scaling Up Nutrition (SUN) adalah usaha terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Kerjasama antara pemerintah, organisasi masyarakat sipil, dunia usaha, mitra pembangunan dan akademisi merupakan ciri khas dari gerakan ini. Indonesia b',
#  'Mengatur tentang PDTUNJUK TEKNIS DANA ALOKASI KHUSUS FISIK TAHUN ANGGARAN 2023',
#  'Eliminasi Simulasi Militer',
#  'Data SGGI diterima dari laporan analisis penurunan stunting secara statistik yang disusun oleh BPS dan Setwapres. Laporan ini menggunakan data Susenas Maret yang diperoleh sebelum penetapan PSBB terkait pandemi COVID-19 di Indonesia. Setelah data disusun, dilakukan normalisasi indikator',
#  'Tanggal 25 Januari diperingati Hari Gizi Nasional setiap tahunnya.',
#  'Target prevalensi stunting World Health Assembly adalah 22 persen pada tahun 2025.',
#  'RPJPN itu untuk periode 5 tahun.',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota.']
# time: 32 s (started: 2024-03-03 02:45:21 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.3465676235127235,
#  'precisions': [0.4742857142857143,
#   0.3522388059701492,
#   0.30625,
#   0.2819672131147541],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.6129032258064515,
#  'translation_length': 350,
#  'reference_length': 217}
# time: 1.29 s (started: 2024-03-03 02:46:10 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.5227031461700982,
#  'rouge2': 0.4066828036500043,
#  'rougeL': 0.49652298441226306,
#  'rougeLsum': 0.5074162792200767}
# time: 783 ms (started: 2024-03-03 02:46:15 +00:00)

# %% [markdown]
# ## 1000 0

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['1.',
#  'dalam tumbuh',
#  'i.',
#  '1).',
#  '-Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi -Diasi',
#  'iba tidak berbagai dilakukan melalui berbagai kegiatan diluar sektor kesehatan dan tidak khusus pada 1.000 Hari Pertama Kehidupan (HPK).',
#  'dalam Pembukaan UUD Republik Indonesia Tahun 1945 dalam bentuk visi, misi dan arah pembangunan nasional',
#  'ii.',
#  '- Djaman SK No 169857A',
#  'iii',
#  'dilakukan ole (surveyor), se data lebih ter ntukan prevale ota etahui informa penyebab ensi asi eh secara dan objektif b eh tim peneliti ehingga kualita rjamin bila as (cid:31) Ala (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum (cid:31) Pe Sum',
#  '375',
#  '20252',
#  'd).',
#  '2.1 Jumlah Kabupaten/Kota Lokus Stunting Tahun 2018-2022 (Akumulasi) Kabupaten/Kota 514 360 260 160 100 Tahun 2018 Tahun 2020 2020-2024 Lokasi (Rp Miliar)*) 68,38 Kab. Paser dan Kab. Kutai Timur 5,99 Kec. Maratua, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec. Long Apari, Kec.']
# time: 29.4 s (started: 2024-05-05 07:14:39 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0,
#  'precisions': [0.016216216216216217,
#   0.002197802197802198,
#   0.0011135857461024498,
#   0.0],
#  'brevity_penalty': 1.0,
#  'length_ratio': 4.2626728110599075,
#  'translation_length': 925,
#  'reference_length': 217}
# time: 1.2 s (started: 2024-05-05 07:15:42 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.035688262143197765,
#  'rouge2': 0.0017316017316017318,
#  'rougeL': 0.034202573095565,
#  'rougeLsum': 0.03410529126437759}
# time: 878 ms (started: 2024-05-05 07:15:53 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['RO',
#  'tumbuhan',
#  'tumbuhan pada anak (baik pertumbuhan tubuh dan otak) sehinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dal metabolisme tubuhnya.',
#  'keluarga serangkaian kegiatan yang dilakukan terhadap keluarga yang memiliki ibu hamil, ibu pascapersalinan, anak usia dibawah 5 tahun (balita), serta calon pengantin/calon pasangan usia subur untuk deteksi dini faktor risiko Stunting dan meliputi penyuluhan fasilitasi perangan rujukan, fasilitasi penerimaan program bantuan sosial serta surveilans untuk mendeteksi dini faktor risiko Stunting',
#  'kembali ke tumbuh kembang anak usia dini',
#  'terintegrasi',
#  'tahap-tahap perencanaan pembangunan nasional',
#  'untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor',
#  'dan kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembal',
#  'kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepad',
#  'independen d dilakukan ole (surveyor), se data lebih ter ntukan prevale ota etahui informa penyebab ensi asi eh secara dan objektif b eh tim peneliti ehingga kualita rjamin bila as (cid:31) Ala (cid:31) Pe Sum (cid:31) Tid sul me (cid:31) Ala (cid:31) Pe (cid:31) Tid Jed (cid:31) tig dak tersedia d it untuk mene elakukan prior atahui informasi ensi asi eh secara dan objektif b eh tim peneliti ehingga kualita rjamin bila as (cid:31) Ala (cid:31) Pe Sum (cid:31) Tid Jed (cid:31) tid sul me (cid:31) Ala (cid:31) Pe (cid:31) Tid Jed (cid:31) tid sul me (cid:31) Ala (cid:31) Pe (cid:31) Tid Jed (cid:31) tid sul me (cid:31) Ala (cid:31) Pe (cid:31) Tid Jed (cid:31) tid sul me (cid:31) Ala (cid:31) Pe (cid:31) Tid Jed (cid:31) tid sul me (cid:31) Ala (cid:31) Pe (cid:31) Tid Jed (cid:31) tid sul me (cid:31) Tid sul me (cid:31) Tid Jed (cid:31) tid sul me (cid:31) Tid sul me (cid:31) Tid Jed (cid:31) tid sul me (cid:31) Tid sul me (',
#  '25 Januari',
#  'angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025 3.',
#  'tidak ada tahun kemarin tahun kemarin',
#  'tahun 2020']
# time: 1min 11s (started: 2024-03-01 22:52:01 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.09727231787355675,
#  'precisions': [0.13043478260869565,
#   0.10222222222222223,
#   0.08597285067873303,
#   0.0781010719754977],
#  'brevity_penalty': 1.0,
#  'length_ratio': 3.1797235023041477,
#  'translation_length': 690,
#  'reference_length': 217}
# time: 1.04 s (started: 2024-03-01 22:53:19 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.2874687270458916,
#  'rouge2': 0.2168481379679588,
#  'rougeL': 0.2756218698020917,
#  'rougeLsum': 0.280853743813361}
# time: 875 ms (started: 2024-03-01 22:53:22 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['percepatan penurunan stunting',
#  'terjadi lantaran pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK)',
#  'terjadi lantaran pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK) dan hal tersebut tidak dapat lagi mengingat masa 1000 HPK merupakan periode kritis yang menjadi faktor penentu kualitas kehidupan anak kelak',
#  'Serangkaian kegiatan yang dilakukan terhadap keluarga yang memiliki ibu hamil, ibu pascapersalinan, anak usia dibawah 5 tahun (balita), serta calon pengantin/calon pasangan usia subur untuk deteksi dini faktor risiko Stunting dan meliputi penyuluhan, fasilitasi pelayanan rujukan, fasilitasi penerimaan program bantuan sosial serta surveilans untuk mendeteksi dini faktor risiko Stunting',
#  'Peraturan Presiden Republik Indonesia',
#  'terintegrasi',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'gerakan global',
#  'Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023',
#  'REIICANA',
#  'dari survei yang menyasar rumah tangga dengan anak balita',
#  'Tanggal 25 Januari',
#  'menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#  'RPJMN 2020-2024',
#  '260']
# time: 1min 37s (started: 2024-03-01 22:54:25 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.3763183768389916,
#  'precisions': [0.6011904761904762,
#   0.49673202614379086,
#   0.475177304964539,
#   0.45384615384615384],
#  'brevity_penalty': 0.7470175003104325,
#  'length_ratio': 0.7741935483870968,
#  'translation_length': 168,
#  'reference_length': 217}
# time: 1.06 s (started: 2024-03-01 22:57:26 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4095482456140351,
#  'rouge2': 0.2835894405043341,
#  'rougeL': 0.39718810916179337,
#  'rougeLsum': 0.4008075048732943}
# time: 821 ms (started: 2024-03-01 22:57:29 +00:00)

# %% [markdown]
# ### Bloom

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Apa itu stunting?\nAnswer in English: What is stunting?\n2. Penanganan Stunting\n\nPer',
#  'Stunting disebabkan oleh pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK',
#  'Cara mencegah stunting adalah dengan memberikan asupan gizi yang baik dan sesuai dengan kebutuhan anak pada masa 1000',
#  'Pendampingan keluarga adalah serangkaian kegiatan yang dilakukan terhadap keluarga yang memiliki ibu hamil, ibu pascapersal',
#  'Peraturan Presiden Republik Indonesia Nomor 60 Tahun Tahun 2013 tentang Pengembangan Anak Usia Dini Holistik Integratif,',
#  'Intervensi gizi yang dapat dilakukan untuk menurunkan stunting adalah:\nAnswer in English: Intervensi gizi yang dapat',
#  'RPJPN\nQuestion: Apa kepanjangan dari RKP?',
#  'Gerakan Scaling Up Nutrition (SUN) merupakan upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang Petunjuk Teknis Dana Alokasi Khusus Fisik',
#  'Elsimil\nAnswer in English: Elsimil\nAnswer in Bahasa Indonesia: Elsimil\nAnswer in Bahasa Melayu',
#  'Data SGGI diperoleh dari survei rumah tangga dengan anak balita yang dilakukan oleh enumerator terlatih dengan',
#  'Tanggal 25 Januari diperingati sebagai Hari Gizi Nasional (HGN) setiap tahunnya. Peringatan ini',
#  'Target prevalensi stunting World Health Assembly (WHA) yaitu menurunkan angka stunting sebanyak 40 persen',
#  'RPJPN itu untuk periode 25 tahun.\n\nQuestion: RPJMN itu untuk periode berapa tahun?\nAnswer',
#  '260\n\n260\n\n260\n\n260\n\n260\n\n260\n\n260\n\n260\n\n260\n\n260']
# time: 18.7 s (started: 2024-03-03 02:24:00 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.3403572778752235,
#  'precisions': [0.45064377682403434,
#   0.3394495412844037,
#   0.3054187192118227,
#   0.2872340425531915],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.0737327188940091,
#  'translation_length': 233,
#  'reference_length': 217}
# time: 1.16 s (started: 2024-03-03 02:24:36 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.37870339550772053,
#  'rouge2': 0.26578466639984993,
#  'rougeL': 0.363527070937779,
#  'rougeLsum': 0.3604161986900041}
# time: 828 ms (started: 2024-03-03 02:24:40 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ['Stunting adalah kekurangan tinggi badan yang terjadi pada anak-anak yang masih berusia 0-5 tahun. Ini disebabkan oleh gizi buruk dan kekurangan asupan gizi selama masa hamil, serta kekurangan asupan gizi pada anak-anak yang masih berusia',
#  'Pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK) adalah penyebab stunting.',
#  'Untuk mencegah stunting, yang perlu dilakukan adalah mengambil tindakan yang benar pada masa 1000 Hari Pertama Kehidupan (1000 HPK), yaitu dari kehamilan hingga anak berusia dua tahun. Ini meliputi asupan nutrisi yang cukup dan se',
#  'Pendampingan keluarga merupakan serangkaian kegiatan yang dilakukan terhadap keluarga yang memiliki ibu hamil, ibu pascapersalinan, anak usia dibawah 5 tahun (balita), serta calon pengantin/calon pasangan usia subur untuk deteksi dini faktor risiko Stunting dan',
#  'Pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. Layanan stimulasi holistik mencakup layanan pendidikan, k',
#  'Intervensi gizi dapat dibedakan menjadi intervensi gizi spesifik dan intervensi gizi sensitif. Intervensi gizi spesifik adalah intervensi yang secara langsung mempengaruhi pemenuhan gizi dan perkembangan janin dan anak, sedangkan intervensi gizi sensitif adalah intervensi yang secara tidak',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Scaling Up Nutrition (SUN) adalah upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Kerjasama antara pemerintah, organisasi masyarakat sipil, dunia usaha, mitra pembangunan dan akademisi merupakan ciri khas dari gerakan ini. Indonesia b',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023.',
#  'Elsimil adalah kepanjangan dari Elektronik Sistem Militer.',
#  'Data SSGI diperoleh melalui survei yang menyasar rumah tangga dengan anak balita dan dilakukan oleh enumerator terlatih yang memiliki latar belakang pendidikan gizi. Survei ini dilakukan secara tahunan sejak 2019, kecuali pada tahun 2020 kare',
#  'Hari Gizi Nasional diperingati setiap tahunnya pada tanggal 25 Januari.',
#  'Target prevalensi stunting World Health Assembly adalah 22 persen pada tahun 2025.',
#  'RPJPN adalah untuk periode 2020-2024.',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota.']
# time: 48.2 s (started: 2024-05-06 00:29:07 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# {'bleu': 0.3576834011353079,
#  'precisions': [0.5120643431635389,
#   0.3575418994413408,
#   0.3119533527696793,
#   0.2865853658536585],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.7188940092165899,
#  'translation_length': 373,
#  'reference_length': 217}
# time: 11.3 s (started: 2024-05-06 00:31:00 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.5275832234819163,
#  'rouge2': 0.4000560258446131,
#  'rougeL': 0.4846548574881909,
#  'rougeLsum': 0.48770852675067233}
# time: 992 ms (started: 2024-05-06 00:32:12 +00:00)

# %% [markdown]
# ## 1000 100

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['a. Pemantauan',
#  'dalam tumbuh, stunting menyebabkan gagal tumbuh, hambatan perkembangan kognitif dan motorik, dan tidak optimalnya ukuran fisik tubuh serta gangguan metabolisme',
#  '1.2. menunjukkan bahwa penurunan stunting memerlukan pendekatan yang menyeluruh, yang harus dimulai dari pemenuhan prasyarat pendukung',
#  '1).',
#  '- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  '-',
#  'RAN-PASTI merupakan penjabaran dari tujuan dibentuknya pemerintahan Indonesia yang tercantum dalam Pembukaan UUD Republik Indonesia Tahun 1945 dalam bentuk visi, misi dan arah pembangunan nasional',
#  'terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor',
#  'a. bahwa untuk melaksanakan ketentuan Pasal 12 ayat (71 Undang-Undang Nomor 28 Tahun 2022 tentang Anggaran Pendapatan dan Belanja Negara Tahun Anggaran 2023, perlu menetapkan Peraturan Presiden tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023',
#  'iii',
#  'Data SSGI 2021 diambil pad 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas). Pengambilan data dilakukan oleh enumerator terlatih dan memperhatikan protokol kesehatan sasaran rumah tangga dengan anak balita.',
#  '375 Tanggal 25 Januari',
#  '20252',
#  '1).',
#  'a.']
# time: 37.9 s (started: 2024-03-01 22:25:37 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.1092891298134368,
#  'precisions': [0.1461187214611872,
#   0.10874704491725769,
#   0.09975669099756691,
#   0.09],
#  'brevity_penalty': 1.0,
#  'length_ratio': 2.0184331797235022,
#  'translation_length': 438,
#  'reference_length': 217}
# time: 1.2 s (started: 2024-03-01 22:29:05 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.20358307685895832,
#  'rouge2': 0.14979066022544282,
#  'rougeL': 0.1921693403438148,
#  'rougeLsum': 0.19312972153294733}
# time: 900 ms (started: 2024-03-01 22:29:15 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kondisi gagal tumbuh pada anak balita kekurangan gizi kronis terutama pada 1.000 Hari Pertama Kehidupan (HPK)1',
#  'dalam tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dal metabolisme tubuhnya',
#  'kembali tidak tumbuh dan berkembang secara optimal',
#  'Tim Pendamping Keluarga',
#  'kembali kembali akan menjadi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi.',
#  'gizi spesifik',
#  'tujuan dibentuknya pemerintahan Indonesia yang tercantum dalam Pembukaan UUD Republik Indonesia Tahun 1945 dalam bentuk visi, misi dan arah pembangunan nasional',
#  'terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor',
#  'dan kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembal',
#  'kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepad',
#  'Data SSGI 2021',
#  '25 Januari',
#  'angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025 3.',
#  'tindak sasaran dan target Evaluasi RPJMN 2020-2024 dilakukan minimal Gambar 9.14 Waktu Pelaksanaan Evaluasi RPJMN dua kali (Gambar 9.14), yaya akan digunakan bagi evaluasi RKP dan bahan mempertahan dalam penyusunan RKP tahun berikutnya; b. evaluasi akhir RPJMN dilakukan pada tahun terakhir pelaksanaan RPJMN, yang hasilnya digunakan sebagai input dalam penyusunan RPJMN periode selanjutnya (RPJMN 2025-2029).',
#  'tahun 2020']
# time: 1min 22s (started: 2024-05-05 07:42:37 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.13773545229385817,
#  'precisions': [0.18949771689497716,
#   0.13947990543735225,
#   0.12254901960784313,
#   0.1111111111111111],
#  'brevity_penalty': 1.0,
#  'length_ratio': 2.0184331797235022,
#  'translation_length': 438,
#  'reference_length': 217}
# time: 1.3 s (started: 2024-03-01 22:24:28 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.36092435823230207,
#  'rouge2': 0.30256185038793737,
#  'rougeL': 0.352801479006843,
#  'rougeLsum': 0.35120886033012255}
# time: 1.24 s (started: 2024-03-01 22:24:32 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kondisi gagal tumbuh pada anak balita akibat kekurangan gizi kronis terutama pada 1.000 Hari Pertama Kehidupan (HPK)1.',
#  'kompleks dan multikausal',
#  'Penurunan stunting memerlukan pendekatan yang menyeluruh, yang harus dimulai dari pemenuhan prasyarat pendukung',
#  'Tim Pendamping Keluarga',
#  'Peraturan Presiden Republik Indonesia',
#  'unanswerable',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Beranda Tentang Tentang SUN',
#  'Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023',
#  'REIICANA',
#  'Data SSGI 2021 diambil pada 514 kabupaten/kota se-Indonesia',
#  'Peringatan ini awalnya ditujukan untuk memperingati berdirinya Sekolah Juru Penerang Makanan yang merupakan cikal bakal pendidikan tenaga gizi Indonesia',
#  'menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#  'RPJMN Nasional',
#  '10']
# time: 2min 12s (started: 2024-03-01 22:30:09 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.23214404329326438,
#  'precisions': [0.5701754385964912,
#   0.5555555555555556,
#   0.5747126436781609,
#   0.5921052631578947],
#  'brevity_penalty': 0.40514559934358063,
#  'length_ratio': 0.5253456221198156,
#  'translation_length': 114,
#  'reference_length': 217}
# time: 1.24 s (started: 2024-03-01 22:33:20 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.3215407619460434,
#  'rouge2': 0.2809116809116809,
#  'rougeL': 0.3209111391084617,
#  'rougeLsum': 0.32777045559733986}
# time: 843 ms (started: 2024-03-01 22:34:02 +00:00)

# %% [markdown]
# ### Bloom

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 422 Client Error: Unprocessable Entity for url: https://api-inference.huggingface.co/models/bigscience/bloom
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-26-093bc57f9841> in <cell line: 3>()
#       2
#       3 for question in questions:
# ----> 4     response = rqa_chain({"query": question})
#       5     answer = response.get('result', '').strip()
#       6     answer_start = "Answer in Indonesian:"
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     143         else:
#     144             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 145         answer = self.combine_documents_chain.run(
#     146             input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     147         )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     598
#     599         if kwargs and not args:
# --> 600             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     601                 _output_key
#     602             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     135         # Other keys are assumed to be needed for LLM prediction
#     136         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 137         output, extra_return_dict = self.combine_docs(
#     138             docs, callbacks=_run_manager.get_child(), **other_keys
#     139         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     242         inputs = self._get_inputs(docs, **kwargs)
#     243         # Call predict on the LLM.
# --> 244         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     245
#     246     async def acombine_docs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in predict(self, callbacks, **kwargs)
#     314                 completion = llm.predict(adjective="funny")
#     315         """
# --> 316         return self(kwargs, callbacks=callbacks)[self.output_key]
#     317
#     318     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     124         run_manager: Optional[CallbackManagerForChainRun] = None,
#     125     ) -> Dict[str, str]:
# --> 126         response = self.generate([inputs], run_manager=run_manager)
#     127         return self.create_outputs(response)[0]
#     128
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     136         callbacks = run_manager.get_child() if run_manager else None
#     137         if isinstance(self.llm, BaseLanguageModel):
# --> 138             return self.llm.generate_prompt(
#     139                 prompts,
#     140                 stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     631     ) -> LLMResult:
#     632         prompt_strings = [p.to_string() for p in prompts]
# --> 633         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     634
#     635     async def agenerate_prompt(
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     801                 )
#     802             ]
# --> 803             output = self._generate_helper(
#     804                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805             )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668             for run_manager in run_managers:
#     669                 run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670             raise e
#     671         flattened_outputs = output.flatten()
#     672         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     655         try:
#     656             output = (
# --> 657                 self._generate(
#     658                     prompts,
#     659                     stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#    1315         for prompt in prompts:
#    1316             text = (
# -> 1317                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1318                 if new_arg_supported
#    1319                 else self._call(prompt, stop=stop, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/llms/huggingface_hub.py in _call(self, prompt, stop, run_manager, **kwargs)
#     133         parameters = {**_model_kwargs, **kwargs}
#     134
# --> 135         response = self.client.post(
#     136             json={"inputs": prompt, "parameters": parameters}, task=self.task
#     137         )
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_client.py in post(self, json, data, model, task, stream)
#     271
#     272             try:
# --> 273                 hf_raise_for_status(response)
#     274                 return response.iter_lines() if stream else response.content
#     275             except HTTPError as error:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     369         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     370         # as well (request id and/or server error message)
# --> 371         raise HfHubHTTPError(str(e), response=response) from e
#     372
#     373
#
# HfHubHTTPError: 422 Client Error: Unprocessable Entity for url: https://api-inference.huggingface.co/models/bigscience/bloom (Request ID: 0K5eyBaaBNnaHdinH02qn)
#
# Input validation error: `inputs` must have less than 1000 tokens. Given: 1083
# Make sure 'text-generation' task is supported by the model.
# time: 8.32 s (started: 2024-05-06 00:41:39 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kondisi gagal tumbuh pada anak balita akibat kekurangan gizi kronis terutama pada 1.000 Hari Pertama Kehidupan (HPK). Kondisi gagal tumbuh pada anak balita disebabkan oleh kurangnya asupan gizi dalam waktu lama serta terjad',
#  'Stunting disebabkan oleh kekurangan gizi kronis, infeksi berulang, dan stimulasi psikososial yang tidak memadai terutama dalam 1.000 Hari Pertama Kehidupan (HPK). Penyebab stunting yang kompleks dan multikausal membutuhkan intervensi lintas sektor yang terintegrasi',
#  'Stunting dapat dicegah dengan mengimplementasikan formulasi kebijakan dan strategi yang tepat, salah satunya adalah dengan melakukan audit kasus stunting. Audit kasus stunting dilakukan melalui empat kegiatan, yaitu pembentukan tim audit, pelaksanaan audit kasus stunting dan program dan ke',
#  'Pendampingan keluarga adalah upaya mendukung keluarga dalam mengatasi persoalan kesehatan, gizi, keluarga berencana, dan lingkungan. Dalam melakukan pendampingan, tenaga kesehatan seperti bidan dan kader penggerak bekerja sama dengan keluarga untuk menc',
#  'Pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. Layanan stimulasi holistik mencakup layanan pendidikan, k',
#  'Intervensi gizi dapat dibedakan menjadi gizi spesifik dan gizi sensitif. Intervensi gizi spesifik langsung mengatasi terjadinya stunting dengan cara meningkatkan asupan makanan, konseling ASI, makanan pendamping ASI dan makanan selama kehamilan, pemberian vitamin dan',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Scaling Up Nutrition (SUN) adalah upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Kerjasama antara pemerintah, organisasi masyarakat sipil, dunia usaha, mitra pembangunan dan akademisi merupakan ciri khas dari gerakan ini. Indonesia b',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023.',
#  'Elsimil adalah kepanjangan dari Elang Similir.',
#  'Data SGGI 2021 diambil pada 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas). Pengambilan data dilakuk',
#  'Hari Gizi Nasional diperingati setiap 25 Januari setiap tahunnya.',
#  'Target prevalensi stunting World Health Assembly adalah 22 persen pada tahun 2025.',
#  'RPJPN itu untuk periode 20 (dua puluh) tahun.',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota.']
# time: 34.4 s (started: 2024-03-03 02:50:26 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.3732829126575777,
#  'precisions': [0.5116279069767442,
#   0.3817204301075269,
#   0.3333333333333333,
#   0.2982456140350877],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.7834101382488479,
#  'translation_length': 387,
#  'reference_length': 217}
# time: 1.79 s (started: 2024-03-03 02:51:25 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.5599371837107686,
#  'rouge2': 0.4526136720842604,
#  'rougeL': 0.5272960791828716,
#  'rougeLsum': 0.5306838025705951}
# time: 1.23 s (started: 2024-03-03 02:51:29 +00:00)

# %% [markdown]
# ## 1000 200

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['i.',
#  '',
#  'a.',
#  'ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan ibu dan',
#  '-',
#  'b).',
#  'dalam Pembukaan UUD Republik Indonesia Tahun 1945 dalam bentuk visi, misi dan arah pembangunan nasional',
#  'iii',
#  '71 Undang-Undang Nomor 28 Tahun 2022 tentang Anggaran Pendapatan dan Belanja Negara Republik Indonesia Tahun 2023',
#  'aot9rr 2O2O**l',
#  'SSGI 2021 diambil pad 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas). Pengambilan data dilakukan oleh enumerator terlatih dan memperhatikan protokol kesehatan sasaran rumah tangga dengan anak balita.',
#  '375 Tanggal 25 Januari',
#  '20252',
#  'a.',
#  '2.1 Jumlah Kabupaten/Kota Lokus Stunting Tahun 2018-2022 (Akumulasi) Kabupaten/Kota 514 360 260 160 100 Tahun 2018 Tahun 2020 Tahun 2021 Tahun 2022 7 2.2 Pelaksanaan kegiatan yang mendukung percepatan stunting tahun 2020']
# time: 49.2 s (started: 2024-03-01 22:43:41 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.09661954331633943,
#  'precisions': [0.14492753623188406,
#   0.09667673716012085,
#   0.084375,
#   0.07371794871794872],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.5898617511520738,
#  'translation_length': 345,
#  'reference_length': 217}
# time: 1.44 s (started: 2024-03-01 22:45:16 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.14151212895817214,
#  'rouge2': 0.08148148148148149,
#  'rougeL': 0.13381786878189755,
#  'rougeLsum': 0.13695752688558444}
# time: 963 ms (started: 2024-03-01 22:45:25 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dal metabolisme tubuhnya.',
#  'kembali tumbuhan kegagalan',
#  'dalam kelompok ibu dan anak berusia 0-23 bulan or rumah tangga 1.000 HPK',
#  'kelompok dilakukan',
#  'kembali kembali kembali akan mengadili kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi.',
#  'gizi spesifik (langsung) dan gizi sensitif (tidak langsung).',
#  'tujuan dibentuknya pemerintahan Indonesia yang tercantum dalam Pembukaan UUD Republik Indonesia Tahun 1945 dalam bentuknya visi, misi dan arah pembangunan nasional',
#  'terkait hasil implementasi gerakan nasional percepat perbaikan gizi di Indonesia hingga tahun 2019.',
#  'dana kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kem',
#  'kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali',
#  'Data SSGI 2021',
#  '25 Januari',
#  'angka stunting sebanyak 40 persen',
#  '2005-2025',
#  'tahun 2020']
# time: 1min 28s (started: 2024-05-05 07:45:21 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.07934857501848873,
#  'precisions': [0.15204678362573099,
#   0.0856269113149847,
#   0.060897435897435896,
#   0.05],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.576036866359447,
#  'translation_length': 342,
#  'reference_length': 217}
# time: 1.43 s (started: 2024-03-01 22:42:55 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.24948026383079902,
#  'rouge2': 0.15407850434166223,
#  'rougeL': 0.24151156576030341,
#  'rougeLsum': 0.24239446883970212}
# time: 838 ms (started: 2024-03-01 22:42:59 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan tumbuh kembang yang dialami anak akibat gizi buruk, infeksi berulang, dan didefinitikan terhambat gizinya if tinggi badan merek terhadap usia lebih dari dua deviasi standar di bawah median standar pertumbuhan anak WHO',
#  'kekurangan gizi',
#  'Stunting menyebabkan organ tubuh tidak tumbuh dan berkembang secara optimal',
#  'Pendampingan oleh tim pendamping keluarga',
#  'Peraturan Presiden Republik Indonesia',
#  'Intervensi gizi spesifik',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Unduh Global Nutrition Report 2018',
#  'Petunjuk Teknis Dana Alokasi Khusus Fisik',
#  'Aspek Kewilayahan',
#  'pada 514 kabupaten/kota se-Indonesia',
#  'Peringatan ini awalnya ditujukan untuk memperingati berdirinya Sekolah Juru Penerang Makanan yang merupakan cikal bakal pendidikan tenaga gizi Indonesia',
#  'Menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#  'RPJMN 2020-2024',
#  '10']
# time: 2min 31s (started: 2024-03-01 22:37:23 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.24486772780878321,
#  'precisions': [0.5819672131147541,
#   0.5327102803738317,
#   0.5161290322580645,
#   0.5061728395061729],
#  'brevity_penalty': 0.4590075939109434,
#  'length_ratio': 0.5622119815668203,
#  'translation_length': 122,
#  'reference_length': 217}
# time: 1.16 s (started: 2024-03-01 22:40:13 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.3274339558488165,
#  'rouge2': 0.28485958485958485,
#  'rougeL': 0.32059831879646117,
#  'rougeLsum': 0.32637217447434164}
# time: 836 ms (started: 2024-03-01 22:40:36 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kondisi gagal tumbuh pada anak, baik pertumbuhan tubuh maupun otak, yang menyebabkan tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya. Stunting',
#  'Penyebab stunting adalah pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK), yang tidak dapat lagi diperbaiki karena masa 1000 HPK merupakan periode kritis yang menjadi faktor penentu kualitas kehidupan anak kel',
#  'Cara mencegah stunting meliputi:\n\na. Memastikan pencegahan stunting menjadi prioritas pemerintah dan masyarakat di semua tingkatan.\nb. Meningkatkan kesadaran publik dan perubahan perilaku terkait stunting.\nc. Memperhatikan keberhasilan negara-negara lain dalam p',
#  'Pendampingan keluarga adalah upaya mengasuh keluarga dalam mengatasi masalah stunting dengan fokus pada masa inkubasi stunting dan melalui kegiatan fasilitasi penyuluhan/sosialisasi dan komunikasi perubahan perilaku, fasilitasi pelayanan dan rujukan kesehatan,',
#  'Pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. Layanan stimulasi holistik mencakup layanan pendidikan, k',
#  'Intervensi gizi dapat dibagi menjadi dua jenis, yaitu intervensi gizi spesifik dan intervensi gizi sensitif. Intervensi gizi spesifik digunakan untuk menangani penyebab-penyebab langsung terjadinya kurang gizi, sedangkan intervensi gizi sensitif digunakan untuk mencegah',
#  'RPJPN berarti Rencana Pembangunan Jangka Panjang Nasional.',
#  'Gerakan Scaling Up Nutrition (SUN) adalah gerakan nasional percepatan perbaikan gizi yang telah dilakukan oleh Indonesia. Gerakan ini menunjukkan peningkatan komitmen terhadap perbaikan gizi dan terintegrasi dengan strategi nasional percepatan penurunan stunting terintegrasi dan pelibatan lintas sektor',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023.',
#  'Elsimil adalah Eliminasi Sampah Ilegal Menuju Lingkungan Bersih.',
#  'Data SSGI 2021 diambil pada 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas). Pengambilan data dilakukan',
#  'Tanggal 25 Januari diperingati Hari Gizi Nasional setiap tahunnya.',
#  'Target prevalensi stunting World Health Assembly adalah 22 persen pada tahun 2025.',
#  'RPJPN itu untuk periode 20 tahun.',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 24 Kabupaten/Kota.']
# time: 36.7 s (started: 2024-03-03 02:52:11 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.3258375517572847,
#  'precisions': [0.4854111405835544,
#   0.3370165745856354,
#   0.2824207492795389,
#   0.24397590361445784],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.737327188940092,
#  'translation_length': 377,
#  'reference_length': 217}
# time: 1.36 s (started: 2024-03-03 02:53:01 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.5087737000944548,
#  'rouge2': 0.39826164488057064,
#  'rougeL': 0.48577421963563794,
#  'rougeLsum': 0.4864850040077757}
# time: 1.14 s (started: 2024-03-03 02:53:05 +00:00)

# %% [markdown]
# ## 1500 0

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['0 sampai 59 bulan',
#  '',
#  '1).',
#  'i.',
#  'ilegal',
#  'imunisasi',
#  'ii.',
#  'terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor',
#  '- Djaman SK No 169857A',
#  'pnas (diolah), 2019',
#  '3.3 Normalisasi Indikator Langkah selanjutnya yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional yang diasional',
#  'i.',
#  '20252',
#  'a. Satu Data Indonesia b. Sistem Pemerintahan Berbasis Elektronik (SPBE), c. Data dan Informasi khusus, meliputi: ii. Data dan informasi dari Badan Pemeriksa Kaidah Pelaksanaan Daerah; serta iii. Hasil Survei dan Penelitian Tematik (Domestik dan Internasional). Terdapat 4 (empat) pilar dari RPJMN ke IV tahun 2020-2024 yang hasilnya digunai bahan masukan evaluasi RPJMN adalah 2020-2024 adalah evaluasi Rencana Strategis Kementerian/Lembaga (Renstra K/L) dan data informasi lainnya yang terintegrasi, terpadu, dan handal antara lain: a. Satu Data Indonesia b. Sistem Pemerintahan Berbasis Elektronik (SPBE), c. Data dan Informasi dari Badan Pemeriksa Kaidah Pelaksanaan Daerah; serta iii. Hasil Survei dan Penelitian Tematik (Domestik dan Internasional). Terdapat 4 (empat) pilar dari RPJMN kevuan yang didalamnya digun evaluasi Rencana Strategis Kementerian/Lembaga (Renstra K/L) dan data informasi lainnya yang terjaga 2 Rancangan Awal - Rencana Pembangunan Jangka Menengah Nasional IV 2020-2024 telah sejalan dengan Sustainable Development Goals (SDGs). Target-target dari 17 tujuan (goals) dalam Tujuan Pembangunan Berkelanjutan (SDG',
#  '260 kabupaten/kota pada tahun 2020']
# time: 43.5 s (started: 2024-05-05 07:17:57 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.029979730053731876,
#  'precisions': [0.055415617128463476,
#   0.031331592689295036,
#   0.024193548387096774,
#   0.019230769230769232],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.8294930875576036,
#  'translation_length': 397,
#  'reference_length': 217}
# time: 1.19 s (started: 2024-05-05 07:25:44 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.10383165034810099,
#  'rouge2': 0.09275362318840581,
#  'rougeL': 0.10413273001508294,
#  'rougeLsum': 0.10331739823265247}
# time: 762 ms (started: 2024-05-05 07:25:48 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya.',
#  'tumbuh, hambatan perkembangan kognitif dan motorik, dan tidak optimalnya ukuran fisik tubuh serta gangguan metabolisme',
#  'terjadi gagal tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dal metabolisme tubuhnya.',
#  'keluarga berisiko Stunting',
#  'PAUDHI',
#  'gizi spesifik',
#  'tahun',
#  'keterlibatan multisektor',
#  'dan tetapan ketentuan Pasal 12 ayat (71 Undang-Undang Nomor 28 Tahun 2022 tentang Anggaran Pendapatan dan Belanja Negara Tahun Anggaran 2023, perlu menetapkan Peraturan Presiden tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023',
#  'kembali kembali',
#  'entri ke komputer yang dilakukan di lapangan',
#  '25 Januari',
#  'angka stunting',
#  'kembali tahun ketiga pelaksanaan RPJMN 2020-2024',
#  '260 kabupaten/kota']
# time: 1min 49s (started: 2024-03-01 23:15:50 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.07137735209917628,
#  'precisions': [0.33766233766233766,
#   0.1223021582733813,
#   0.06349206349206349,
#   0.05084745762711865],
#  'brevity_penalty': 0.6642538428642955,
#  'length_ratio': 0.7096774193548387,
#  'translation_length': 154,
#  'reference_length': 217}
# time: 1.09 s (started: 2024-03-01 23:17:47 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.28085615509932405,
#  'rouge2': 0.20069589559225554,
#  'rougeL': 0.2691774810623151,
#  'rougeLsum': 0.27250346151868254}
# time: 601 ms (started: 2024-03-01 23:17:51 +00:00)

# %% [markdown]
# ### Flan t-5 large

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan tumbuh kembang yang dialami anak akibat gizi buruk, infeksi berulang, dan didefinisikan terhambat gizinya if tinggi badan mereka terhadap usia lebih dari dua deviasi standar di bawah median standar pertumbuhan anak WHO',
#  'kompleks dan multikausal',
#  'identifikasi prioritas kegiatan',
#  'Tim Pendamping Keluarga',
#  'Peraturan Presiden Republik Indonesia',
#  'yang secara langsung mempengaruhi pemenuhan gizi dan perkembangan janin dan anak terutama sampai berusia kurang dari 23 bulan',
#  'Rencana Pembangunan Jangka Menengah Nasional',
#  'upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor',
#  'Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023',
#  'media edukasi',
#  'FAO/WHO Global Individual Food Consumption data Tool',
#  'HGN',
#  'Menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025 3.',
#  'RPJMN 2020- 2024',
#  '260']
# time: 3min 34s (started: 2024-03-01 23:52:34 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.28704829533494336,
#  'precisions': [0.6209677419354839,
#   0.5871559633027523,
#   0.6041666666666666,
#   0.6190476190476191],
#  'brevity_penalty': 0.4723665527410147,
#  'length_ratio': 0.5714285714285714,
#  'translation_length': 124,
#  'reference_length': 217}
# time: 1.19 s (started: 2024-03-01 23:56:14 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.38749254885900847,
#  'rouge2': 0.2514308426073132,
#  'rougeL': 0.38257147959011306,
#  'rougeLsum': 0.3862584689292764}
# time: 658 ms (started: 2024-03-01 23:56:17 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting merujuk pada kondisi gagal tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya.',
#  'Stunting disebabkan karena seseorang tidak mendapatkan asupan bergizi dalam jumlah yang tepat pada jangka waktu yang lama (kronik). Sehingga, stunting sebenarnya dapat dicegah dengan asupan gizi yang memadai, terutama pada 1000 Hari Pertama Ke',
#  'Mencegah stunting dapat dilakukan melalui pemberian makanan tambahan bagi ibu hamil dengan kurang energi kronik (KEK), pemberian suplementasi tablet tambah darah, pemberian suplementasi kalsium, pemeriksaan kehamilan, perlindungan dari malaria, pencegahan HIV, dan ibu menyus',
#  'Pendampingan keluarga adalah upaya pengawasan dan pembinaan terhadap keluarga yang dilakukan oleh tim pendamping keluarga yang terdiri dari bidan, kader, dan PKK. Pendampingan keluarga bertujuan untuk membantu keluarga mengurangi resiko stunting pada',
#  'Pengembangan Anak Usia Dini Holistik Integratif (PAUD HI) adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. Layanan stimulasi holistik mencakup layanan',
#  'Intervensi gizi dapat dibedakan menjadi dua jenis, yaitu intervensi gizi spesifik dan intervensi gizi sensitif. Intervensi gizi spesifik meliputi kegiatan yang langsung mengatasi penyebab terjadinya stunting, seperti asupan makanan, pencegahan infeksi, status gizi ib',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Scaling Up Nutrition (SUN) adalah upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Kerjasama antara pemerintah, organisasi masyarakat sipil, dunia usaha, mitra pembangunan dan akademisi merupakan ciri khas dari gerakan ini. Indonesia b',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023.',
#  'Elsimil adalah singkatan dari "E-Learning Sistem Informasi Masyarakat".',
#  'Data SGGI diperoleh melalui survei berskala nasional pertama di Indonesia yang mengumpulkan data konsumsi individu secara lengkap, yaitu SKMI. Survei ini dilakukan bekerjasama dengan Perguruan Tinggi, Badan Pusat Statistik, Dinas Kesehatan Provinsi dan Kabupaten/Kota dan dib',
#  'Hari Gizi Nasional diperingati setiap tahunnya pada tanggal 25 Januari.',
#  'Target prevalensi stunting World Health Assembly adalah 22 persen.',
#  'RPJPN itu untuk periode 20 tahun.',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota.']
# time: 53 s (started: 2024-05-06 00:49:06 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.3008167274237775,
#  'precisions': [0.4758269720101781,
#   0.30687830687830686,
#   0.2534435261707989,
#   0.22126436781609196],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.8110599078341014,
#  'translation_length': 393,
#  'reference_length': 217}
# time: 2.01 s (started: 2024-05-06 00:50:21 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.5244216099599008,
#  'rouge2': 0.411105353087436,
#  'rougeL': 0.4725092726979519,
#  'rougeLsum': 0.47881508578274085}
# time: 1.32 s (started: 2024-05-06 00:50:40 +00:00)

# %% [markdown]
# ## 1500 100

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['0 sampai 59 bulan',
#  'd.',
#  'ibu hamil Kurang Energi Kronik (KEK) Pemberian suplementasi tablet',
#  'adalah guru kehidupan bagi anaknya',
#  'a.',
#  'iba tidak tergapainya tergapainya tergapainya tergapainya tergapainya',
#  'dalam Pembukaan UUD Republik Indonesia Tahun 1945 dalam bentuk visi, misi dan arah pembangunan nasional',
#  'terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor',
#  '',
#  'dilihat di saat dilihat melalui Google Playstore atau Apple App Store',
#  'SSGI 2021 diambil pad 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas). Pengambilan data dilakukan oleh enumerator terlatih dan memperhatikan protokol kesehatan yang ketat dengan sasaran rumah tangga dengan anak balita.',
#  'd.',
#  '20252',
#  'i)',
#  '']
# time: 40.1 s (started: 2024-03-01 23:23:33 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.16101549364031054,
#  'precisions': [0.35772357723577236,
#   0.34545454545454546,
#   0.3469387755102041,
#   0.3333333333333333],
#  'brevity_penalty': 0.4656934740600102,
#  'length_ratio': 0.5668202764976958,
#  'translation_length': 123,
#  'reference_length': 217}
# time: 986 ms (started: 2024-03-01 23:24:33 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.11856209150326796,
#  'rouge2': 0.09275362318840581,
#  'rougeL': 0.12334188034188033,
#  'rougeLsum': 0.12300854700854699}
# time: 610 ms (started: 2024-03-01 23:24:40 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dal metabolisme tubuhnya',
#  'komitmen politik dan kebijakan untuk pelaksanaan',
#  'terjadi gagal tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dal metabolisme tubuhnya',
#  'keluarga berisiko Stunting',
#  'adalah pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi.',
#  'gizi gizi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak terjadi tidak',
#  'tujuan dibentuknya pemerintahan Indonesia yang tercantum dalam Pembukaan UUD Republik Indonesia Tahun 1945 dalam bentuk visi, misi dan arah pembangunan nasional',
#  'SUN Indonesia',
#  'dan tetapkan ketentuan Pasal 12 ayat (1) Undang-Undang Dasar Negara Republik Indonesia Tahun 2022 tentang Anggaran Pendapatan dan Belanja Negara Tahun Anggaran 2023',
#  'Google Playstore or Apple App Store',
#  'Data SSGI 2021',
#  'Sekolah Juru Penerang Makanan yang merupakan cikal bakal pendidikan tenaga gizi Indonesia',
#  'angka stunting',
#  'tahun tahun kembali pelaksanaan RPJMN',
#  '61,64 Kab. Bulungan dan Kab. Nunukan 84,51 Kec. Sebatik, Kec. Nunukan, Kec. Krayan, Kec. Krayan Selatan, Kec. Sebatik Barat, Kec. Nunukan Selatan, Kec. Sebatik Timur, Kec. Sebatik Utara, Kec. Sebatik Tengah, Kec. Seimanggiris, Kec. Tulin Onsoi, Kec. Lumbis Ogong, Kec. Krayan Tengah, Kec. Seimanggiris, Kec. Tulin Onsoi, Kec. Lumbis Ogong, Kec. Krayan Tengah, Kec. Seimanggiris, Kec. Tulin Onsoi, Kec. Lumbis Ogong, Kec. Krayan Tengah, Kec. Sebatik Timur, Kec. Sebatik Utara, Kec. Sebatik Tengah, Kec. Seimanggiris, Kec. Tulin Onsoi, Kec. Lumbis Ogong, Kec. Krayan Tengah, Kec. Sebatik Timur, Kec. Sebatik Utara, Kec. Sebatik Tengah, Kec. Seimanggiris, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin Onsoi, Kec. Tulin']
# time: 3min 8s (started: 2024-03-01 23:25:06 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.06582173136010173,
#  'precisions': [0.1218568665377176,
#   0.06772908366533864,
#   0.0513347022587269,
#   0.04430379746835443],
#  'brevity_penalty': 1.0,
#  'length_ratio': 2.3824884792626726,
#  'translation_length': 517,
#  'reference_length': 217}
# time: 1.31 s (started: 2024-03-01 23:28:35 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.16495224741028555,
#  'rouge2': 0.08369991246388761,
#  'rougeL': 0.16213981096540186,
#  'rougeLsum': 0.1600944227223549}
# time: 614 ms (started: 2024-03-01 23:28:38 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan tumbuh kembang yang dialami anak akibat gizi buruk, infeksi berulang, dan didefinisikan terhambat gizinya jif tinggi badan merek terhadap usia lebih dari dua deviasi standar di bawah median standar pertumbuhan anak WHO',
#  'kompleks dan multikausal',
#  'identifikasi prioritas kegiatan',
#  'Tim Pendamping Keluarga',
#  'Peraturan Presiden Republik Indonesia',
#  'Sensitive',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Beranda Tentang Tentang SUN',
#  'Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023',
#  'media edukasi',
#  'Pada 514 kabupaten/kota se-Indonesia',
#  'Peringatan ini awalnya ditujukan untuk memperingati berdirinya Sekolah Juru Penerang Makanan yang merupakan cikal bakal pendidikan tenaga gizi Indonesia',
#  'Menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025 3.',
#  'RPJMN 2005- 2025',
#  '260 kabupaten/kota']
# time: 2min 51s (started: 2024-03-01 23:33:07 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.25567904984035117,
#  'precisions': [0.5882352941176471,
#   0.5673076923076923,
#   0.5777777777777777,
#   0.5974025974025974],
#  'brevity_penalty': 0.43887992979155477,
#  'length_ratio': 0.5483870967741935,
#  'translation_length': 119,
#  'reference_length': 217}
# time: 917 ms (started: 2024-03-01 23:36:03 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.3567428495999924,
#  'rouge2': 0.32410477704595353,
#  'rougeL': 0.3479717794003508,
#  'rougeLsum': 0.34981564981564983}
# time: 670 ms (started: 2024-03-01 23:36:10 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang atau tinggi badannya berada di bawah standar yang ditetapkan oleh menteri yang menyelenggarakan urusan pemerintahan di bidang k',
#  'Stunting disebabkan karena seseorang tidak mendapatkan asupan bergizi dalam jumlah yang tepat pada jangka waktu yang lama (kronis). Sehingga, stunting sebenarnya dapat dicegah dengan asupan gizi yang memadai, terutama pada 1000 Hari Pertama Ke',
#  'Untuk mencegah stunting, hal terpenting adalah memastikan pola asuh yang benar pada masa 1000 Hari Pertama Kehidupan (1000 HPK), yang dimulai saat kehamilan hingga anak berusia dua tahun. Hal ini melibatkan pemberian makanan tambahan bagi',
#  'Pendampingan keluarga adalah upaya mendampingi keluarga dalam mengurangi resiko terjadinya stunting pada anak-anaknya, melalui pemberian informasi, pelayanan kesehatan, sosialisasi, dan fasilitasi akses terhadap sanitasi dan air bersih serta program sosial dan k',
#  'Pengembangan Anak Usia Dini Holistik Integratif (PAUD HI) adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. PAUD HI melibatkan pihak terkait sepert',
#  'Intervensi gizi dapat dibedakan menjadi dua jenis, yaitu intervensi gizi spesifik dan intervensi gizi sensitif. Intervensi gizi spesifik melibatkan kegiatan yang langsung mengatasi penyebab terjadinya stunting, seperti pemeriksaan kehamilan secara berkala, pemberian',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Scaling Up Nutrition (SUN) adalah upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Kerjasama antara pemerintah, organisasi masyarakat sipil, dunia usaha, mitra pembangunan dan akademisi merupakan ciri khas dari gerakan ini. Indonesia b',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023.',
#  'ELSIMIL adalah singkatan dari E-Learning Sistem Informasi Masyarakat.',
#  'Data SGGI diperoleh melalui survei berskala nasional pertama di Indonesia yang mengumpulkan data konsumsi individu secara lengkap, yaitu SKMI. Survei ini dilakukan bekerjasama dengan Perguruan Tinggi, Badan Pusat Statistik, Dinas Kesehatan Provinsi dan Kabupaten/Kota dan dib',
#  'Hari Gizi Nasional diperingati setiap tahunnya pada tanggal 25 Januari.',
#  'Target prevalensi stunting World Health Assembly adalah menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025.',
#  'RPJPN itu untuk periode 2005-2025.',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota.']
# time: 42.8 s (started: 2024-03-03 02:29:22 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.39960601362115483,
#  'precisions': [0.527363184079602,
#   0.40310077519379844,
#   0.3629032258064516,
#   0.33053221288515405],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.8525345622119815,
#  'translation_length': 402,
#  'reference_length': 217}
# time: 1.61 s (started: 2024-03-03 02:30:32 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.5767004191518721,
#  'rouge2': 0.45953380117107506,
#  'rougeL': 0.524537511841906,
#  'rougeLsum': 0.5282637851233665}
# time: 1.12 s (started: 2024-03-03 02:30:57 +00:00)

# %% [markdown]
# ### Bloom

# %%
['Apa itu stunting?',
 'Apa penyebab stunting',
 'Bagaimana cara mencegah stunting?',
 'Pendampingan keluarga adalah',
 'Jelaskan mengenai Pengembangan Anak Usia Dini Holistik Integratif!',
 'Sebutkan jenis intervensi gizi!',
 'Apa kepanjangan dari RPJPN?',
 'Apa itu Gerakan Scaling Up Nutrition (SUN)?',
 'Mengatur tentang apa Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023?',
 'Apa kepanjangan Elsimil?',
 'Bagaimana data SGGI diperoleh?',
 'Kapan diperingati Hari Gizi Nasional setiap tahunnya?',
 'Berapa target prevalensi stunting World Health Assembly?',
 'RPJPN itu untuk periode berapa tahun?',
 'Lokus stunting tahun 2020 ditetapkan sebanyak berapa Kabupaten/Kota?']

# %%
def process_question(question):
    response = rqa_chain({"question": question}, return_only_outputs=True)
    answers = response.get('answer', '').split('\nAnswer in Indonesian: ')[-1].split('\n')[0].strip()
    return response

while True:
    user_question = input("Masukkan pertanyaan (ketik 'exit' untuk keluar): ")

    if user_question.lower() == 'exit':
        print("Keluar dari program.")
        break

    answer = process_question(user_question)
    print(f"{answer}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-141-fe4996fec9f9> in <cell line: 6>()
#       5
#       6 while True:
# ----> 7     user_question = input("Masukkan pertanyaan (ketik 'exit' untuk keluar): ")
#       8
#       9     if user_question.lower() == 'exit':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
# time: 45.9 s (started: 2024-05-05 09:09:13 +00:00)

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 422 Client Error: Unprocessable Entity for url: https://api-inference.huggingface.co/models/bigscience/bloom
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-136-093bc57f9841> in <cell line: 3>()
#       2
#       3 for question in questions:
# ----> 4     response = rqa_chain({"query": question})
#       5     answer = response.get('result', '').strip()
#       6     answer_start = "Answer in Indonesian:"
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     143         else:
#     144             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 145         answer = self.combine_documents_chain.run(
#     146             input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     147         )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     598
#     599         if kwargs and not args:
# --> 600             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     601                 _output_key
#     602             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     135         # Other keys are assumed to be needed for LLM prediction
#     136         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 137         output, extra_return_dict = self.combine_docs(
#     138             docs, callbacks=_run_manager.get_child(), **other_keys
#     139         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     242         inputs = self._get_inputs(docs, **kwargs)
#     243         # Call predict on the LLM.
# --> 244         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     245
#     246     async def acombine_docs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in predict(self, callbacks, **kwargs)
#     314                 completion = llm.predict(adjective="funny")
#     315         """
# --> 316         return self(kwargs, callbacks=callbacks)[self.output_key]
#     317
#     318     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     124         run_manager: Optional[CallbackManagerForChainRun] = None,
#     125     ) -> Dict[str, str]:
# --> 126         response = self.generate([inputs], run_manager=run_manager)
#     127         return self.create_outputs(response)[0]
#     128
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     136         callbacks = run_manager.get_child() if run_manager else None
#     137         if isinstance(self.llm, BaseLanguageModel):
# --> 138             return self.llm.generate_prompt(
#     139                 prompts,
#     140                 stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     631     ) -> LLMResult:
#     632         prompt_strings = [p.to_string() for p in prompts]
# --> 633         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     634
#     635     async def agenerate_prompt(
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     801                 )
#     802             ]
# --> 803             output = self._generate_helper(
#     804                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805             )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668             for run_manager in run_managers:
#     669                 run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670             raise e
#     671         flattened_outputs = output.flatten()
#     672         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     655         try:
#     656             output = (
# --> 657                 self._generate(
#     658                     prompts,
#     659                     stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#    1315         for prompt in prompts:
#    1316             text = (
# -> 1317                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1318                 if new_arg_supported
#    1319                 else self._call(prompt, stop=stop, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/llms/huggingface_hub.py in _call(self, prompt, stop, run_manager, **kwargs)
#     133         parameters = {**_model_kwargs, **kwargs}
#     134
# --> 135         response = self.client.post(
#     136             json={"inputs": prompt, "parameters": parameters}, task=self.task
#     137         )
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_client.py in post(self, json, data, model, task, stream)
#     271
#     272             try:
# --> 273                 hf_raise_for_status(response)
#     274                 return response.iter_lines() if stream else response.content
#     275             except HTTPError as error:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     369         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     370         # as well (request id and/or server error message)
# --> 371         raise HfHubHTTPError(str(e), response=response) from e
#     372
#     373
#
# HfHubHTTPError: 422 Client Error: Unprocessable Entity for url: https://api-inference.huggingface.co/models/bigscience/bloom (Request ID: t_2UQqU7VGXHcVMGPkBYM)
#
# Input validation error: `inputs` must have less than 1000 tokens. Given: 1223
# Make sure 'text-generation' task is supported by the model.
# time: 206 ms (started: 2024-05-05 08:56:52 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.3403572778752235,
#  'precisions': [0.45064377682403434,
#   0.3394495412844037,
#   0.3054187192118227,
#   0.2872340425531915],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.0737327188940091,
#  'translation_length': 233,
#  'reference_length': 217}
# time: 1.16 s (started: 2024-03-03 02:24:36 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.37870339550772053,
#  'rouge2': 0.26578466639984993,
#  'rougeL': 0.363527070937779,
#  'rougeLsum': 0.3604161986900041}
# time: 828 ms (started: 2024-03-03 02:24:40 +00:00)

# %% [markdown]
# ## 1500 200

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['dalam terjadinya stunting',
#  'dalam terjadinya stunting',
#  'dalam terjadinya',
#  'dilakukan oleh Tim Pendamping Keluarga yaitu sekelompok tenaga yang terdiri Bidan, Kader TP PKK, dan kader KB untuk meliputi penyuluhan dan fasilitasi pelayanan rujukan dan fasilitasi penerimaan program bantuan sosial kepada calon pengantin/calon pasangan usia subur, ibu hamil, ibu pasca persalinan, anak usia 0-59 bulan serta melakukan surveilans keluarga berisiko stunting untuk mendeteksi dini faktor-faktor risiko stunting',
#  'b.',
#  '',
#  'RAN-PG',
#  'dl',
#  '- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -',
#  'irklir Selain berfungsi sebagai media edukasi tentang kesehatan reproduksi, kontrasepsi, kesiapan pranikah, kesiapan kehamilan, serta cega kanker',
#  'SSGI 2021 diambil pad 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas). Pengambilan data dilakukan oleh enumerator terlatih dan memperhatikan protokol kesehatan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan sasaran rumah tangga dengan',
#  'i.',
#  '20252',
#  'a.',
#  '2.1 Jumlah Kabupaten/Kota Lokus Stunting Tahun 2018-2022 (Akumulasi) Kabupaten/Kota 514 360 260 160 100 Tahun 2018 Tahun 2020 2020 Tahun 2021']
# time: 50.6 s (started: 2024-03-01 23:50:05 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.10434843450417196,
#  'precisions': [0.16380952380952382,
#   0.1095890410958904,
#   0.088,
#   0.07505070993914807],
#  'brevity_penalty': 1.0,
#  'length_ratio': 2.4193548387096775,
#  'translation_length': 525,
#  'reference_length': 217}
# time: 1.09 s (started: 2024-03-01 23:51:55 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.10617739988997472,
#  'rouge2': 0.05483405483405483,
#  'rougeL': 0.07668473868312996,
#  'rougeLsum': 0.07661041553257122}
# time: 667 ms (started: 2024-03-01 23:51:58 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['tumbuhan pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya',
#  'kembali tahun',
#  'tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak',
#  'Tim Pendamping Keluarga',
#  'PAUD',
#  'kejadian tidak langsung',
#  'tujuan dibentuknya pemerintahan Indonesia yang tercantum dalam Pembukaan UUD Republik Indonesia Tahun 1945 dalam bentuk visi, misi dan arah pembangunan nasional',
#  'komitmen pemerintah Indonesia dalam mempercepat perbaikan gizi di Indonesia',
#  'dan tetapkan kembali kembali sarana',
#  'Google Playstore or Apple App Store',
#  'Data SSGI 2021',
#  '25 Januari',
#  'angka stunting',
#  '20',
#  'tahun 2020']
# time: 1min 41s (started: 2024-03-01 23:45:44 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0,
#  'precisions': [0.14948453608247422,
#   0.0446927374301676,
#   0.006024096385542169,
#   0.0],
#  'brevity_penalty': 0.888201452290974,
#  'length_ratio': 0.8940092165898618,
#  'translation_length': 194,
#  'reference_length': 217}
# time: 888 ms (started: 2024-03-01 23:47:52 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.19916577170522354,
#  'rouge2': 0.08527841342486651,
#  'rougeL': 0.1900834349243573,
#  'rougeLsum': 0.19351142508285366}
# time: 643 ms (started: 2024-03-01 23:47:47 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question}, return_only_outputs=True)
    answer = response.get('result', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['terjadi lantaran pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK) dan hal tersebut tidak dapat lagi mengingat masa 1000 HPK merupakan periode kritis yang menjadi faktor penentu kualitas kehidupan anak kelak',
#  'identifikasi faktor penyebab langsung stunting',
#  'terjadi lantaran pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK) dan hal tersebut tidak dapat lagi mengingat masa 1000 HPK merupakan periode kritis yang menjadi faktor penentu kualitas kehidupan anak kelak',
#  'Tim Pendamping Keluarga',
#  'Peraturan Presiden Republik Indonesia',
#  'yang menyasar pada sasaran yang sama dapat lebih dikonvergensikan dan diintegrasikan selama pelaksanaan',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'SUN Movement Joint-Assessment Report',
#  'Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023',
#  'media edukasi',
#  'Data SSGI 2021 diambil pada 514 kabupaten/kota se-Indonesia',
#  'Peringatan ini awalnya ditujukan untuk memperingati berdirinya Sekolah Juru Penerang Makanan yang merupakan cikal bakal pendidikan tenaga gizi Indonesia',
#  'Menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025 3.',
#  '20',
#  'Semua tahun 2020']
# time: 6min 27s (started: 2024-03-01 23:38:28 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.20648411039547426,
#  'precisions': [0.378698224852071,
#   0.2792207792207792,
#   0.24285714285714285,
#   0.2204724409448819],
#  'brevity_penalty': 0.7527488279550412,
#  'length_ratio': 0.7788018433179723,
#  'translation_length': 169,
#  'reference_length': 217}
# time: 1.24 s (started: 2024-03-01 23:45:04 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.35231421923858897,
#  'rouge2': 0.23197224074582568,
#  'rougeL': 0.3399551323459822,
#  'rougeLsum': 0.3402166586072055}
# time: 631 ms (started: 2024-03-01 23:45:08 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = rqa_chain({"query": question})
    answer = response.get('result', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting merujuk pada kondisi gagal tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya.',
#  'Penyebab stunting adalah kekurangan gizi kronis, infeksi berulang, dan stimulasi psikososial yang tidak memadai terutama dalam 1000 Hari Pertama Kehidupan (HPK).',
#  'Untuk mencegah stunting, perlu dilakukan pola asuh yang benar selama masa 1000 Hari Pertama Kehidupan (1000 HPK), yang meliputi kewajiban ibu hamil, ibu nifas, dan orang tua dalam mengasuh anaknya. Hal ini penting karena masa 10',
#  'Pendampingan keluarga adalah kegiatan yang dilakukan oleh Tim Pendamping Keluarga, yang terdiri dari Bidan, Kader TP PKK, dan kader KB, untuk melakukan pendampingan meliputi penyuluhan, fasilitasi pelayanan rujukan dan fasilitasi penerimaan program b',
#  'Pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. Layanan stimulasi holistik mencakup layanan pendidikan, k',
#  'Intervensi gizi dapat dibedakan menjadi dua, yaitu intervensi gizi spesifik dan intervensi gizi sensitif. Intervensi gizi spesifik ditujukan kepada anak dalam 1.000 HPK dan berkontribusi pada 30 persen penurunan stunting, sedangkan intervensi gizi sensitif dil',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Scaling Up Nutrition (SUN) adalah gerakan global di bawah Sekretaris Jenderal PBB untuk mengatasi semua bentuk malnutrisi melalui keterlibatan lintas sektor. Gerda Verburg, koordinator gerakan SUN di tingkat global, menyampaikan apresiasinya terhadap komitmen pemerintah Indonesia dal',
#  'Mengatur tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023.',
#  'Elsimil adalah singkatan dari Elektronik Sistem Informasi Masyarakat.',
#  'Data SSGI 2021 diperoleh dengan melakukan survei pada 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang telah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas).',
#  'Hari Gizi Nasional diperingati setiap tahunnya pada tanggal 25 Januari.',
#  'Target prevalensi stunting World Health Assembly adalah 22 persen pada tahun 2025.',
#  'RPJPN itu untuk periode 20 tahun.',
#  'Lokus stunting tahun 2020 ditetapkan sebanyak 260 Kabupaten/Kota.']
# time: 54.8 s (started: 2024-05-06 00:56:14 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.33978140926926936,
#  'precisions': [0.5340599455040872,
#   0.35795454545454547,
#   0.2878338278931751,
#   0.2422360248447205],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.6912442396313363,
#  'translation_length': 367,
#  'reference_length': 217}
# time: 1.75 s (started: 2024-05-06 00:58:06 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.5645353927305767,
#  'rouge2': 0.4403874321822132,
#  'rougeL': 0.5220088321646794,
#  'rougeLsum': 0.5247409388238007}
# time: 1.5 s (started: 2024-05-06 00:58:12 +00:00)

# %% [markdown]
# # Conversational Retrieval Chain

# %%
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts.prompt import PromptTemplate

_template = """Given the following conversation and a follow up question,
rephrase the follow up question to be a standalone question, in its original language.

Chat History:
{chat_history}
Follow Up Input: {question}
Standalone question:"""
CONDENSE_QUESTION_PROMPT = PromptTemplate.from_template(_template)

template = """Use the following pieces of context to answer the question at the end.
If you don't know the answer, just say that you don't know, don't try to make up an answer.
{context}

Question: {question}
Answer in Indonesian:"""
ANSWER_PROMPT = PromptTemplate.from_template(template)

memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True, output_key='answer')
cr_chain = ConversationalRetrievalChain.from_llm(
    llm,
    retriever,
    memory=memory,
    return_source_documents=True,
    condense_question_prompt=CONDENSE_QUESTION_PROMPT,
    combine_docs_chain_kwargs={"prompt": ANSWER_PROMPT}
)
# Out:
# time: 3.82 ms (started: 2024-05-06 03:07:41 +00:00)

# %% [markdown]
# ## 500 0

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['i.',
#  'a).',
#  '1).',
#  'KUHP',
#  'a.',
#  'Pidana',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Pidana',
#  'id Lampiran I Surat Menteri PPN/Kepala Bappenas Nomor',
#  'ao,oo 91,OO',
#  'SGGI',
#  '',
#  'World Health Organization',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  '']
# time: 20.6 s (started: 2024-05-05 08:13:01 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# {'bleu': 0.002932029817246428,
#  'precisions': [0.23255813953488372,
#   0.16666666666666666,
#   0.14285714285714285,
#   0.14285714285714285],
#  'brevity_penalty': 0.01748325649252071,
#  'length_ratio': 0.19815668202764977,
#  'translation_length': 43,
#  'reference_length': 217}
# time: 8.9 s (started: 2024-03-02 01:23:29 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.08717948717948718,
#  'rouge2': 0.07222222222222222,
#  'rougeL': 0.0947008547008547,
#  'rougeLsum': 0.08717948717948716}
# time: 1.15 s (started: 2024-03-02 01:23:40 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['Stunting',
#  'X-Men',
#  'saat tahun',
#  'a. Nama pangan olahan terdiri dari nama jenis dan nama dagang. b. Nama pangan olahan terdiri dari nama jenis dan nama dagang. c. Nama jenis adalah pernyataan orang identitas mengenai pangan olahan. d. Nama jenis yang belum diatur dalam angka 1) harus memenuhi',
#  'Pidana',
#  'X-Men',
#  'tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke',
#  'PENNY K. LUKITO 79 - LAMPIRAN III PERATURAL BADAN PENDAWAS OBAT DAN MAKANAN NOMOR 26 TAHUN 2021 TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI PADA LABEL PANGANAN OLAHA TENTANG INFORMASI NILAI GIZI P',
#  'tahun tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke t',
#  'kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepada kepad',
#  'TUJUAN 17 INDIKATOR NAMA KETERANGAN Jumlah metadata kegiatan statistik dasar, sektoral, dan khusus yang terdalam Sistem Informasi Rujukan Statistik (SIRuSa).',
#  'tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke',
#  '40 persen',
#  'tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke',
#  '14']
# time: 4min 51s (started: 2024-03-02 01:25:01 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0,
#  'precisions': [0.016597510373443983, 0.001053740779768177, 0.0, 0.0],
#  'brevity_penalty': 1.0,
#  'length_ratio': 4.442396313364055,
#  'translation_length': 964,
#  'reference_length': 217}
# time: 1.35 s (started: 2024-03-02 01:30:24 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.08337571176280854,
#  'rouge2': 0.06666666666666667,
#  'rougeL': 0.08225934005820154,
#  'rougeLsum': 0.08306784086670234}
# time: 916 ms (started: 2024-03-02 01:30:12 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['percepatan penurunan stunting',
#  'unanswerable',
#  'stunting',
#  'Kelompok Keluarga',
#  'Rohmadeny',
#  'Rasio Gini Terima Kasih',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Nasional Percepatan Perbaikan Gizi',
#  'TENTANG PDTUNJUK TEKNIS DANA ALOKASI KHUSUS FISIK',
#  'LSPro Penerbit SPPT SNI',
#  'TUJUAN 17 INDIKATOR NAMA KETERANGAN Jumlah metadata kegiatan statistik dasar, sektoral, dan khusus yang terdapat dalam Sistem Informasi Rujukan Statistik (SIRuSa). Indikator nasional sebagai proksi indikator global (tidak adak di dalam lampiran perpres). Persentase indikator SDGs terpilah yang relevan den target. Indikator nasional sebagai proksi indikator global (tidak adak di dalam lampiran perpres). digunakan dalam TPB/SDGs, dan acuan untuk merumuskan Metadata Indikator TPB/SDGs Nasional.',
#  '2',
#  'sebanyak 40 persen',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  '65 Lampiran 1']
# time: 1min 36s (started: 2024-03-02 01:37:42 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.024606999995472733,
#  'precisions': [0.13385826771653545,
#   0.05357142857142857,
#   0.039603960396039604,
#   0.02197802197802198],
#  'brevity_penalty': 0.4923027445285314,
#  'length_ratio': 0.5852534562211982,
#  'translation_length': 127,
#  'reference_length': 217}
# time: 975 ms (started: 2024-03-02 01:39:54 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.2038457699230895,
#  'rouge2': 0.1492063492063492,
#  'rougeL': 0.20440304369170348,
#  'rougeLsum': 0.20866012109311077}
# time: 763 ms (started: 2024-03-02 01:39:58 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kekurangan tinggi badan pada anak-anak yang berusia di bawah lima tahun.',
#  '"Stunting disebabkan oleh gizi buruk selama kehamilan dan pertumbuhan anak. Ini bisa disebabkan oleh kekurangan asupan gizi, penyakit, atau kekurangan asupan air minum yang mengakibatkan dehidrasi."',
#  'Bagi mencegah stunting, Anda dapat mengikuti langkah-langkah berikut:\n1. Pastikan ibu hamil dan ibu menyusui mendapatkan gizi cukup. Ibu hamil dan ibu menyusui harus memakan makanan yang sehat dan mengonsumsi suplemen vitamin sebagai langkah awal',
#  '"Pendampingan keluarga adalah serangkaian kegiatan yang dilakukan terhadap keluarga yang memiliki ibu hamil, ibu pascapersalinan, anak usia dibawah 5 tahun, dalam mencegah stunting. Hal ini dilakukan melalui pendekatan keluarga dan fokus pada per',
#  'Pengembangan anak usia dini holistik integratif penting karena ia memfasilitasi pemenuhan kebutuhan perkembangan dan pertumbuhan anak secara holistik integratif, yang sangat menentukan kualitas kesehatan, kecerdasan, dan kematangan sosial di tahap berikutnya. Hal ini',
#  '"Jenis-jenis intervensi gizi yang disebutkan dalam teks adalah intervensi gizi spesifik dan kegiatan intervensi yang dilakukan pada sektor kesehatan."',
#  '"RPJPN adalah Rencana Pembangunan Jangka Panjang Nasional."',
#  'Gerakan Scaling Up Nutrition (SUN) adalah upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Kerjasama antara pemerintah, organisasi masyarakat sipil, dunia usaha, mitra pembangunan dan akademisi merupakan ciri khas dari gerakan ini.',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 ditetapkan untuk menetapkan Peraturan Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023. Hal ini ditetapkan sesuai dengan Peraturan Pemerintah Republik Indonesia Nomor 33 Tahun 2012, y',
#  '"ESM"',
#  'Data SGGI dapat diperoleh melalui pengumpulan dan pengelolaan data.',
#  'Hari Gizi Nasional (HGN) dirayakan setiap 25 Januari setiap tahunnya.',
#  '"Target prevalensi stunting yang ditetapkan oleh World Health Assembly adalah 22 persen pada tahun 2025."',
#  'Rencana Pembangunan Jangka Panjang Nasional (RPJPN) berlaku untuk periode 20 (dua puluh) tahun terhitung sejak tahun 2005 sampai dengan tahun 2025.',
#  'Sebanyak 260 Kabupaten/Kota ditetapkan sebagai lokus stunting pada tahun 2020.']
# time: 1min 3s (started: 2024-05-06 02:01:27 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.22501693572988077,
#  'precisions': [0.41761363636363635,
#   0.2433234421364985,
#   0.18012422360248448,
#   0.14006514657980457],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.6221198156682028,
#  'translation_length': 352,
#  'reference_length': 217}

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4338072344714451,
#  'rouge2': 0.28976088159339997,
#  'rougeL': 0.3829880941620144,
#  'rougeLsum': 0.38932771028743185}
# time: 862 ms (started: 2024-05-06 02:03:43 +00:00)

# %% [markdown]
# ### Bloom

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kondisi gagal tumbuh pada anak balita akibat kekurangan gizi kronis terutama pada 1000 hari pertama kehidupan',
#  'Penyebab stunting adalah kekurangan gizi kronis yang disebabkan oleh asupan gizi yang tidak sesuai dengan kebutuhan',
#  'Bagaimana mencegah stunting?\n\nIs to use the word mencegah, which means "to prevent" in Indonesian',
#  'Pendampingan keluarga adalah\nThe word pendamping is an adjective, not a noun. The word yang is',
#  'Pengembangan Anak Usia Dini Holistik Integratif merupakan upaya pengembangan anak usia dini yang dilakukan untuk memenuhi',
#  'Intervensi gizi adalah pencegahan, perbaikan, dan penanganan\nAnswer in English:\n\nIntervensi gizi adalah',
#  'RP',
#  'RPJP is the abbreviation of Rencana Pembangunan Jangka Panjang Nasional.\nAnswer in English: RPJP is',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 Tentang Petunjuk Teknis Dana Alokasi Khusus Fisik',
#  'Saya kira masalah adalah bahwa percakapan itu\n\nAnswer in English:\n\nI think the problem is that the',
#  'Tanggal peringatan Hari Gizi Nasional setiap tahun adalah tanggal 25 Januari.\n\nFollow Up Input: What is',
#  'Target prevalensi stunting World Health Assembly (WHA) adalah menurunkan angka stunting sebanyak 40',
#  'Prevalensi stunting di Indonesia setiap tahun cenderung menurun, yang ditunjukkan oleh hasil Riskesdas',
#  'Target prevalensi stunting World Health Assembly (WHA) yaitu menurunkan angka stunting sebanyak 40']
# time: 34.1 s (started: 2024-05-06 02:59:25 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.2269785748598253,
#  'precisions': [0.34051724137931033,
#   0.23963133640552994,
#   0.1921182266009852,
#   0.1693121693121693],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.0691244239631337,
#  'translation_length': 232,
#  'reference_length': 217}
# time: 1.36 s (started: 2024-05-06 03:00:22 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.3026505764728076,
#  'rouge2': 0.21159388772922944,
#  'rougeL': 0.2856437933156033,
#  'rougeLsum': 0.2800835161204015}
# time: 867 ms (started: 2024-05-06 03:00:25 +00:00)

# %% [markdown]
# ## 500 100

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['0',
#  'a penyebab stunt',
#  'a penyebab stunt',
#  'adalah',
#  'telp/fax',
#  '1. Intervensi Spesifik',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'g.',
#  'Indonesia',
#  'a nasional',
#  'Status Gizi Indonesia (SSGI)',
#  'Nusa Tenggara Timur',
#  'United states Agency for International Development',
#  'Indonesia',
#  'RPJMN 2020-2024']
# time: 30.1 s (started: 2024-03-02 01:45:11 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.004085985173643357,
#  'precisions': [0.28888888888888886,
#   0.13333333333333333,
#   0.15789473684210525,
#   0.2],
#  'brevity_penalty': 0.02187912655046472,
#  'length_ratio': 0.2073732718894009,
#  'translation_length': 45,
#  'reference_length': 217}
# time: 1.37 s (started: 2024-03-02 01:46:05 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.11260118919693388,
#  'rouge2': 0.06666666666666667,
#  'rougeL': 0.11265409924984393,
#  'rougeLsum': 0.11111111111111112}
# time: 970 ms (started: 2024-03-02 01:46:14 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['dilakukan untuk mengidentifikasi alokasi yang seperti identifikasi alokasi tumbuhan dan perkembangan anak kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang ortingai oleh menteri yang menyelenggarai urusan pemerintahan di bidang kesehatan.',
#  'Pencegahan Stunting 1. Pengertian Stunting 3. Intervensi Pencegahan Stunting Cegah Stunting BKKBN Perkenalalak Aplikasi ELSIMIL untuk Cegah Stunting Cegah Stunting',
#  'dan tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tid',
#  'd. Nama jenis harus sesuai dengan SNI yang he telah diberlakukan wajib.',
#  'PENGAMATAN PENGAWAS_____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________',
#  'tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak',
#  'terjadi tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun',
#  'SUN Business Network',
#  'tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak',
#  'kembali kembali yang meliputi',
#  'status gizi balita (stunting, wasting, and underweight) tingkat nasional, provinsi, dan kabupaten/kota.',
#  'Status Gizi Indonesia',
#  '40 persen',
#  'tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun',
#  '260 Kabupaten/Kota']
# time: 5min 26s (started: 2024-03-02 01:48:53 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.005133122088367369,
#  'precisions': [0.010656333252603536,
#   0.00583373845405931,
#   0.004147353012929983,
#   0.0026927784577723377],
#  'brevity_penalty': 1.0,
#  'length_ratio': 19.027649769585253,
#  'translation_length': 4129,
#  'reference_length': 217}
# time: 980 ms (started: 2024-03-02 01:54:27 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.2002101692641235,
#  'rouge2': 0.16277056277056276,
#  'rougeL': 0.1932428416318272,
#  'rougeLsum': 0.19513478985094634}
# time: 683 ms (started: 2024-03-02 01:54:30 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang',
#  'Dalam jangka pendek, stunting menyebabkan gagal tumbuh, hambatan perkembangan kognitif dan motorik, dan tidak optimalnya ukuran fisik tubuh serta gangguan metabolisme',
#  'berlari; menendang bola; menaiki tangga bahkan bersepeda roda tiga dapat merek lakukan den baik',
#  'BERENCANA',
#  'Jika lekukan bekas tekanan tertinggal pada kedua kaki/ tungkai, this menunjukkan pasien memiliki edema',
#  'Stunting Normal',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Nasional Percepatan Perbaikan Gizi',
#  'Peraturan Presiden',
#  'SNI',
#  'to mengetahui perkembangan status gizi balita (stunting, wasting, dan underweight) tingkat nasional, provinsi, dan kabupaten/kota',
#  'setiap tahunnya',
#  'sebanyak 40 persen',
#  '20 tahun',
#  '14 persen']
# time: 1min 32s (started: 2024-03-02 01:41:53 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.08580535927979048,
#  'precisions': [0.3620689655172414,
#   0.2079207920792079,
#   0.17045454545454544,
#   0.1375],
#  'brevity_penalty': 0.41866271675356936,
#  'length_ratio': 0.5345622119815668,
#  'translation_length': 116,
#  'reference_length': 217}
# time: 1.12 s (started: 2024-03-02 01:44:19 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.2692579058640961,
#  'rouge2': 0.2059259259259259,
#  'rougeL': 0.25851342520579124,
#  'rougeLsum': 0.25445883627959553}
# time: 1.02 s (started: 2024-03-02 01:44:26 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang atau tinggi badannya berada di bawah standar yang ditetapkan oleh menteri yang menyelenggarakan urusan pemerintahan di bidang k',
#  '"Penyebab stunting yang kompleks dan multikausal membutuhkan intervensi lintas sektor yang otak dan sistem kekebalan tubuh. Balita stunting berpotensi memiliki tingkat kecerdasan tidak maksimal, lebih rentan terhadap penyakit, dan di masa depan dapat berisiko pada menurunnya',
#  'Untuk mencegah stunting, dapat dilakukan dengan menggunakan aplikasi ELSIMIL yang dikembangkan oleh BKKBN. Aplikasi ini dapat membantu mengidentifikasi data pada level sub-komponen dan detilnya untuk mengalokasikan yang secara riil mendukung percepat',
#  'Pendampingan keluarga adalah upaya untuk membantu keluarga dalam mencapai keluarga yang seimbang dan sejahtera. Hal ini meliputi pemberian informasi, pengembangan kemampuan, dan pengawasan terhadap kegiatan keluarga.',
#  'Pengembangan anak usia dini holistik integratif penting karena ia menjadi upaya pengembangan anak yang dilakukan secara simultan, sistematis, dan terintegrasi dalam memenuhi kebutuhan esensial anak yang beragam dan saling terkait. Hal ini meliputi layanan pendidikan, kesehatan,',
#  'Intervensi gizi dibedakan menjadi gizi spesifik dan gizi sensitif. Intervensi gizi spesifik (langsung) digunakan untuk menangani penyebab-penyebab langsung terjadinya kurang gizi, sedangkan intervensi gizi sensitif (tidak langsung) digunakan untuk mencegah penyebab tid',
#  '"RPJPN berarti Rencana Pembangunan Jangka Panjang Nasional."',
#  '"Gerakan Scaling Up Nutrition (SUN) adalah upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Kerjasama antara pemerintah, organisasi masyarakat sipil, dunia usaha, mitra pembangunan dan akademisi merupakan ciri khas dari gerakan ini',
#  'Dalam Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023, diatur tentang PDTUNJUK TEKNIS DANA ALOKASI KHUSUS FISIK TAHUN ANGGARAN 2023.',
#  '"ELSIMIL tidak memiliki arti."',
#  'Data SGGI diperoleh melalui pengumpulan data yang dilakukan dengan membawa surat ijin pengumpulan data dari Provinsi dan Kabupaten/Kota, surat tugas dan Dinas Kesehatan Kabupaten/kota, salinan DSRT, peta BS, VSEN Blok I-IV Susenas Maret 2019, dokumen',
#  '"Hari Gizi Nasional dirayakan setiap tahunnya pada tanggal 25 Januari."',
#  '"Target prevalensi stunting World Health Assembly adalah menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025."',
#  'Periode RPJPN adalah lima tahun.',
#  'Lokus stunting tahun 2020 adalah 79,1 persen.']
# time: 1min 13s (started: 2024-05-06 02:13:16 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.27215959727808675,
#  'precisions': [0.4253164556962025,
#   0.27631578947368424,
#   0.23013698630136986,
#   0.20285714285714285],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.8202764976958525,
#  'translation_length': 395,
#  'reference_length': 217}
# time: 1.63 s (started: 2024-05-06 02:20:37 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.49021931933909135,
#  'rouge2': 0.34968855060783927,
#  'rougeL': 0.4296382103762993,
#  'rougeLsum': 0.4269484018314025}
# time: 891 ms (started: 2024-05-06 02:20:40 +00:00)

# %% [markdown]
# ### Bloom

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan',
#  'Faktor penyebab stunting dapat disebabkan oleh banyak hal, antara lain\n\nFaktor kemiskinan\n\nF',
#  'Stunting adalah kondisi gagal tumbuh pada anak balita akibat kekurangan gizi kronis, terutama pada periode 1000',
#  'Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis terutama pada 1000 Hari Pertama Kehidupan',
#  'Pengembangan Anak Usia Dini Holistik Integratif (PAUD HI) adalah upaya pengembangan anak usia',
#  'Intervensi gizi adalah upaya yang dilakukan untuk meningkatkan status gizi masyarakat, baik gizi spesifik maupun gizi sensitif',
#  'Pembangunan sumber daya manusia yang tertuang dalam RPJPN, tujuan pembangunan berkelanjutan dan RPJPD',
#  'Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang terutama pada 1000 hari',
#  'Stunting adalah kondisi gagal tumbuh pada anak balita akibat kekurangan gizi kronis terutama pada 1.000 Hari',
#  'Elsimil adalah kepanjangan dari Elektronik Sistem Informasi Manajemen\n\nAnswer in English:\n\nElsimil is the',
#  'Data SSGI diperoleh melalui Sensus Pertanian, Survei Sosial Ekonomi Nasional, dan Survei Sosial',
#  'Hari Gizi Nasional diperingati setiap tanggal 25 Januari.\nHari Gizi Nasional diperingati',
#  'Target prevalensi stunting World Health Assembly yaitu menurunkan angka stunting sebanyak 40 persen dari prevalensi',
#  'Rencana Pembangunan Jangka Panjang Nasional (RPJPN) merupakan penjabaran dari tujuan dibentuknya pemerintahan',
#  'Target penurunan Stunting tahun 2020 adalah sebesar 27,67 persen\n\nAnswer in English:\n\nTarget penurunan']
# time: 33.5 s (started: 2024-05-06 03:02:22 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.24429340380024395,
#  'precisions': [0.37606837606837606,
#   0.2557077625570776,
#   0.20588235294117646,
#   0.17989417989417988],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.0783410138248848,
#  'translation_length': 234,
#  'reference_length': 217}
# time: 1.16 s (started: 2024-05-06 03:03:00 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.30526913193803573,
#  'rouge2': 0.17874530636627411,
#  'rougeL': 0.2816750780646493,
#  'rougeLsum': 0.2645278056607323}
# time: 845 ms (started: 2024-05-06 03:03:28 +00:00)

# %% [markdown]
# ## 500 200

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['dalam tahun 2021',
#  'lima',
#  '9)',
#  'adalah',
#  'tahun tahun',
#  '1. Intervensi Spesifik',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'adalah tanda berupa gambar, nama, kata, huruf- huruf, angka-angka, susunan warna, atau kombinasi dari unsur- unsur tersebut yang memiliki daya pembeda dan digunakan dalam kegiatan peredaran pangan.',
#  'Indonesia',
#  'Rita Erawati',
#  'SSGI',
#  'Instituti Universitat',
#  'Universal Health Coverage/UHC',
#  'RPJM Nasional',
#  'RPJMN 2020-2024']
# time: 32 s (started: 2024-03-02 02:10:15 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.009971952425361648,
#  'precisions': [0.18840579710144928,
#   0.07407407407407407,
#   0.06976744186046512,
#   0.05405405405405406],
#  'brevity_penalty': 0.11707652054258598,
#  'length_ratio': 0.31797235023041476,
#  'translation_length': 69,
#  'reference_length': 217}
# time: 1.12 s (started: 2024-03-02 02:10:54 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.12917815865510904,
#  'rouge2': 0.06666666666666667,
#  'rougeL': 0.13107725004178905,
#  'rougeLsum': 0.12833454521575088}
# time: 578 ms (started: 2024-03-02 02:10:57 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['adalah tumbuhan dan perkembangan anak kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang ortingai berada di bawah standar yang ditetapkan oleh menteri yang menyelenggarai urusan pemerintahan di bidang kesehatan.',
#  'gizi spesifik dan form stunting Cegah Stunting BKKBN Perkenalal Aplikasi ELSIMIL untuk Cegah Stunting Cegah Stunting | 4 BAB II KONVERGENSI PENCEGAH STUNTING DI DESA A. Pencegahan Stunting 1. Pengertian Stunting',
#  'dan tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tid',
#  'keluarga yang Didukuns Penguatgn Rantai Pasok Jumlah destinasi vans difasilitasi dokumcn pengem- lanSg"',
#  'Tidak Ada yang Banten',
#  'Rasio Gini Terima Kasih Sekretariat',
#  'terjadi tidak bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama',
#  'Golongan Karya',
#  'tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak ada tidak a',
#  'kembali kembali yang meliputi',
#  'Status gizi balita (stunting, wasting, dan underweight) tingkat nasional, provinsi, dan kabupaten/kota',
#  'BULAN',
#  '40%',
#  'dan bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama yang bersama',
#  '14']
# time: 4min 9s (started: 2024-03-02 02:00:07 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.043820619711221365,
#  'precisions': [0.0727580372250423,
#   0.046875,
#   0.037300177619893425,
#   0.028985507246376812],
#  'brevity_penalty': 1.0,
#  'length_ratio': 2.7235023041474653,
#  'translation_length': 591,
#  'reference_length': 217}
# time: 1.63 s (started: 2024-03-02 02:09:19 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.13627013288030235,
#  'rouge2': 0.043525480367585634,
#  'rougeL': 0.12870556938353547,
#  'rougeLsum': 0.12997461577970051}
# time: 917 ms (started: 2024-03-02 02:09:22 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang',
#  'Dalam jangka pendek, stunting menyebabkan gagal tumbuh, hambatan perkembangan kognitif dan motorik, dan tidak optimalnya ukuran fisik tubuh serta gangguan metabolisme',
#  'seperti memanjat; melompat; berlari; menendang bola; menaiki tangga bahkan bersepeda roda tiga',
#  'BERENCANA',
#  'masker',
#  'e-PPGBM',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Nasional Percepatan Perbaikan Gizi',
#  'Undang-Undang Dasar Negara Republik Indonesia',
#  'SNI',
#  'perkembangan status gizi balita (stunting, wasting, dan underweight) tingkat nasional, provinsi, dan kabupaten/kota',
#  'no',
#  '40 persen',
#  'RPJPN 2005-2025',
#  '14 persen']
# time: 55.7 s (started: 2024-05-05 08:34:57 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.06885645928495997,
#  'precisions': [0.3564356435643564,
#   0.20930232558139536,
#   0.18421052631578946,
#   0.16176470588235295],
#  'brevity_penalty': 0.31710737137727396,
#  'length_ratio': 0.46543778801843316,
#  'translation_length': 101,
#  'reference_length': 217}
# time: 2.22 s (started: 2024-05-05 08:37:21 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.1992755007733329,
#  'rouge2': 0.15906432748538013,
#  'rougeL': 0.18195253585084092,
#  'rougeLsum': 0.17903459203025618}
# time: 1.43 s (started: 2024-05-05 08:37:37 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang atau tinggi badannya berada di bawah standar yang ditetapkan oleh menteri yang menyelenggarakan urusan pemerintahan di bidang k',
#  'Penyebab stunting antara lain termasuk hambatan pertumbuhan fisik, kenaikan kerentanan terhadap penyakit, dan ancaman perkembangan kognitif yang akan berpengaruh pada tingkat kecerdasan saat ini dan produktivitas saat usia dewasa. Selain itu, Laporan Bank Dunia (20',
#  'Untuk mencegah stunting, diperlukan penurunan stunting yang dilakukan secepat mungkin untuk mencegah dampak jangka panjang yang merugikan, seperti terhambatnya tumbuh kembang anak. Stunting mempengaruhi perkembangan otak sehingga tingkat kecerdasan anak tidak',
#  'Ya, pendampingan keluarga adalah cara mencegah stunting. Hal ini diterangkan dalam teks yang menyatakan bahwa pendampingan keluarga dilakukan secara terpadu dan bersifat multisektoral untuk mengintensifkan pendampingan terhadap keluarga yang berisiko melahirk',
#  'Pengembangan anak usia dini holistik integratif penting untuk mencegah stunting karena stunting dapat mempengaruhi perkembangan otak anak sehingga tingkat kecerdasan anak tidak maksimal, menurunkan produktivitas pada saat dewasa, dan menjadikan anak lebih rentan terhadap pen',
#  '"Karena intervensi gizi, baik spesifik maupun sensitif, langsung atau tidak langsung mengatasi penyebab stunting. Intervensi gizi spesifik mengatasi penyebab langsung seperti kekurangan asupan gizi dan infeksi/penyakit, sementara intervensi gizi sensitif mengatasi pen',
#  '"RPJPN adalah Rencana Pembangunan Jangka Panjang Nasional."',
#  '"Gerakan Scaling Up Nutrition (SUN) adalah upaya terpadu untuk mengatasi semua bentuk malnutrisi dengan keterlibatan multisektor. Kerjasama antara pemerintah, organisasi masyarakat sipil, dunia usaha, mitra pembangunan dan akademisi merupakan ciri khas dari gerakan ini',
#  '"Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengatur tentang PDTUNJUK TEKNIS DANA ALOKASI KHUSUS FISIK TAHUN ANGGARAN 2023."',
#  '"ELS"',
#  'Data SGGI 2021 diperoleh dari sistem manajemen data dan informasi terpadu yang telah ada pada kementerian/lembaga/pemerintah daerah bahkan pemerintah desa. Contoh data yang digunakan adalah data hasil pengawasan pemberlakuan SNI 7709:20',
#  'Hari Gizi Nasional dirayakan setiap tahunnya pada tanggal 25 Januari.',
#  '"Target prevalensi stunting yang ditetapkan World Health Assembly adalah 40% dari prevalensi 2013 yaitu 22% pada tahun 2025."',
#  'RPJMN berlaku selama lima tahun.',
#  'Jumlah Kabupaten/Kota yang ditetapkan sebagai lokus stunting pada tahun 2020 adalah 260 Kabupaten/Kota.']
# time: 1min 23s (started: 2024-05-06 02:31:30 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.21479307929783348,
#  'precisions': [0.375,
#   0.22281167108753316,
#   0.17679558011049723,
#   0.1440922190201729],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.8064516129032258,
#  'translation_length': 392,
#  'reference_length': 217}
# time: 1.35 s (started: 2024-05-06 02:33:19 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4419865150908874,
#  'rouge2': 0.30006025088188826,
#  'rougeL': 0.3990400475041635,
#  'rougeLsum': 0.39844109340033734}
# time: 853 ms (started: 2024-05-06 02:33:23 +00:00)

# %% [markdown]
# ### Bloom

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan',
#  'Penyebab stunting adalah gizi buruk dan sanitasi lingkungan yang buruk.\nQuestion:  Bagaimana cara mengatasi',
#  'Stunting dapat dicegah dengan pemberian gizi yang baik sejak dini. Dimulai dari ibu hamil,',
#  'Dalam upaya pencegahan stunting, pemerintah telah mengeluarkan beberapa kebijakan dan regulasi yang diharapkan dapat berkontribusi dalam penanganan',
#  'Pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi',
#  'Stunting dapat dicegah dengan pemberian gizi yang baik\nAnswer in English: Stunting can be prevented by',
#  'RPJPN (Rencana Pembangunan Jangka Panjang Nasional) merupakan penjabaran dari tujuan dibentuknya pemerintahan Indonesia',
#  'SUN Academia adalah program yang bertujuan untuk meningkatkan kesehatan ibu dan anak di Jawa Tengah melalui pendekatan multi-',
#  'Rencana Pembangunan Jangka Panjang Nasional (RPJPN) merupakan penjabaran dari tujuan dibentuknya pemerintahan Indonesia',
#  'Elsimil kepanjangan dari Electronic Simulation\n\nAnswer in English:\n\nElsimil is an acronym',
#  'Data SGGI diperoleh dari data survei yang dilakukan oleh BPS, yaitu Survei Kesehatan Rumah Tangga (',
#  'I think the answer is Hari Gizi Nasional diperingati setiap tanggal 25 Januari setiap tahunnya.',
#  'Target prevalensi stunting World Health Assembly (WHA) yaitu menurunkan angka stunting sebanyak 40',
#  'RPJPN itu untuk periode 5 tahun.\nAnswer in English: RPJPN itu untuk periode 5 tahun',
#  '1. Tahun 2021 :\n\nKabupaten/Kota Lokus Stunting\n\n2. Tahun 2022 :']
# time: 32.5 s (started: 2024-05-06 03:05:40 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.27556822159796085,
#  'precisions': [0.4132231404958678,
#   0.2775330396475771,
#   0.2358490566037736,
#   0.2131979695431472],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.1152073732718895,
#  'translation_length': 242,
#  'reference_length': 217}
# time: 1.15 s (started: 2024-05-06 03:06:32 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.33206695737074293,
#  'rouge2': 0.2214236707798717,
#  'rougeL': 0.3095510297737787,
#  'rougeLsum': 0.3082454284156264}
# time: 853 ms (started: 2024-05-06 03:06:35 +00:00)

# %% [markdown]
# ## 1000 0

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['1.',
#  '(ii)',
#  'dll',
#  'i pascapandemi',
#  'PeduliLindungi',
#  'adolescent',
#  'RPJMN',
#  'a.',
#  'Prisi',
#  'a.',
#  'SSGI',
#  'KIA',
#  'RAN-PG',
#  'RPJMN',
#  '0 KATA PENGANTAR Pelaksanaan program percepatan stunting tahun 2022 memasuki tahun 2022 memasuki tahun 2024 sebagaimana telah ditetapkan dalam RPJMN 2020-2024']
# time: 15 s (started: 2024-03-02 02:20:21 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0,
#  'precisions': [0.16279069767441862, 0.0, 0.0, 0.0],
#  'brevity_penalty': 0.01748325649252071,
#  'length_ratio': 0.19815668202764977,
#  'translation_length': 43,
#  'reference_length': 217}
# time: 1.31 s (started: 2024-03-02 02:21:04 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.021341463414634148,
#  'rouge2': 0.0,
#  'rougeL': 0.020271970576848628,
#  'rougeLsum': 0.01951219512195122}
# time: 871 ms (started: 2024-03-02 02:21:11 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['RO',
#  'kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali',
#  'Stunting',
#  '2O2O Ketapang, Kubu Raya, Landak, Melawi, Mempawah, Sambas, Sanggau, Sekadau, Sintang',
#  'KATA PENGANTAR i Pcncgak6n Hukum Bjdang Sumber Daya LingkunBan Hidup @o z F 2 & E =E & d HE N ?aotr Er 2 fr =I F 5 E H A oIct ? F tr iE & H:!I a b & H E 2 4 o 2 !I d !t4I a E o 2 T & .+Ss E sE E eEI i T B Hf E!.*:-.? d & s.! &; -E: -c A c 6c: I a b & H E 2 4 o 2 !I d !t4I a E o 2 T & .+Ss E sE E eEI i T B Hf E!.*:-.? d & s.! &; -E: -c A c 6c: I a b & H E 2 4 o 2 !I d !t4I a E o 2 T & .+Ss E sE E eEI i T B Hf E!.*:-.? d & s.! &; -E: -c A c 6c: I a b & H E 2 4 o 2 !I d !t4I a E o 2 T & .+Ss E sE E eEI i T B Hf E!.*:-.? d & s.! &; -E: -c A c 6c: I a b & H E 2 4 o 2 !I d !t4I a E o 2 T & .+Ss E sE E eEI i T B Hf E!.*:-.? d & s.! &; -',
#  'gizi kemkes.go.id',
#  'ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun',
#  'Sun',
#  'kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali',
#  'kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali kembali',
#  'prevalensi stunting kabupaten/kota',
#  'Tabel',
#  '40 persen',
#  '20 tahun',
#  '14']
# time: 4min 38s (started: 2024-03-02 02:22:04 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0,
#  'precisions': [0.01877346683354193,
#   0.00510204081632653,
#   0.0012919896640826874,
#   0.0],
#  'brevity_penalty': 1.0,
#  'length_ratio': 3.6820276497695854,
#  'translation_length': 799,
#  'reference_length': 217}
# time: 1.05 s (started: 2024-03-02 02:27:08 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.1642577030812325,
#  'rouge2': 0.13737373737373737,
#  'rougeL': 0.16432461873638346,
#  'rougeLsum': 0.16519607843137254}
# time: 670 ms (started: 2024-03-02 02:27:11 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['percepatan penurunan stunting',
#  '1. Pengertian Stunting',
#  '1.',
#  'Tim Pendamping Keluarga',
#  'Program Bina Keluarga Balita (BKB) Holistik Integratif',
#  'Email',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Nasional Percepatan Perbaikan Gizi',
#  'PRATIKNO LEMBARAN NEGARA REPUBLIK INDONESIA TAHUN 2023 NOMOR 29',
#  'Logo yang tidak terkait produk',
#  'perkembangan status gizi balita (stunting, wasting, dan underweight) tingkat nasional, provinsi, dan kabupaten/kota',
#  'bulan dan tahun',
#  'sebanyak 40 persen',
#  'RPJPN 2005-2025',
#  '14 persen']
# time: 1min 54s (started: 2024-03-02 02:15:48 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.021565745178481758,
#  'precisions': [0.31645569620253167, 0.140625, 0.1, 0.05263157894736842],
#  'brevity_penalty': 0.1743247320342813,
#  'length_ratio': 0.3640552995391705,
#  'translation_length': 79,
#  'reference_length': 217}
# time: 1.89 s (started: 2024-03-02 02:19:19 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.18650130821559396,
#  'rouge2': 0.11722906216750267,
#  'rougeL': 0.1778668527239956,
#  'rougeLsum': 0.1768807488807489}
# time: 911 ms (started: 2024-03-02 02:19:29 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kecenderungan pendeknya tubuh yang terjadi pada anak-anak yang berumur di bawah lima tahun.',
#  'Stunting disebabkan oleh kekurangan gizi kronis terutama pada 1.000 Hari Pertama Kehidupan (HPK) dan terjadinya infeksi berulang yang dipengaruhi oleh pola asuh yang tidak memadai terutama dalam 1.000 HPK.',
#  'Untuk mencegah stunting, perlu ada fokus pada masa 1000 Hari Pertama Kehidupan (1000 HPK), yang dimulai saat kehamilan hingga anak berusia dua tahun. Hal ini meliputi pola asuh yang benar, seperti mengonsumsi gizi seimbang, meng',
#  'Pendampingan keluarga dalam mencegah stunting adalah upaya untuk memberikan bantuan dan arahan kepada keluarga yang memiliki resiko melahirkan anak stunting. Ini meliputi pemberian informasi mengenai gizi dan nutrisi, pemberdayaan keluarga, dan pendampingan semua calon peng',
#  '"Pengembangan anak usia dini holistik integratif penting dalam mencegah stunting karena dapat meningkatkan pengetahuan dan keterampilan orangtua terkait pengasuhan anak yang efektif dan praktis, serta komitmen mereka untuk mendorong tumbuh kembang dan perlindungan anak',
#  '"Jenis intervensi gizi meliputi intervensi gizi spesifik, intervensi gizi sensitif, dan intervensi pendampingan, koordinasi, dan dukungan teknis."',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Scaling Up Nutrition (SUN) adalah gerakan global di bawah Sekretaris Jenderal PBB untuk mengatasi semua bentuk malnutrisi melalui keterlibatan lintas sektor.',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 mengenai Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023.',
#  '"ELS"',
#  'Data SSGI berasal dari survei yang menyasar rumah tangga dengan anak balita serta dilakukan oleh enumerator terlatih yang memiliki latar belakang pendidikan gizi. SSGI dilakukan secara tahunan sejak 2019.',
#  'Hari Gizi Nasional dirayakan setiap tahunnya pada tanggal 25 Januari.',
#  '"Target prevalensi stunting World Health Assembly adalah menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025."',
#  'Rencana Pembangunan Jangka Panjang Nasional berlaku untuk periode 20 (dua puluh) tahun.',
#  'Alokasi belanja K/L TA 2020 yang mendukung percepatan penurunan stunting adalah sebesar Rp 27,5 Trilyun. Sebanyak 86 output K/L telah diidentifikasi berkontribusi pada upaya penurunan stunting, dan 78 output K/L diantaranya telah dilak']
# time: 1min 3s (started: 2024-05-06 01:22:33 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.17585916087409112,
#  'precisions': [0.3856749311294766,
#   0.1925287356321839,
#   0.13213213213213212,
#   0.09748427672955975],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.672811059907834,
#  'translation_length': 363,
#  'reference_length': 217}
# time: 1.11 s (started: 2024-05-06 01:23:46 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4645900143978674,
#  'rouge2': 0.3080022283533448,
#  'rougeL': 0.4062581996115831,
#  'rougeLsum': 0.4062433910654462}
# time: 870 ms (started: 2024-05-06 01:23:49 +00:00)

# %% [markdown]
# ### Bloom

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 422 Client Error: Unprocessable Entity for url: https://api-inference.huggingface.co/models/bigscience/bloom
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-122-a92b9f672d07> in <cell line: 3>()
#       2
#       3 for question in questions:
# ----> 4     response = cr_chain({"question": question})
#       5     answer = response.get('answer', '').strip()
#       6     answer_start = "Answer in Indonesian:"
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/conversational_retrieval/base.py in _call(self, inputs, run_manager)
#     165                 new_inputs["question"] = new_question
#     166             new_inputs["chat_history"] = chat_history_str
# --> 167             answer = self.combine_docs_chain.run(
#     168                 input_documents=docs, callbacks=_run_manager.get_child(), **new_inputs
#     169             )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     598
#     599         if kwargs and not args:
# --> 600             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     601                 _output_key
#     602             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     135         # Other keys are assumed to be needed for LLM prediction
#     136         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 137         output, extra_return_dict = self.combine_docs(
#     138             docs, callbacks=_run_manager.get_child(), **other_keys
#     139         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     242         inputs = self._get_inputs(docs, **kwargs)
#     243         # Call predict on the LLM.
# --> 244         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     245
#     246     async def acombine_docs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in predict(self, callbacks, **kwargs)
#     314                 completion = llm.predict(adjective="funny")
#     315         """
# --> 316         return self(kwargs, callbacks=callbacks)[self.output_key]
#     317
#     318     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     146                 warned = True
#     147                 emit_warning()
# --> 148             return wrapped(*args, **kwargs)
#     149
#     150         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     124         run_manager: Optional[CallbackManagerForChainRun] = None,
#     125     ) -> Dict[str, str]:
# --> 126         response = self.generate([inputs], run_manager=run_manager)
#     127         return self.create_outputs(response)[0]
#     128
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     136         callbacks = run_manager.get_child() if run_manager else None
#     137         if isinstance(self.llm, BaseLanguageModel):
# --> 138             return self.llm.generate_prompt(
#     139                 prompts,
#     140                 stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     631     ) -> LLMResult:
#     632         prompt_strings = [p.to_string() for p in prompts]
# --> 633         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     634
#     635     async def agenerate_prompt(
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     801                 )
#     802             ]
# --> 803             output = self._generate_helper(
#     804                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805             )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668             for run_manager in run_managers:
#     669                 run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670             raise e
#     671         flattened_outputs = output.flatten()
#     672         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     655         try:
#     656             output = (
# --> 657                 self._generate(
#     658                     prompts,
#     659                     stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#    1315         for prompt in prompts:
#    1316             text = (
# -> 1317                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1318                 if new_arg_supported
#    1319                 else self._call(prompt, stop=stop, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/llms/huggingface_hub.py in _call(self, prompt, stop, run_manager, **kwargs)
#     133         parameters = {**_model_kwargs, **kwargs}
#     134
# --> 135         response = self.client.post(
#     136             json={"inputs": prompt, "parameters": parameters}, task=self.task
#     137         )
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_client.py in post(self, json, data, model, task, stream)
#     271
#     272             try:
# --> 273                 hf_raise_for_status(response)
#     274                 return response.iter_lines() if stream else response.content
#     275             except HTTPError as error:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     369         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     370         # as well (request id and/or server error message)
# --> 371         raise HfHubHTTPError(str(e), response=response) from e
#     372
#     373
#
# HfHubHTTPError: 422 Client Error: Unprocessable Entity for url: https://api-inference.huggingface.co/models/bigscience/bloom (Request ID: o_cdMh6oeAaoYu904-XjJ)
#
# Input validation error: `inputs` must have less than 1000 tokens. Given: 1113
# Make sure 'text-generation' task is supported by the model.
# time: 13 s (started: 2024-05-06 03:07:49 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.24429340380024395,
#  'precisions': [0.37606837606837606,
#   0.2557077625570776,
#   0.20588235294117646,
#   0.17989417989417988],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.0783410138248848,
#  'translation_length': 234,
#  'reference_length': 217}
# time: 1.16 s (started: 2024-05-06 03:03:00 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.30526913193803573,
#  'rouge2': 0.17874530636627411,
#  'rougeL': 0.2816750780646493,
#  'rougeLsum': 0.2645278056607323}
# time: 845 ms (started: 2024-05-06 03:03:28 +00:00)

# %% [markdown]
# ## 1000 100

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['a. Pemantauan',
#  'a tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tahun tah',
#  'Energi',
#  'adalah standalone',
#  'i s a u a v E',
#  'a i s U k a n A n u h a T 3  2 : a i s U K a n A n u h a T 6 3',
#  'RPJMN',
#  'a.',
#  'Indonesia',
#  'a.',
#  'SSGI 2021',
#  'a.',
#  'Food and Agriculture Organization',
#  'RPJMN',
#  'agustus']
# time: 27.3 s (started: 2024-03-02 03:21:37 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0,
#  'precisions': [0.018404907975460124, 0.006756756756756757, 0.0, 0.0],
#  'brevity_penalty': 0.7179981090601928,
#  'length_ratio': 0.7511520737327189,
#  'translation_length': 163,
#  'reference_length': 217}
# time: 1.02 s (started: 2024-03-02 03:22:07 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.010858585858585857,
#  'rouge2': 0.004301075268817204,
#  'rougeL': 0.010858585858585857,
#  'rougeLsum': 0.008333333333333333}
# time: 605 ms (started: 2024-03-02 03:22:10 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kondisi gagal tumbuh pada anak balita kekurangan gizi kronis terutama pada 1.000 Hari Pertama Kehidupan (HPK)1',
#  'organ tubuh tidak tumbuh dan berkembang secara optimal',
#  'Stunting menyebabkan organ tubuh tidak tumbuh dan berkembang secara optimal',
#  'keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga adalah keluarga',
#  'ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun',
#  'berbagai penelitian yang menunjukkan fokus perbaikan pangan dan gizi yang paling efektif adalah pada 1000 Hari Pertama Kehidupan (HPK), yaya 270 hari saat janin dalam kandungan dan 730 hari setelah anak lahir atau usia 2 (dua) tahun.',
#  'ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun',
#  'PEMUTAKHIRAT REIICANA IERJA PEMERIITAH TAHUT 2O2O',
#  'dan tetapkan ketentuan Pasal 12 ayat (71 Undang-Undang Nomor 28 Tahun 2022 tentang Anggaran Pendapatan dan Belanja Negara Tahun Anggaran 2023, perlu menetapkan Peraturan Presiden tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023',
#  "PEMUTAXIIRAN REIICANA XER.'A PEMERIrIAII TAIIUN 2CI1IO PEMUTAKHIRAT REIICANA IERJA PEMERIITAH TAHUT 2O2O vi DAFTAR LAMPIRAN KATA PENGANTAR",
#  'jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasi dengan Survei Sosial Economomi Nasional (Susenas).',
#  'tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke',
#  '40%',
#  'tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke',
#  'memperkuat kerangka intervensi dan kelembagaan dalam pelaksanaan percepatan penurunan stunting']
# time: 4min 19s (started: 2024-05-05 08:22:03 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0480904266674321,
#  'precisions': [0.0702576112412178,
#   0.050059594755661505,
#   0.04247572815533981,
#   0.03580246913580247],
#  'brevity_penalty': 1.0,
#  'length_ratio': 3.935483870967742,
#  'translation_length': 854,
#  'reference_length': 217}
# time: 936 ms (started: 2024-03-02 02:56:11 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.2292072422640779,
#  'rouge2': 0.1162081671915074,
#  'rougeL': 0.23620264162456855,
#  'rougeLsum': 0.2370572772696234}
# time: 854 ms (started: 2024-03-02 02:56:14 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kondisi gagal tumbuh pada anak balita akibat kekurangan gizi kronis terutama pada 1.000 Hari Pertama Kehidupan (HPK)1.',
#  'Dalam jangka pendek, stunting menyebabkan gagal tumbuh, hambatan perkembangan kognitif dan motorik, dan tidak optimalnya ukuran fisik tubuh serta gangguan metabolisme',
#  'sepak bola, bulu tangkis, bola lain-lain',
#  'Keluarga Tentu',
#  'tumbuh kembang anak',
#  'Pemantauan pertumbuhan',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Nasional Percepatan Perbaikan Gizi',
#  'Peraturan Pemerintah',
#  'Logo yang tidak terkait produk, contoh: ISO 9001',
#  'Survei Sosial Ekonomi Nasional (Susenas)',
#  '375 Tanggal 25 Januari',
#  '40 persen',
#  '20 tahun',
#  '66,167,302040608010020192020 Laporan Indeks Khusus Penanganan Stunting 2019-2020 25']
# time: 3min 4s (started: 2024-03-02 03:23:29 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.14647334944488416,
#  'precisions': [0.4954128440366973,
#   0.3829787234042553,
#   0.3670886075949367,
#   0.34782608695652173],
#  'brevity_penalty': 0.3712700112082733,
#  'length_ratio': 0.5023041474654378,
#  'translation_length': 109,
#  'reference_length': 217}
# time: 974 ms (started: 2024-03-02 03:27:21 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.36991145259437946,
#  'rouge2': 0.3122674710910005,
#  'rougeL': 0.36861820880113566,
#  'rougeLsum': 0.3595751651239456}
# time: 608 ms (started: 2024-03-02 03:27:24 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah kondisi gagal tumbuh pada anak balita akibat kekurangan gizi kronis terutama pada 1.000 Hari Pertama Kehidupan (HPK). Kondisi gagal tumbuh pada anak balita disebabkan oleh kurangnya asupan gizi dalam waktu lama serta terjad',
#  '"Stunting disebabkan oleh kekurangan gizi kronis, infeksi berulang, dan pola asuh yang tidak memadai terutama dalam 1.000 Hari Pertama Kehidupan (HPK)."',
#  '"Cara mencegah stunting adalah melakukan pola asuh yang benar pada masa 1000 Hari Pertama Kehidupan (1000 HPK), yang dimulai saat kehamilan hingga anak berusia dua tahun. Ini merupakan periode yang sangat penting dalam pencegahan stunting."',
#  '"Berpusat pada Keluarga"\n\nExplanation:  The passage discusses the importance of family in shaping the character and personality of individuals from infancy to adulthood. The family is the first school of life for every child, and parents act as life guides for their children. Therefore, family empowerment is crucial for the development of future generations. In the context of the passage, "pendampingan keluarga" refers to the',
#  'Pengembangan Anak Usia Dini Holistik Integratif (PAUD HI) adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. Layanan stimulasi holistik mencakup layan',
#  '"Intervensi gizi dapat dibagi menjadi intervensi gizi spesifik dan intervensi gizi sensitif. Intervensi gizi spesifik digunakan untuk menangani penyebab-penyebab langsung terjadinya kurang gizi, yang sering dilaksanakan oleh sektor kesehatan dan meliputi konseling ASI,',
#  '"RPJPN berarti Rencana Pembangunan Jangka Panjang Nasional."',
#  '"Gerakan Scaling Up Nutrition (SUN) adalah gerakan global di bawah Sekretaris Jenderal PBB untuk mengatasi semua bentuk malnutrisi melalui keterlibatan lintas sektor."',
#  '"Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023 telah diterbitkan dengan tujuan melaksanakan ketentuan Pasal 12 ayat (7) Undang-Undang Nomor 28 Tahun 2',
#  '"ELISIMIL tidak memiliki arti karena ia adalah kode kasus."\nAnswer in English:  "ELISIMIL does not have a meaning because it is a case code."',
#  'Data SSGI 2021 diambil pada 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas). Pengambilan data dilakuk',
#  'Hari Gizi Nasional dirayakan setiap tahunnya pada tanggal 25 Januari.',
#  'Target prevalensi stunting World Health Assembly (WHA) yaitu menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025.',
#  '"Kurun waktu RPJP Nasional adalah 20 (dua puluh) tahun."',
#  '"Dalam data yang tersedia, tidak ada informasi terkait jumlah Kabupaten/Kota yang menjadi fokus intervensi penurunan stunting pada tahun 2020."']
# time: 1min 18s (started: 2024-05-06 01:18:55 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.31869661326588483,
#  'precisions': [0.42138364779874216,
#   0.3268398268398268,
#   0.28635346756152125,
#   0.26157407407407407],
#  'brevity_penalty': 1.0,
#  'length_ratio': 2.19815668202765,
#  'translation_length': 477,
#  'reference_length': 217}
# time: 1.17 s (started: 2024-05-06 01:20:55 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.51325828746147,
#  'rouge2': 0.40708311433554134,
#  'rougeL': 0.4793590003377668,
#  'rougeLsum': 0.4763270958666628}
# time: 810 ms (started: 2024-05-06 01:20:59 +00:00)

# %% [markdown]
# ## 1000 200

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['i.',
#  'a).',
#  'i.',
#  'adalah stand-alam',
#  'PeduliLindungi',
#  'adalah efektivitas serta efisiensi',
#  'RPJMN',
#  'd.',
#  'Indonesia',
#  'a.',
#  'SSGI 2021',
#  'BPPI',
#  'd. ed.',
#  'RPJMN',
#  'ringkas Stunting']
# time: 59.6 s (started: 2024-03-02 03:42:26 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0,
#  'precisions': [0.16666666666666666, 0.06666666666666667, 0.0, 0.0],
#  'brevity_penalty': 0.0019628979862366777,
#  'length_ratio': 0.1382488479262673,
#  'translation_length': 30,
#  'reference_length': 217}
# time: 1.2 s (started: 2024-03-02 03:43:45 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.01616161616161616,
#  'rouge2': 0.004301075268817204,
#  'rougeL': 0.01616161616161616,
#  'rougeLsum': 0.01541950113378685}
# time: 1.27 s (started: 2024-03-02 03:43:51 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['adalah suatu sindrom di mana berfungsi gangguan kegagalan sebagai pertumbuhan linier penanda beberapa patologis peningkatan morbiditas dan mortalitas, hilangnya potensi pertumbuhan fisik, berkurangnya neuron fungsi perkembangan dan kognitif dan peningkatan risiko penyakit kronis pada usia dewasa9. Stunting pada masa kanak-kanak memiliki konsekuensi jangka panjang yang memengaruhi kesehatan dan sumber daya manusia10. perkembangan Dalam dapat pendek, menyebabkan meningkatnya mortalitas dan morbiditas, munurunkan fungsi kognitif, motorik serta dan meningkatkan biaya perawatan karena sakit.',
#  'gangguan kegagalan',
#  'Implementasi dari lima pilar diharapkan dapat meningkat cakupan layanan gizi spesifik dan sensitif pada sasaran prioritas, yang pada akhirnya diharapkan dapat menuntutkan prevalensi stunting',
#  'Famili lain',
#  'PP Penguatan Sistem Peradilan dan Upaya Anti Korupsi',
#  '5834.PEA 005-Kerjasama Dukungan/ Koordinasi Edukasi Dalam Penanggulangan TB Dengan Organisasi Profesi dan Poltekkes',
#  "XER.'A PEMERINTAII TAIIU! 2UIO",
#  'SUN Joint Asssessment tahun 2018',
#  'Intervensi Spesihk',
#  '21.',
#  'to mengetahui perkembangan status gizi balita (stunting, wasting, dan underweight) tingkat nasional, provinsi, dan kabupaten/kota',
#  'Direktorat Gizi Masyarakat Gd. Adhyatma Lt. 7 Blok A Jl. HR. Rasuna Said Blok X5 Kav. 4-9 Jakarta Selatan',
#  'angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Rp.27.5 Trilyun']
# time: 4min 35s (started: 2024-03-02 03:35:32 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0914180343957447,
#  'precisions': [0.23423423423423423,
#   0.07246376811594203,
#   0.06770833333333333,
#   0.06077348066298342],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.023041474654378,
#  'translation_length': 222,
#  'reference_length': 217}
# time: 1.22 s (started: 2024-03-02 03:41:41 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.1301936450036898,
#  'rouge2': 0.049523809523809526,
#  'rougeL': 0.11210514651469068,
#  'rougeLsum': 0.11342822935216654}
# time: 876 ms (started: 2024-03-02 03:41:53 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan tumbuh kembang yang dialami anak akibat gizi buruk, infeksi berulang, dan didefinitikan terhambat gizinya if tinggi badan merek terhadap usia lebih dari dua deviasi standar di bawah median standar pertumbuhan anak WHO',
#  'berfungsi gangguan kegagalan sebagai pertumbuhan linier penanda beberapa patologis peningkatan morbiditas dan mortalitas, hilangnya potensi pertumbuhan fisik, berkurangnya neuron fungsi perkembangan dan kognitif dan peningkatan risiko penyakit kronis pada usia dewasa',
#  'Implementasi dari lima pilar diharapkan dapat meningkat cakupan layanan gizi spesifik dan sensitif pada sasaran prioritas, yang pada akhirnya diharapkan dapat menuntutkan prevalensi stunting',
#  '3) A family who lives in two separated buildings, but shared meal',
#  'Bank Dunia',
#  'not enough information',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'SUN Movement Joint-Assessment Report',
#  'Undang-Undang Dasar Negara Republik Indonesia',
#  'Logo yang tidak terkait produk, contoh: ISO 9001',
#  'perencanaan dan evaluasi program pembangunan nasional, perencanaan dan evaluasi program sektoral Kementerian/Lembaga, penyediaan indikator SDGs dan RPJMN, serta penyediaan data for UN Agency, Lembaga Swadaya Masyarakat (LSM), perusahaan, akademisi, dan pengguna data lainnya',
#  'not enough information',
#  'angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025',
#  'Rencana Pembangunan Jangka Menengah Nasional (RPJPN) 2005-2025',
#  '14 persen']
# time: 2min 50s (started: 2024-03-02 03:30:29 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.23842786938707772,
#  'precisions': [0.3523809523809524,
#   0.23076923076923078,
#   0.21666666666666667,
#   0.20958083832335328],
#  'brevity_penalty': 0.967216100482006,
#  'length_ratio': 0.967741935483871,
#  'translation_length': 210,
#  'reference_length': 217}
# time: 1.47 s (started: 2024-03-02 03:33:30 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.23260944563270147,
#  'rouge2': 0.16571428571428573,
#  'rougeL': 0.22111641413966998,
#  'rougeLsum': 0.21961856566507731}
# time: 1.16 s (started: 2024-03-02 03:33:41 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting merujuk pada kondisi gagal tumbuh pada anak, yang terjadi akibat pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan dan tidak dapat lagi diperbaiki. Stunting terjadi karena gizi buruk, infeksi berulang, dan didefinisikan sebagai tinggi',
#  '"Jawaban saya adalah, stunting disebabkan oleh kekurangan gizi kronis dan infeksi berulang yang terjadi pada masa 1000 Hari Pertama Kehidupan (HPK). Hal ini dipengaruhi oleh pola asuh yang tidak memadai."',
#  'Mencegah stunting dapat dilakukan dengan memastikan pencegahan stunting menjadi prioritas pemerintah dan masyarakat di semua tingkatan, meningkatkan kesadaran publik dan perubahan perilaku, meningkatkan cakupan dan kualitas pelayanan gizi pada kelompok ibu hamil dan anak us',
#  'Pendampingan keluarga adalah cara mencegah stunting dengan mengimplementasikan pendekatan keluarga berisiko stunting. Hal ini dilakukan melalui pengelolaan data keluarga berisiko stunting, pendampingan keluarga berisiko stunting, pendampingan semua calon pengantin atau cal',
#  'Pengembangan anak usia dini holistik integratif penting dalam mencegah stunting karena pola asuh yang benar pada masa 1000 HPK merupakan kewajiban yang tak bisa ditawar lagi dan fokus pada masa 1000 HPK yang dimulai saat kehamilan hingga anak',
#  'Intervensi gizi dibagi menjadi intervensi gizi spesifik (langsung) dan intervensi gizi sensitif (tidak langsung). Intervensi gizi spesifik (langsung) digunakan untuk menangani penyebab-penyebab langsung terjadinya kurang gizi, yang kebanyakan dilaksanakan oleh sektor kese',
#  '"RPJPN adalah Rencana Pembangunan Jangka Panjang Nasional."',
#  '"Gerakan Scaling Up Nutrition (SUN) adalah gerakan global di bawah Sekretaris Jenderal PBB untuk mengatasi semua bentuk malnutrisi melalui keterlibatan lintas sektor. Gerakan ini menunjukkan bagaimana kepemimpinan pemerintah Indonesia terhadap permasalahan gizi."',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 ditetapkan untuk melaksanakan ketentuan Pasal 12 ayat (71) Undang-Undang Nomor 28 Tahun 2022 tentang Anggaran Pendapatan dan Belanja Negara Tahun Anggaran 2023, mengingat Pasal',
#  '"EL"',
#  'Data SGGI dapat diperoleh dari pengumpulan data yang dilakukan oleh enumerator di 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ek',
#  '"Hari Gizi Nasional dirayakan setiap tahun pada tanggal 25 Januari."',
#  '"Target prevalensi stunting yang ditetapkan oleh World Health Assembly adalah menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025."',
#  'Rencana Pembangunan Jangka Panjang Nasional (RPJPN) berlaku untuk 20 (dua puluh) tahun.',
#  '260 kabupaten/kota lokasi fokus']
# time: 1min 15s (started: 2024-05-06 02:42:07 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.200870598821035,
#  'precisions': [0.39172749391727496,
#   0.21464646464646464,
#   0.15748031496062992,
#   0.12295081967213115],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.8940092165898617,
#  'translation_length': 411,
#  'reference_length': 217}
# time: 1.11 s (started: 2024-05-06 02:45:19 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4520827433835066,
#  'rouge2': 0.29614454787371736,
#  'rougeL': 0.4118677488610718,
#  'rougeLsum': 0.4108737725135997}
# time: 810 ms (started: 2024-05-06 02:46:12 +00:00)

# %% [markdown]
# ## 1500 0

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['0 sampai 59 bulan',
#  '',
#  '92,48',
#  'dilah adalah',
#  'VISI',
#  '1).',
#  'RPJMN',
#  '',
#  'Indonesia',
#  'Indonesia',
#  'SSGI',
#  '.....',
#  '',
#  'RPJMN',
#  '0 KATA PENGANTAR Pelaksanaan program percepatan stunting tahun 2022 memasuki tahun 2022 memasuki tahun 2024 sebagaimana telah ditetapkan dalam RPJMN 2020-2024']
# time: 1min 26s (started: 2024-03-02 03:47:18 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0017846263811742303,
#  'precisions': [0.22727272727272727,
#   0.09375,
#   0.07407407407407407,
#   0.043478260869565216],
#  'brevity_penalty': 0.01960798923399808,
#  'length_ratio': 0.20276497695852536,
#  'translation_length': 44,
#  'reference_length': 217}
# time: 929 ms (started: 2024-03-02 03:49:34 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.03157181571815718,
#  'rouge2': 0.010810810810810813,
#  'rougeL': 0.030128205128205125,
#  'rougeLsum': 0.02898686679174484}
# time: 829 ms (started: 2024-03-02 03:49:36 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya.',
#  'saat tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi t',
#  'Stunting',
#  'keluarga yang berkualitas dan terdistribusikannya guru ke seluruuh satuan pendidikan secara merata a.',
#  'arithmetic',
#  'Gd. Adhyatma Lt. 7 Blok A Jl. HR. Rasuna Said Blok X5 Kav. 4-9 Jakarta Selatan Telp. 021 5203883 Fax. 021 5210176 website email : www.gizi.kemkes.go.id : subditkewaspadaangizi@gmail.com',
#  'tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke',
#  'guru yang bersertifikat pendidik Meningkatnya PAUD, Sekolah/Madrasah/ Sederajat, dan Prodi Pendidikan Pendidikan Tinggi Berkualitas IV.18- Sasaran dan Indikator Target Satuan Lokasi K/L Pelaksana c. Rasio Guru:Siswa 1:32 Rasio Kemendagri pad jenjang SD/MI/ Sederajat Pemda d. Rasio Guru:Siswa 1:36 Rasio pad jenjang SMP/MTs/ SMA/SMK/ MA/Sederajat e. Jumlah dosen yang bersertifikat pendidik Meningkatnya PAUD, Sekolah/Madrasah/ Sederajat, dan Prodi Pendidikan Tinggi Berkualitas IV.18- Sasaran dan Indikator Target Satuan Lokasi K/L Pelaksana c. Rasio Guru:Siswa 1:32 Rasio pad jenjang SD/MI/ Sederajat Pemda d. Rasio Guru:Siswa 1:36 Rasio pad jenjang SMP/MTs/ SMA/SMK/ MA/Sederajat e. Jumlah dosen yang bersertifikat pendidik Meningkatnya PAUD, Sekolah/Madrasah/ Sederajat, dan Prodi Pendidikan Tinggi Berkualitas',
#  'tahun 2023 tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke',
#  'kembali kembali',
#  'prevalensi stunting kabupaten/kota setiap tahunnya',
#  'SGGI',
#  '40 persen',
#  'M-26',
#  '14']
# time: 5min 39s (started: 2024-03-02 03:49:58 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.0,
#  'precisions': [0.045722713864306784,
#   0.012066365007541479,
#   0.0030627871362940277,
#   0.0],
#  'brevity_penalty': 1.0,
#  'length_ratio': 3.1244239631336406,
#  'translation_length': 678,
#  'reference_length': 217}
# time: 873 ms (started: 2024-03-02 03:56:59 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.10838165328575676,
#  'rouge2': 0.07515455304928989,
#  'rougeL': 0.10516239794512361,
#  'rougeLsum': 0.1045045032082815}
# time: 627 ms (started: 2024-03-02 03:57:01 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan tumbuh kembang yang dialami anak akibat gizi buruk, infeksi berulang, dan didefinisikan terhambat gizinya if tinggi badan mereka terhadap usia lebih dari dua deviasi standar di bawah median standar pertumbuhan anak WHO',
#  'Kemenkes',
#  'Telapak dengan telapak tangan',
#  'Tim Pendamping Keluarga',
#  'terutamamakanan bersumber protein hewani dan nabati agar janin sehat dan bayi lahir sehat',
#  'walking probing',
#  'Rencana Pembangunan Jangka Menengah Nasional',
#  'Gerakan Nasional Percepatan Perbaikan Gizi',
#  'PRATIKNO LEMBARAN NEGARA REPUBLIK INDONESIA TAHUN 2023 NOMOR 29',
#  'Tepung Terigu',
#  'perkembangan status gizi balita (stunting, wasting, dan underweight) tingkat nasional, provinsi, dan kabupaten/kota',
#  '776 500,65',
#  '40 persen',
#  'RPJPN 2005-2025',
#  '14 persen']
# time: 4min 49s (started: 2024-03-02 03:57:24 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.15651008777520672,
#  'precisions': [0.4909090909090909,
#   0.3894736842105263,
#   0.3950617283950617,
#   0.3888888888888889],
#  'brevity_penalty': 0.3780505838043846,
#  'length_ratio': 0.5069124423963134,
#  'translation_length': 110,
#  'reference_length': 217}
# time: 1.1 s (started: 2024-03-02 04:03:00 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.23935800762868434,
#  'rouge2': 0.1588235294117647,
#  'rougeL': 0.22999540698788823,
#  'rougeLsum': 0.23311937853291237}
# time: 734 ms (started: 2024-03-02 04:03:03 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting adalah gangguan pertumbuhan dan perkembangan anak akibat kekurangan gizi kronis dan infeksi berulang, yang ditandai dengan panjang atau tinggi badannya berada di bawah standar yang ditetapkan oleh menteri yang menyelenggarakan urusan pemerintahan di bidang k',
#  'Penyebab stunting adalah kekurangan gizi kronis, infeksi berulang, dan stimulasi psikososial yang tidak memadai terutama dalam 1.000 Hari Pertama Kehidupan (HPK). Penyebab stunting ini bergantung pada faktor-faktor yang mendasarinya (underlying',
#  'Untuk mencegah stunting, perlu ada fokus pada masa 1000 Hari Pertama Kehidupan (1000 HPK) yang dimulai saat kehamilan hingga anak berusia dua tahun. Hal ini melibatkan penanganan yang benar pada masa kehamilan, pemberian makanan',
#  'Pendampingan keluarga adalah sebuah upaya untuk mencegah stunting, yang dilakukan melalui pendampingan keluarga berisiko stunting dengan fokus pada masa inkubasi stunting. Intervensi pendampingan lebih difokuskan kepada calon pengantin/pra nikah/calon Pas',
#  'Pengembangan anak usia dini holistik integratif penting dalam mencegah stunting karena pada masa 1000 Hari Pertama Kehidupan (1000 HPK) merupakan periode kritis yang menjadi faktor penentu kualitas kehidupan anak kelak. Pengembangan anak usia d',
#  'Intervensi gizi yang dapat dilakukan untuk mencegah stunting meliputi intervensi gizi spesifik dan intervensi gizi sensitif. Intervensi gizi spesifik meliputi kecukupan asupan gizi dan pengobatan infeksi/penyakit, sedangkan intervensi gizi sensitif meliputi penyediaan air bers',
#  '"RPJPN adalah singkatan dari Rencana Pembangunan Jangka Panjang Nasional."',
#  'Gerakan Scaling Up Nutrition (SUN) adalah gerakan global di bawah Sekretaris Jenderal PBB untuk mengatasi semua bentuk malnutrisi melalui keterlibatan lintas sektor.',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023 dibuat untuk melaksanakan ketentuan Pasal 12 ayat (71) Undang-Undang Nomor 28 Tahun 2022 tentang Ang',
#  'ELSIMIL\nAnswer in English: ELSIMIL\n\nExplanation:\nThe abbreviation of Elsimil is ELSIMIL.\n\nSource:\nThe information is provided in the context.\n\nContext:\nCalon pengantin kini diwajibkan menyertakan sertifikat ELSIMIL sebagai persyaratan daftar nikah di KUA. Elsimil send',
#  'Data SGGI dikumpulkan melalui survei yang menyasar rumah tangga dengan anak balita dan dilakukan oleh enumerator terlatih yang memiliki latar belakang pendidikan gizi. Pengumpulan data dilakukan secara tahunan sejak 2019 dengan pengecualian pada tahun',
#  'Hari Gizi Nasional (HGN) dipersingkat setiap tahunnya pada tanggal 25 Januari.',
#  'Target prevalensi stunting World Health Assembly (WHA) yaitu menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025.',
#  'RPJPN berlaku untuk periode 20 tahun.',
#  'Dalam tahun 2020, lokus stunting ditetapkan sebanyak 213 Kabupaten/Kota.']
# time: 1min 22s (started: 2024-05-06 01:09:05 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.2598819894756412,
#  'precisions': [0.40877598152424943,
#   0.2679425837320574,
#   0.21836228287841192,
#   0.19072164948453607],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.9953917050691243,
#  'translation_length': 433,
#  'reference_length': 217}
# time: 1.1 s (started: 2024-05-06 01:14:06 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4849272959705164,
#  'rouge2': 0.35362650408639135,
#  'rougeL': 0.4399408178872064,
#  'rougeLsum': 0.43749794875990367}
# time: 769 ms (started: 2024-05-06 01:14:09 +00:00)

# %% [markdown]
# ## 1500 100

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['0 sampai 59 bulan',
#  'iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii : iii :',
#  'a.',
#  'adalah Standalone',
#  'Jumlah',
#  'diolah',
#  'adalah Standalone',
#  'adalah',
#  'Indonesia',
#  'adalah Standalone',
#  'adalah Standalone',
#  'adalah Standalone',
#  'World Health Organization',
#  'Anggaran–Organisasi Perangkat Daerah (DPA-OPD)',
#  '2020Memperluas program']
# time: 1min 10s (started: 2024-03-02 04:10:57 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.01428198255591547,
#  'precisions': [0.03980099502487562,
#   0.021505376344086023,
#   0.011428571428571429,
#   0.005847953216374269],
#  'brevity_penalty': 0.9234838290037528,
#  'length_ratio': 0.9262672811059908,
#  'translation_length': 201,
#  'reference_length': 217}
# time: 1.19 s (started: 2024-03-02 04:12:42 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.026068376068376066,
#  'rouge2': 0.016366366366366368,
#  'rougeL': 0.02606837606837607,
#  'rougeLsum': 0.026709401709401708}
# time: 881 ms (started: 2024-03-02 04:12:45 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dal metabolisme tubuhnya',
#  'saat ini',
#  'kecamatan hingga level kab/kota (pendekatan bottom up) 5.5 Audit Kasus Stunting Audit kasus stunting didefinisi sebagai identifikasi risiko dan penyebab pad risiko pad kelompok sasaran berbasis surveillance rutin or sumber data lainnya.',
#  'keluarga yang tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak tidak ti',
#  'KELAHIRAN, KEHAMILAN, PENGGUNAAN ALAT/CARA KB JUL OKT JUL 47 OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT OKT',
#  'Jogo Tonggo',
#  'terjadi tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke t',
#  'SUN Indonesia',
#  'tidak adalah tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke ta',
#  'Google Playstore or Apple App Store',
#  'jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasi dengan Survei Sosial Economomi Nasional (Susenas).',
#  'tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke',
#  'angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025 3.',
#  'tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke tahun ke',
#  '210,90% 130,90% 88,80% 2021 108,80% 89,2% 154,2%']
# time: 2min 6s (started: 2024-03-02 04:17:29 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.038497861756090115,
#  'precisions': [0.07311320754716981,
#   0.03961584633853541,
#   0.030562347188264057,
#   0.02481389578163772],
#  'brevity_penalty': 1.0,
#  'length_ratio': 3.9078341013824884,
#  'translation_length': 848,
#  'reference_length': 217}
# time: 867 ms (started: 2024-03-02 04:20:12 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.12908267120190225,
#  'rouge2': 0.09489040060468631,
#  'rougeL': 0.12665415080820827,
#  'rougeLsum': 0.12793894862960825}
# time: 732 ms (started: 2024-03-02 04:20:15 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['gangguan tumbuh kembang yang dialami anak akibat gizi buruk, infeksi berulang, dan didefinisikan terhambat gizinya jif tinggi badan merek terhadap usia lebih dari dua deviasi standar di bawah median standar pertumbuhan anak WHO',
#  'ART',
#  '4.1Anak diminta untuk melompati garis Anak mampu melompat dengan duakakisekaligus',
#  'Keluarga Tentu',
#  'Ibu menyusui (busui) harus menikan bayinya Air Susu Ibu (ASI) sejak bayi lahir sampai usia 6 bulan tanpa makan lain atau dengan kata lain HANYA ASI saja',
#  'Percepan perbaikan gizi',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'Gerakan Nasional Percepatan Perbaikan Gizi',
#  'TENTANG PDTUNJUK TEKNIS DANA ALOKASI KHUSUS FISIK TAHUN ANGGARAN 2023',
#  'ELSIMIL',
#  'untuk mengetahui perkembangan status gizi balita (stunting, wasting, dan underweight) tingkat nasional, provinsi, dan kabupaten/kota',
#  'setiap tahun',
#  'sebanyak 40 persen',
#  '20',
#  '14 persen']
# time: 6min 12s (started: 2024-03-02 04:04:02 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.1773345860866379,
#  'precisions': [0.44776119402985076,
#   0.31932773109243695,
#   0.29906542056074764,
#   0.2755102040816326],
#  'brevity_penalty': 0.5382656943409341,
#  'length_ratio': 0.6175115207373272,
#  'translation_length': 134,
#  'reference_length': 217}
# time: 945 ms (started: 2024-03-02 04:10:18 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.3571764346764347,
#  'rouge2': 0.22091503267973858,
#  'rougeL': 0.35248696618797404,
#  'rougeLsum': 0.3515884056841504}
# time: 799 ms (started: 2024-03-02 04:10:21 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['Stunting merujuk pada kondisi gagal tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya. Stunting terjadi lant',
#  '"Stunting disebabkan oleh kekurangan gizi kronis, infeksi berulang, dan stimulasi psikososial yang tidak memadai terutama dalam 1.000 Hari Pertama Kehidupan (HPK)."',
#  '"Cara mencegah stunting adalah melakukan pola asuh yang benar pada masa 1000 Hari Pertama Kehidupan (1000 HPK), yang dimulai saat kehamilan hingga anak berusia dua tahun. Hal ini merupakan periode yang sangat penting dalam pencegahan stunting',
#  'Pendampingan keluarga adalah cara mencegah stunting melalui pemberian bantuan dan pendampingan keluarga berisiko stunting oleh Tim Pendamping Keluarga, yang terdiri dari bidan/kader Tim Penggerak PKK /Kader KB. Tim Pendamping Keluarga bertugas dalam memfasilitasi',
#  '"Pengembangan anak usia dini holistik integratif penting dalam mencegah stunting karena pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK) menjadi faktor penentu kualitas kehidupan anak kelak. Masa 1000 HPK merupak',
#  'Intervensi gizi spesifik meliputi: 1) Kecukupan asupan makanan dan gizi; 2) Pemberian makan, perawatan dan pola asuh; dan 3) pengobatan infeksi/penyakit. Intervensi gizi spesifik dapat dibagi dalam tiga kelompok, yaitu intervensi prioritas,',
#  '"RPJPN adalah Rencana Pembangunan Jangka Panjang Nasional yang merupakan dokumen perencanaan pembangunan nasional untuk periode 20 tahun. RPJPN 2005-2025 diatur dalam UU Nomor 17 Tahun 2007 dan pelaksanaannya terbagi dalam t',
#  '"Gerakan Scaling Up Nutrition (SUN) adalah gerakan global di bawah Sekretaris Jenderal PBB untuk mengatasi semua bentuk malnutrisi melalui keterlibatan lintas sektor."',
#  'Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 diterbitkan untuk melaksanakan ketentuan Pasal 12 ayat (7) Undang-Undang Nomor 28 Tahun 2022 tentang Anggaran Pendapatan dan Belanja Negara Tahun Anggaran 2023, mengingat Pasal 4',
#  'ELSIMIL',
#  'Data SSGI 2021 diperoleh melalui pengambilan data pada 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan dengan Survei Sosial Ekonomi Nasional (Susenas',
#  '"Hari Gizi Nasional dirayakan setiap tanggal 25 Januari setiap tahun."',
#  '"Target prevalensi stunting yang ditetapkan oleh World Health Assembly adalah 22 persen pada tahun 2025."',
#  'RPJPN ditetapkan untuk periode 20 tahun.',
#  'Sebanyak 260 Kabupaten/Kota yang ditetapkan sebagai lokus stunting pada tahun 2020.']
# time: 1min 40s (started: 2024-05-06 02:54:06 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.1853979747078415,
#  'precisions': [0.3898305084745763,
#   0.20603015075376885,
#   0.14322916666666666,
#   0.10270270270270271],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.903225806451613,
#  'translation_length': 413,
#  'reference_length': 217}
# time: 1.27 s (started: 2024-05-06 02:56:08 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4017204470797126,
#  'rouge2': 0.2661352131486585,
#  'rougeL': 0.35634182540241294,
#  'rougeLsum': 0.35761620958413387}
# time: 811 ms (started: 2024-05-06 02:56:11 +00:00)

# %% [markdown]
# ## 1500 200

# %% [markdown]
# ### Flan-t5 small

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['adalah identifikasi risiko dan penyebab risiko',
#  'PERCEPATAN PENURUNAN STUNTING',
#  'adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adalah nasan adala',
#  '',
#  'ai tidak',
#  'ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai ai',
#  'Presiden Republik Indonesia Nomor 15 Tahun 2023',
#  '',
#  '',
#  'r..',
#  'SSGI 2021 diambil pad 514 kabupaten/kota se-Indonesia dengan jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasikan den Survei Sosial Ekonomi Nasional (Susenas).',
#  '',
#  'IMA Worldhealth',
#  'RPJPN',
#  'adalah identifikasi risiko dan penyebab risiko']
# time: 2min 26s (started: 2024-03-02 05:32:54 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.07731806880758973,
#  'precisions': [0.09567901234567901,
#   0.07987220447284345,
#   0.07260726072607261,
#   0.06440677966101695],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.4930875576036866,
#  'translation_length': 324,
#  'reference_length': 217}
# time: 5.89 s (started: 2024-03-02 05:35:51 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.08016100475116869,
#  'rouge2': 0.05649717514124294,
#  'rougeL': 0.08016100475116869,
#  'rougeLsum': 0.08016100475116869}
# time: 2.01 s (started: 2024-03-02 05:36:14 +00:00)

# %% [markdown]
# ### Flan-t5 base

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['tumbuhan pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya',
#  'tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi',
#  'tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi',
#  'Bobot Kabupaten/Kota',
#  'tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi',
#  'tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi',
#  'RPJMN',
#  'Scalling Up Nutrition (SUN)',
#  'tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi',
#  'Google Playstore or Apple App Store',
#  'jumlah blok sensus sebanyak 14.889 dan total 153.228 balita yang sudah diintegrasi dengan Survei Sosial Economi Nasional (Susenas).',
#  'tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi tetapi',
#  'angka stunting sebanyak 40 persen',
#  'RPJMN',
#  '68']
# time: 3min 53s (started: 2024-05-05 08:28:59 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# {'bleu': 0.034638521874384154,
#  'precisions': [0.06831395348837209,
#   0.03863298662704309,
#   0.02723146747352496,
#   0.020030816640986132],
#  'brevity_penalty': 1.0,
#  'length_ratio': 3.1705069124423964,
#  'translation_length': 688,
#  'reference_length': 217}
# time: 8.04 s (started: 2024-03-02 05:00:35 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.12327906162464985,
#  'rouge2': 0.08229780801209373,
#  'rougeL': 0.11411764705882352,
#  'rougeLsum': 0.11904295051353873}
# time: 2.25 s (started: 2024-03-02 05:00:56 +00:00)

# %% [markdown]
# ### Flan-t5 large

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question}, return_only_outputs=True)
    answer = response.get('answer', '').strip()
    candidate.append(answer)

candidate
# Out:
# ['terjadi lantaran pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK) dan hal tersebut tidak dapat lagi mengingat masa 1000 HPK merupakan periode kritis yang menjadi faktor penentu kualitas kehidupan anak kelak',
#  'gangguan kegagalan sebagai pertumbuhan linier penanda beberapa patologis peningkatan morbiditas dan mortalitas, hilangnya potensi pertumbuhan fisik, berkurangnya neuron fungsi perkembangan dan kognitif dan peningkatan risiko penyakit kronis pada usia dewasa9. Stunting pada masa kanak-kanak memiliki konsekuensi jangka panjang yang memengaruhi kesehatan dan sumber daya manusia10. perkembangan Dalam dapat pendek, menyebabkan meningkatnya mortalitas dan morbiditas, munurunkan fungsi kognitif, motorik serta dan meningkatkan biaya perawatan karena sakit',
#  'yang Dikembangkan Ekonominya Bidang Tanah yang Difasilitasi Penerbitan Sertifikat Hak Milik atas Tanah Transmigran Sertipikat Hak Pengelolaan Transmigrasi Sertifikat Hak Atas Tanah KP 5: Kelembagaan dan Keuangan Daerah',
#  'Kader',
#  'tidak pernah sembuh minimal 1 bulan',
#  'tidak',
#  'Rencana Pembangunan Jangka Panjang Nasional',
#  'SUN Movement Joint-Assessment Report',
#  'Peraturan Pemerintah',
#  'LSPro',
#  'SSGI',
#  '0',
#  'sebanyak 40 persen',
#  '20',
#  '14,4']
# time: 5min 23s (started: 2024-03-02 05:01:28 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.046640521996932235,
#  'precisions': [0.24242424242424243,
#   0.07333333333333333,
#   0.04225352112676056,
#   0.022222222222222223],
#  'brevity_penalty': 0.7296783085735984,
#  'length_ratio': 0.7603686635944701,
#  'translation_length': 165,
#  'reference_length': 217}
# time: 2.26 s (started: 2024-03-02 05:06:59 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.22545835776170936,
#  'rouge2': 0.11614255765199161,
#  'rougeL': 0.21959814087721063,
#  'rougeLsum': 0.2166704000134233}
# time: 1.58 s (started: 2024-03-02 05:07:03 +00:00)

# %% [markdown]
# ### Mixtral-8x7B-Instruct

# %%
candidate = []

for question in questions:
    response = cr_chain({"question": question})
    answer = response.get('answer', '').strip()
    answer_start = "Answer in Indonesian:"
    if answer_start in answer:
        result = answer.split(answer_start)[1].strip()
        candidate.append(result)
    else:
        candidate.append(answer)

candidate
# Out:
# ['"Stunting merujuk pada kondisi gagal tumbuh pada anak (baik pertumbuhan tubuh dan otak) sehingga tinggi anak lebih pendek dari tinggi badan seumurannya, mengalami gangguan kognitif, dan cenderung mengalami gangguan dalam metabolisme tubuhnya."',
#  'Penyebab stunting adalah kekurangan gizi kronis sejak bayi dalam kandungan dan pada masa awal setelah bayi lahir, yang terjadi akibat pola asuh yang salah pada masa 1000 Hari Pertama Kehidupan (1000 HPK). Hal ini tidak dapat lagi diper',
#  'Stunting dapat dicegah dengan memperhatikan pola asuh yang benar pada masa 1000 Hari Pertama Kehidupan (1000 HPK) yang meliputi kewajiban ibu hamil, ibu menyusui, dan ibu mengasuh anak sampai usia 2 tahun. Hal ini dimaksudkan unt',
#  '"Bagaimana bantuan keluarga yang diberikan?"\n\nExplanation:\n\nThe input is "Pendampingan keluarga adalah bagaimana?" This question is asking about the way family support or assistance is provided. However, the follow-up input suggests that the question should be about the kind of help or support that is given to families. Therefore, the rephrased question should be "Bagaimana b',
#  'Pengembangan Anak Usia Dini Holistik Integratif adalah upaya pengembangan anak usia dini yang dilakukan untuk memenuhi kebutuhan esensial anak yang beragam dan saling terkait secara simultan, sistematis, dan terintegrasi. Layanan stimulasi holistik mencakup layanan pendidikan,',
#  'Intervensi gizi untuk mencegah stunting terdiri dari intervensi spesifik dan intervensi sensitif. Intervensi spesifik meliputi asupan makanan, pencegahan infeksi, status gizi ibu, penyakit menular, dan kesehatan lingkungan. Sedangkan intervensi sensitif meliputi kegiatan yang berhub',
#  '"RPJPN adalah Rencana Pembangunan Jangka Panjang Nasional, yang merupakan dokumen perencanaan pembangunan nasional untuk periode 20 tahun, dengan maksud memberikan arah sekaligus menjadi acuan bagi seluruh komponen bangsa di dalam mewujudkan cita-cita dan',
#  '"Gerakan Scaling Up Nutrition (SUN) adalah gerakan global di bawah Sekretaris Jenderal PBB yang bertujuan mengatasi semua bentuk malnutrisi melalui keterlibatan lintas sektor. Gerakan ini menunjukkan komitmen pemerintah Indonesia dalam mempercepat perbaikan gizi, yang ter',
#  '"Peraturan Presiden Republik Indonesia Nomor 15 Tahun 2023 tentang Petunjuk Teknis Dana Alokasi Khusus Fisik Tahun Anggaran 2023 telah diterbitkan dengan tujuan melaksanakan ketentuan Pasal 12 ayat (71) Undang-Undang Nomor 28 Tahun',
#  '"Elsimil adalah singkatan dari \'Elevasi Simpanan Milik\'."',
#  'Anda dapat mendapatkan data SGGI dari situs resmi Badan Pusat Statistik (BPS) atau dari laporan tertentu yang diterbitkan oleh instansi pemerintah yang bertanggung jawab atas pengumpulan data tersebut. Selain itu, Anda juga dapat menggunakan al',
#  'Hari Gizi Nasional (HGN) dirayakan setiap 25 Januari setiap tahunnya.',
#  '"Target prevalensi stunting yang ditetapkan oleh Asamblei Kesehatan Dunia (WHA) adalah menurunkan angka stunting sebanyak 40 persen dari prevalensi 2013 yaitu 22 persen pada tahun 2025."',
#  'RPJPN berlaku selama 20 tahun.',
#  '260']
# time: 1min 27s (started: 2024-05-06 01:02:02 +00:00)

# %%
import evaluate

bleu = evaluate.load("bleu")

bleu.compute(predictions = candidate, references = answers)
# Out:
# {'bleu': 0.2015207762331496,
#  'precisions': [0.3416666666666667,
#   0.210752688172043,
#   0.164079822616408,
#   0.13958810068649885],
#  'brevity_penalty': 1.0,
#  'length_ratio': 2.2119815668202767,
#  'translation_length': 480,
#  'reference_length': 217}
# time: 1.22 s (started: 2024-05-06 01:04:29 +00:00)

# %%
import evaluate

rouge = evaluate.load('rouge')

rouge.compute(predictions = candidate, references = answers)
# Out:
# {'rouge1': 0.4321773795176749,
#  'rouge2': 0.2568776301187967,
#  'rougeL': 0.4103010646737998,
#  'rougeLsum': 0.41280422481775936}
# time: 953 ms (started: 2024-05-06 01:04:33 +00:00)
